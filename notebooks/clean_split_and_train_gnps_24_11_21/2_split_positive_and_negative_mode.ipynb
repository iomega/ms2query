# %% [markdown]
# # Split data
# In this notebook the data that was cleaned in 1_Clean_GNPS_spectra is split into different subsets.

# %%
import pickle
import os
root_folder = "C:/Users/jonge094/PycharmProjects/PhD_MS2Query/ms2query/data/gnps_24_11_2021"

# %%
outfile = os.path.join(root_folder, "in_between_files_clean_gnps_spectra/ALL_GNPS_24_11_2021_inchikeys_from_pubchem.pickle")
with open(outfile, 'rb') as file:
    gnps_spectra = pickle.load(file)

# %%
def count_annotations(spectra):
    inchi_lst = []
    smiles_lst = []
    inchikey_lst = []
    nr_of_spectra_with_less_than_3_peaks = 0
    nr_of_spectra_with_more_than_500_peaks = 0

    for i, spec in enumerate(spectra):
        inchi_lst.append(spec.get("inchi"))
        smiles_lst.append(spec.get("smiles"))
        inchikey = spec.get("inchikey")
        if inchikey is None:
            inchikey = spec.get("inchikey_inchi")
        inchikey_lst.append(inchikey)
        if len(spec.peaks.mz) < 3:
            nr_of_spectra_with_less_than_3_peaks += 1
        if len(spec.peaks.mz) > 500:
            nr_of_spectra_with_more_than_500_peaks += 1

    inchi_count = sum([1 for x in inchi_lst if x])
    smiles_count = sum([1 for x in smiles_lst if x])
    inchikey_count = sum([1 for x in inchikey_lst if x])
    print("nr_of_spectra:", len(spectra))
    print("Inchis:", inchi_count, "--", len(set(inchi_lst)), "unique")
    print("Smiles:", smiles_count, "--", len(set(smiles_lst)), "unique")
    print("Inchikeys:", inchikey_count, "--", 
          len(set([x[:14] for x in inchikey_lst if x])), "unique (first 14 characters)")
    print("Spectra with less than 3 peaks:", nr_of_spectra_with_less_than_3_peaks)
    print("Spectra with more than 500 peaks:", nr_of_spectra_with_more_than_500_peaks)

# %%
count_annotations(gnps_spectra)
# Out:
# nr_of_spectra: 403840
# Inchis: 352717 -- 27034 unique
# Smiles: 352694 -- 37299 unique
# Inchikeys: 352673 -- 22615 unique (first 14 characters)
# Spectra with less than 3 peaks: 0
# Spectra with more than 500 peaks: 19264

# %% [markdown]
# ## split into negative and positive mode

# %%
spectrums_positive = []
spectrums_negative = []
for i, spec in enumerate(gnps_spectra):
    if spec.get("ionmode") == "positive":
        spectrums_positive.append(spec)
    elif spec.get("ionmode") == "negative":
        spectrums_negative.append(spec)
    else:
        print(f"No ionmode found for spectrum {i} ({spec.get('ionmode')})")
# Out:
# No ionmode found for spectrum 342240 (n/a)
# No ionmode found for spectrum 342245 (n/a)
# No ionmode found for spectrum 342246 (n/a)
# No ionmode found for spectrum 342248 (n/a)
# No ionmode found for spectrum 342249 (n/a)
# No ionmode found for spectrum 342252 (n/a)
# No ionmode found for spectrum 342256 (n/a)
# No ionmode found for spectrum 342262 (n/a)
# No ionmode found for spectrum 342264 (n/a)
# No ionmode found for spectrum 342268 (n/a)
# No ionmode found for spectrum 342476 (n/a)
# No ionmode found for spectrum 342479 (n/a)
# No ionmode found for spectrum 342483 (n/a)
# No ionmode found for spectrum 342485 (n/a)
# No ionmode found for spectrum 342497 (n/a)
# No ionmode found for spectrum 342498 (n/a)
# No ionmode found for spectrum 342499 (n/a)
# No ionmode found for spectrum 342503 (n/a)
# No ionmode found for spectrum 342505 (n/a)
# No ionmode found for spectrum 342506 (n/a)
# No ionmode found for spectrum 342512 (n/a)
# No ionmode found for spectrum 342514 (n/a)
# No ionmode found for spectrum 342515 (n/a)
# No ionmode found for spectrum 342517 (n/a)
# No ionmode found for spectrum 342519 (n/a)
# No ionmode found for spectrum 342521 (n/a)
# No ionmode found for spectrum 342523 (n/a)
# No ionmode found for spectrum 342524 (n/a)
# No ionmode found for spectrum 342527 (n/a)
# No ionmode found for spectrum 342528 (n/a)
# No ionmode found for spectrum 342530 (n/a)
# No ionmode found for spectrum 342531 (n/a)
# No ionmode found for spectrum 342533 (n/a)
# No ionmode found for spectrum 342535 (n/a)
# No ionmode found for spectrum 342536 (n/a)
# No ionmode found for spectrum 342538 (n/a)
# No ionmode found for spectrum 342539 (n/a)
# No ionmode found for spectrum 342541 (n/a)
# No ionmode found for spectrum 342542 (n/a)
# No ionmode found for spectrum 342543 (n/a)
# No ionmode found for spectrum 342546 (n/a)
# No ionmode found for spectrum 342547 (n/a)
# No ionmode found for spectrum 342548 (n/a)
# No ionmode found for spectrum 342550 (n/a)
# No ionmode found for spectrum 342552 (n/a)
# No ionmode found for spectrum 342553 (n/a)
# No ionmode found for spectrum 342556 (n/a)
# No ionmode found for spectrum 342558 (n/a)
# No ionmode found for spectrum 342560 (n/a)
# No ionmode found for spectrum 342561 (n/a)
# No ionmode found for spectrum 342562 (n/a)
# No ionmode found for spectrum 342563 (n/a)
# No ionmode found for spectrum 342564 (n/a)
# No ionmode found for spectrum 342566 (n/a)
# No ionmode found for spectrum 342568 (n/a)
# No ionmode found for spectrum 342569 (n/a)
# No ionmode found for spectrum 342570 (n/a)
# No ionmode found for spectrum 342571 (n/a)
# No ionmode found for spectrum 342592 (n/a)
# No ionmode found for spectrum 342612 (n/a)
# No ionmode found for spectrum 342642 (n/a)
# No ionmode found for spectrum 342659 (n/a)
# No ionmode found for spectrum 342662 (n/a)
# No ionmode found for spectrum 342670 (n/a)
# No ionmode found for spectrum 342685 (n/a)
# No ionmode found for spectrum 342692 (n/a)
# No ionmode found for spectrum 342701 (n/a)
# No ionmode found for spectrum 342716 (n/a)
# No ionmode found for spectrum 342725 (n/a)
# No ionmode found for spectrum 342739 (n/a)
# No ionmode found for spectrum 343041 (n/a)
# No ionmode found for spectrum 343044 (n/a)
# No ionmode found for spectrum 343045 (n/a)
# No ionmode found for spectrum 343046 (n/a)
# No ionmode found for spectrum 343049 (n/a)
# No ionmode found for spectrum 343050 (n/a)
# No ionmode found for spectrum 343058 (n/a)
# No ionmode found for spectrum 343074 (n/a)
# No ionmode found for spectrum 343089 (n/a)
# No ionmode found for spectrum 343103 (n/a)
# No ionmode found for spectrum 343105 (n/a)
# No ionmode found for spectrum 343125 (n/a)
# No ionmode found for spectrum 343130 (n/a)
# No ionmode found for spectrum 343132 (n/a)
# No ionmode found for spectrum 343134 (n/a)
# No ionmode found for spectrum 343136 (n/a)
# No ionmode found for spectrum 343148 (n/a)
# No ionmode found for spectrum 343157 (n/a)
# No ionmode found for spectrum 343159 (n/a)
# No ionmode found for spectrum 343160 (n/a)
# No ionmode found for spectrum 343168 (n/a)
# No ionmode found for spectrum 343194 (n/a)
# No ionmode found for spectrum 343203 (n/a)
# No ionmode found for spectrum 343210 (n/a)
# No ionmode found for spectrum 343213 (n/a)
# No ionmode found for spectrum 343214 (n/a)
# No ionmode found for spectrum 343218 (n/a)
# No ionmode found for spectrum 343223 (n/a)
# No ionmode found for spectrum 343227 (n/a)
# No ionmode found for spectrum 343228 (n/a)
# No ionmode found for spectrum 343230 (n/a)
# No ionmode found for spectrum 343236 (n/a)
# No ionmode found for spectrum 343238 (n/a)
# No ionmode found for spectrum 343249 (n/a)
# No ionmode found for spectrum 343255 (n/a)
# No ionmode found for spectrum 343256 (n/a)
# No ionmode found for spectrum 343262 (n/a)
# No ionmode found for spectrum 343265 (n/a)
# No ionmode found for spectrum 343266 (n/a)
# No ionmode found for spectrum 343267 (n/a)
# No ionmode found for spectrum 343268 (n/a)
# No ionmode found for spectrum 343269 (n/a)
# No ionmode found for spectrum 343271 (n/a)
# No ionmode found for spectrum 343272 (n/a)
# No ionmode found for spectrum 343276 (n/a)
# No ionmode found for spectrum 343278 (n/a)
# No ionmode found for spectrum 343279 (n/a)
# No ionmode found for spectrum 343283 (n/a)
# No ionmode found for spectrum 343284 (n/a)
# No ionmode found for spectrum 343286 (n/a)
# No ionmode found for spectrum 343300 (n/a)
# No ionmode found for spectrum 343308 (n/a)
# No ionmode found for spectrum 343309 (n/a)
# No ionmode found for spectrum 343310 (n/a)
# No ionmode found for spectrum 343315 (n/a)
# No ionmode found for spectrum 343321 (n/a)
# No ionmode found for spectrum 343322 (n/a)
# No ionmode found for spectrum 343327 (n/a)
# No ionmode found for spectrum 343338 (n/a)
# No ionmode found for spectrum 343339 (n/a)
# No ionmode found for spectrum 343341 (n/a)
# No ionmode found for spectrum 343348 (n/a)
# No ionmode found for spectrum 343349 (n/a)
# No ionmode found for spectrum 343352 (n/a)
# No ionmode found for spectrum 343354 (n/a)
# No ionmode found for spectrum 343355 (n/a)
# No ionmode found for spectrum 343357 (n/a)
# No ionmode found for spectrum 343361 (n/a)
# No ionmode found for spectrum 343363 (n/a)
# No ionmode found for spectrum 343367 (n/a)
# No ionmode found for spectrum 343370 (n/a)
# No ionmode found for spectrum 343373 (n/a)
# No ionmode found for spectrum 343376 (n/a)
# No ionmode found for spectrum 343377 (n/a)
# No ionmode found for spectrum 343378 (n/a)
# No ionmode found for spectrum 343381 (n/a)
# No ionmode found for spectrum 343382 (n/a)
# No ionmode found for spectrum 343384 (n/a)
# No ionmode found for spectrum 343404 (n/a)
# No ionmode found for spectrum 343405 (n/a)
# No ionmode found for spectrum 343406 (n/a)
# No ionmode found for spectrum 343408 (n/a)
# No ionmode found for spectrum 343409 (n/a)
# No ionmode found for spectrum 343410 (n/a)
# No ionmode found for spectrum 343411 (n/a)
# No ionmode found for spectrum 343412 (n/a)
# No ionmode found for spectrum 343413 (n/a)
# No ionmode found for spectrum 343415 (n/a)
# No ionmode found for spectrum 343416 (n/a)
# No ionmode found for spectrum 343418 (n/a)
# No ionmode found for spectrum 343420 (n/a)
# No ionmode found for spectrum 343421 (n/a)
# No ionmode found for spectrum 343422 (n/a)
# No ionmode found for spectrum 343424 (n/a)
# No ionmode found for spectrum 343425 (n/a)
# No ionmode found for spectrum 343426 (n/a)
# No ionmode found for spectrum 343428 (n/a)
# No ionmode found for spectrum 343431 (n/a)
# No ionmode found for spectrum 343432 (n/a)
# No ionmode found for spectrum 343433 (n/a)
# No ionmode found for spectrum 343434 (n/a)
# No ionmode found for spectrum 343435 (n/a)
# No ionmode found for spectrum 343436 (n/a)
# No ionmode found for spectrum 343437 (n/a)
# No ionmode found for spectrum 343439 (n/a)
# No ionmode found for spectrum 343442 (n/a)
# No ionmode found for spectrum 343444 (n/a)
# No ionmode found for spectrum 343456 (n/a)
# No ionmode found for spectrum 343457 (n/a)
# No ionmode found for spectrum 343458 (n/a)
# No ionmode found for spectrum 343460 (n/a)
# No ionmode found for spectrum 343462 (n/a)
# No ionmode found for spectrum 343464 (n/a)
# No ionmode found for spectrum 343465 (n/a)
# No ionmode found for spectrum 343466 (n/a)
# No ionmode found for spectrum 343467 (n/a)
# No ionmode found for spectrum 343468 (n/a)
# No ionmode found for spectrum 343470 (n/a)
# No ionmode found for spectrum 343471 (n/a)
# No ionmode found for spectrum 343472 (n/a)
# No ionmode found for spectrum 343473 (n/a)
# No ionmode found for spectrum 343474 (n/a)
# No ionmode found for spectrum 343475 (n/a)
# No ionmode found for spectrum 343479 (n/a)
# No ionmode found for spectrum 343480 (n/a)
# No ionmode found for spectrum 343481 (n/a)
# No ionmode found for spectrum 343482 (n/a)
# No ionmode found for spectrum 343484 (n/a)
# No ionmode found for spectrum 343489 (n/a)
# No ionmode found for spectrum 343491 (n/a)
# No ionmode found for spectrum 343492 (n/a)
# No ionmode found for spectrum 343493 (n/a)
# No ionmode found for spectrum 343494 (n/a)
# No ionmode found for spectrum 343495 (n/a)
# No ionmode found for spectrum 343497 (n/a)
# No ionmode found for spectrum 343498 (n/a)
# No ionmode found for spectrum 343500 (n/a)
# No ionmode found for spectrum 343502 (n/a)
# No ionmode found for spectrum 343503 (n/a)
# No ionmode found for spectrum 343504 (n/a)
# No ionmode found for spectrum 343505 (n/a)
# No ionmode found for spectrum 343506 (n/a)
# No ionmode found for spectrum 343507 (n/a)
# No ionmode found for spectrum 343509 (n/a)
# No ionmode found for spectrum 343510 (n/a)
# No ionmode found for spectrum 343513 (n/a)
# No ionmode found for spectrum 343514 (n/a)
# No ionmode found for spectrum 343515 (n/a)
# No ionmode found for spectrum 343516 (n/a)
# No ionmode found for spectrum 343518 (n/a)
# No ionmode found for spectrum 343519 (n/a)
# No ionmode found for spectrum 343520 (n/a)
# No ionmode found for spectrum 343522 (n/a)
# No ionmode found for spectrum 343524 (n/a)
# No ionmode found for spectrum 343525 (n/a)
# No ionmode found for spectrum 343526 (n/a)
# No ionmode found for spectrum 343528 (n/a)
# No ionmode found for spectrum 343529 (n/a)
# No ionmode found for spectrum 343531 (n/a)
# No ionmode found for spectrum 343532 (n/a)
# No ionmode found for spectrum 343539 (n/a)
# No ionmode found for spectrum 343540 (n/a)
# No ionmode found for spectrum 343541 (n/a)
# No ionmode found for spectrum 343542 (n/a)
# No ionmode found for spectrum 343543 (n/a)
# No ionmode found for spectrum 343544 (n/a)
# No ionmode found for spectrum 343545 (n/a)
# No ionmode found for spectrum 343546 (n/a)
# No ionmode found for spectrum 343547 (n/a)
# No ionmode found for spectrum 343550 (n/a)
# No ionmode found for spectrum 343552 (n/a)
# No ionmode found for spectrum 343554 (n/a)
# No ionmode found for spectrum 343556 (n/a)
# No ionmode found for spectrum 343559 (n/a)
# No ionmode found for spectrum 343563 (n/a)
# No ionmode found for spectrum 343564 (n/a)
# No ionmode found for spectrum 343565 (n/a)
# No ionmode found for spectrum 343567 (n/a)
# No ionmode found for spectrum 343568 (n/a)
# No ionmode found for spectrum 343572 (n/a)
# No ionmode found for spectrum 343575 (n/a)
# No ionmode found for spectrum 343576 (n/a)
# No ionmode found for spectrum 343577 (n/a)
# No ionmode found for spectrum 343579 (n/a)
# No ionmode found for spectrum 343582 (n/a)
# No ionmode found for spectrum 343591 (n/a)
# No ionmode found for spectrum 343595 (n/a)
# No ionmode found for spectrum 343599 (n/a)
# No ionmode found for spectrum 343609 (n/a)
# No ionmode found for spectrum 343663 (n/a)
# No ionmode found for spectrum 343967 (n/a)
# No ionmode found for spectrum 343971 (n/a)
# No ionmode found for spectrum 343974 (n/a)
# No ionmode found for spectrum 343975 (n/a)
# No ionmode found for spectrum 344826 (n/a)
# No ionmode found for spectrum 344828 (n/a)
# No ionmode found for spectrum 344831 (n/a)
# No ionmode found for spectrum 344871 (n/a)
# No ionmode found for spectrum 344872 (n/a)
# No ionmode found for spectrum 344877 (n/a)
# No ionmode found for spectrum 344880 (n/a)
# No ionmode found for spectrum 344881 (n/a)
# No ionmode found for spectrum 344903 (n/a)
# No ionmode found for spectrum 344912 (n/a)
# No ionmode found for spectrum 344913 (n/a)
# No ionmode found for spectrum 344915 (n/a)
# No ionmode found for spectrum 344916 (n/a)
# No ionmode found for spectrum 344918 (n/a)
# No ionmode found for spectrum 344951 (n/a)
# No ionmode found for spectrum 344964 (n/a)
# No ionmode found for spectrum 344966 (n/a)
# No ionmode found for spectrum 345122 (n/a)
# No ionmode found for spectrum 345124 (n/a)
# No ionmode found for spectrum 345127 (n/a)
# No ionmode found for spectrum 345985 (n/a)
# No ionmode found for spectrum 347193 (n/a)
# No ionmode found for spectrum 347194 (n/a)
# No ionmode found for spectrum 347195 (n/a)
# No ionmode found for spectrum 348071 (n/a)
# No ionmode found for spectrum 348072 (n/a)
# No ionmode found for spectrum 348167 (n/a)
# No ionmode found for spectrum 348177 (n/a)
# No ionmode found for spectrum 348191 (n/a)
# No ionmode found for spectrum 348197 (n/a)
# No ionmode found for spectrum 348200 (n/a)
# No ionmode found for spectrum 348204 (n/a)
# No ionmode found for spectrum 348217 (n/a)
# No ionmode found for spectrum 348223 (n/a)
# No ionmode found for spectrum 348229 (n/a)
# No ionmode found for spectrum 348269 (n/a)
# No ionmode found for spectrum 348287 (n/a)
# No ionmode found for spectrum 348458 (n/a)
# No ionmode found for spectrum 348492 (n/a)
# No ionmode found for spectrum 348496 (n/a)
# No ionmode found for spectrum 348498 (n/a)
# No ionmode found for spectrum 349198 (n/a)
# No ionmode found for spectrum 349199 (n/a)
# No ionmode found for spectrum 349217 (n/a)
# No ionmode found for spectrum 349432 (n/a)
# No ionmode found for spectrum 349433 (n/a)
# No ionmode found for spectrum 349476 (n/a)
# No ionmode found for spectrum 349480 (n/a)
# No ionmode found for spectrum 349484 (n/a)
# No ionmode found for spectrum 349488 (n/a)
# No ionmode found for spectrum 349489 (n/a)
# No ionmode found for spectrum 349491 (n/a)
# No ionmode found for spectrum 349505 (n/a)
# No ionmode found for spectrum 349509 (n/a)
# No ionmode found for spectrum 349510 (n/a)
# No ionmode found for spectrum 349512 (n/a)
# No ionmode found for spectrum 349513 (n/a)
# No ionmode found for spectrum 349514 (n/a)
# No ionmode found for spectrum 349515 (n/a)
# No ionmode found for spectrum 349516 (n/a)
# No ionmode found for spectrum 349518 (n/a)
# No ionmode found for spectrum 349523 (n/a)
# No ionmode found for spectrum 349524 (n/a)
# No ionmode found for spectrum 349525 (n/a)
# No ionmode found for spectrum 349528 (n/a)
# No ionmode found for spectrum 349530 (n/a)
# No ionmode found for spectrum 349531 (n/a)
# No ionmode found for spectrum 349532 (n/a)
# No ionmode found for spectrum 349541 (n/a)
# No ionmode found for spectrum 349547 (n/a)
# No ionmode found for spectrum 349550 (n/a)
# No ionmode found for spectrum 349553 (n/a)
# No ionmode found for spectrum 349557 (n/a)
# No ionmode found for spectrum 349558 (n/a)
# No ionmode found for spectrum 349573 (n/a)
# No ionmode found for spectrum 349574 (n/a)
# No ionmode found for spectrum 349578 (n/a)
# No ionmode found for spectrum 349614 (n/a)
# No ionmode found for spectrum 349615 (n/a)
# No ionmode found for spectrum 349643 (n/a)
# No ionmode found for spectrum 349656 (n/a)
# No ionmode found for spectrum 349660 (n/a)
# No ionmode found for spectrum 349661 (n/a)
# No ionmode found for spectrum 349663 (n/a)
# No ionmode found for spectrum 349668 (n/a)
# No ionmode found for spectrum 349669 (n/a)
# No ionmode found for spectrum 349670 (n/a)
# No ionmode found for spectrum 349677 (n/a)
# No ionmode found for spectrum 349681 (n/a)
# No ionmode found for spectrum 349683 (n/a)
# No ionmode found for spectrum 349686 (n/a)
# No ionmode found for spectrum 349689 (n/a)
# No ionmode found for spectrum 349690 (n/a)
# No ionmode found for spectrum 349694 (n/a)
# No ionmode found for spectrum 349702 (n/a)
# No ionmode found for spectrum 349705 (n/a)
# No ionmode found for spectrum 349708 (n/a)
# No ionmode found for spectrum 349710 (n/a)
# No ionmode found for spectrum 349713 (n/a)
# No ionmode found for spectrum 349722 (n/a)
# No ionmode found for spectrum 349724 (n/a)
# No ionmode found for spectrum 349725 (n/a)
# No ionmode found for spectrum 349726 (n/a)
# No ionmode found for spectrum 349759 (n/a)
# No ionmode found for spectrum 349761 (n/a)
# No ionmode found for spectrum 349770 (n/a)
# No ionmode found for spectrum 349815 (n/a)
# No ionmode found for spectrum 349817 (n/a)
# No ionmode found for spectrum 349821 (n/a)
# No ionmode found for spectrum 349822 (n/a)
# No ionmode found for spectrum 349825 (n/a)
# No ionmode found for spectrum 349831 (n/a)
# No ionmode found for spectrum 349832 (n/a)
# No ionmode found for spectrum 349833 (n/a)
# No ionmode found for spectrum 349838 (n/a)
# No ionmode found for spectrum 349840 (n/a)
# No ionmode found for spectrum 349847 (n/a)
# No ionmode found for spectrum 349849 (n/a)
# No ionmode found for spectrum 349850 (n/a)
# No ionmode found for spectrum 349851 (n/a)
# No ionmode found for spectrum 349852 (n/a)
# No ionmode found for spectrum 349853 (n/a)
# No ionmode found for spectrum 349857 (n/a)
# No ionmode found for spectrum 349858 (n/a)
# No ionmode found for spectrum 349859 (n/a)
# No ionmode found for spectrum 349860 (n/a)
# No ionmode found for spectrum 349861 (n/a)
# No ionmode found for spectrum 349863 (n/a)
# No ionmode found for spectrum 349864 (n/a)
# No ionmode found for spectrum 349865 (n/a)
# No ionmode found for spectrum 349866 (n/a)
# No ionmode found for spectrum 349868 (n/a)
# No ionmode found for spectrum 349872 (n/a)
# No ionmode found for spectrum 349874 (n/a)
# No ionmode found for spectrum 349875 (n/a)
# No ionmode found for spectrum 349876 (n/a)
# No ionmode found for spectrum 349880 (n/a)
# No ionmode found for spectrum 349881 (n/a)
# No ionmode found for spectrum 349882 (n/a)
# No ionmode found for spectrum 349883 (n/a)
# No ionmode found for spectrum 349884 (n/a)
# No ionmode found for spectrum 349885 (n/a)
# No ionmode found for spectrum 349886 (n/a)
# No ionmode found for spectrum 349887 (n/a)
# No ionmode found for spectrum 349888 (n/a)
# No ionmode found for spectrum 349890 (n/a)
# No ionmode found for spectrum 349891 (n/a)
# No ionmode found for spectrum 349892 (n/a)
# No ionmode found for spectrum 349894 (n/a)
# No ionmode found for spectrum 349895 (n/a)
# No ionmode found for spectrum 349896 (n/a)
# No ionmode found for spectrum 349898 (n/a)
# No ionmode found for spectrum 349899 (n/a)
# No ionmode found for spectrum 349900 (n/a)
# No ionmode found for spectrum 349901 (n/a)
# No ionmode found for spectrum 349902 (n/a)
# No ionmode found for spectrum 349903 (n/a)
# No ionmode found for spectrum 349908 (n/a)
# No ionmode found for spectrum 349911 (n/a)
# No ionmode found for spectrum 349912 (n/a)
# No ionmode found for spectrum 349913 (n/a)
# No ionmode found for spectrum 349914 (n/a)
# No ionmode found for spectrum 349915 (n/a)
# No ionmode found for spectrum 349916 (n/a)
# No ionmode found for spectrum 349918 (n/a)
# No ionmode found for spectrum 349920 (n/a)
# No ionmode found for spectrum 349921 (n/a)
# No ionmode found for spectrum 349922 (n/a)
# No ionmode found for spectrum 349923 (n/a)
# No ionmode found for spectrum 349924 (n/a)
# No ionmode found for spectrum 349928 (n/a)
# No ionmode found for spectrum 349930 (n/a)
# No ionmode found for spectrum 349935 (n/a)
# No ionmode found for spectrum 349938 (n/a)
# No ionmode found for spectrum 349939 (n/a)
# No ionmode found for spectrum 349941 (n/a)
# No ionmode found for spectrum 349942 (n/a)
# No ionmode found for spectrum 349944 (n/a)
# No ionmode found for spectrum 349945 (n/a)
# No ionmode found for spectrum 349946 (n/a)
# No ionmode found for spectrum 349951 (n/a)
# No ionmode found for spectrum 349954 (n/a)
# No ionmode found for spectrum 349961 (n/a)
# No ionmode found for spectrum 350001 (n/a)
# No ionmode found for spectrum 350011 (n/a)
# No ionmode found for spectrum 350019 (n/a)
# No ionmode found for spectrum 350022 (n/a)
# No ionmode found for spectrum 350025 (n/a)
# No ionmode found for spectrum 350032 (n/a)
# No ionmode found for spectrum 350033 (n/a)
# No ionmode found for spectrum 350038 (n/a)
# No ionmode found for spectrum 350044 (n/a)
# No ionmode found for spectrum 350049 (n/a)
# No ionmode found for spectrum 350059 (n/a)
# No ionmode found for spectrum 350067 (n/a)
# No ionmode found for spectrum 350073 (n/a)
# No ionmode found for spectrum 350074 (n/a)
# No ionmode found for spectrum 350082 (n/a)
# No ionmode found for spectrum 350086 (n/a)
# No ionmode found for spectrum 350088 (n/a)
# No ionmode found for spectrum 350091 (n/a)
# No ionmode found for spectrum 350092 (n/a)
# No ionmode found for spectrum 350093 (n/a)
# No ionmode found for spectrum 350094 (n/a)
# No ionmode found for spectrum 350095 (n/a)
# No ionmode found for spectrum 350097 (n/a)
# No ionmode found for spectrum 350101 (n/a)
# No ionmode found for spectrum 350104 (n/a)
# No ionmode found for spectrum 350105 (n/a)
# No ionmode found for spectrum 350107 (n/a)
# No ionmode found for spectrum 350113 (n/a)
# No ionmode found for spectrum 350116 (n/a)
# No ionmode found for spectrum 350135 (n/a)
# No ionmode found for spectrum 350138 (n/a)
# No ionmode found for spectrum 350139 (n/a)
# No ionmode found for spectrum 350142 (n/a)
# No ionmode found for spectrum 350143 (n/a)
# No ionmode found for spectrum 350153 (n/a)
# No ionmode found for spectrum 350155 (n/a)
# No ionmode found for spectrum 350158 (n/a)
# No ionmode found for spectrum 350164 (n/a)
# No ionmode found for spectrum 350165 (n/a)
# No ionmode found for spectrum 350168 (n/a)
# No ionmode found for spectrum 350169 (n/a)
# No ionmode found for spectrum 350173 (n/a)
# No ionmode found for spectrum 350176 (n/a)
# No ionmode found for spectrum 350178 (n/a)
# No ionmode found for spectrum 350186 (n/a)
# No ionmode found for spectrum 350187 (n/a)
# No ionmode found for spectrum 350192 (n/a)
# No ionmode found for spectrum 350196 (n/a)
# No ionmode found for spectrum 350198 (n/a)
# No ionmode found for spectrum 350199 (n/a)
# No ionmode found for spectrum 350207 (n/a)
# No ionmode found for spectrum 350209 (n/a)
# No ionmode found for spectrum 350212 (n/a)
# No ionmode found for spectrum 350216 (n/a)
# No ionmode found for spectrum 350218 (n/a)
# No ionmode found for spectrum 350223 (n/a)
# No ionmode found for spectrum 350225 (n/a)
# No ionmode found for spectrum 350227 (n/a)
# No ionmode found for spectrum 350228 (n/a)
# No ionmode found for spectrum 350230 (n/a)
# No ionmode found for spectrum 350233 (n/a)
# No ionmode found for spectrum 350236 (n/a)
# No ionmode found for spectrum 350240 (n/a)
# No ionmode found for spectrum 350244 (n/a)
# No ionmode found for spectrum 350245 (n/a)
# No ionmode found for spectrum 350246 (n/a)
# No ionmode found for spectrum 350254 (n/a)
# No ionmode found for spectrum 350257 (n/a)
# No ionmode found for spectrum 350258 (n/a)
# No ionmode found for spectrum 350259 (n/a)
# No ionmode found for spectrum 350261 (n/a)
# No ionmode found for spectrum 350262 (n/a)
# No ionmode found for spectrum 350266 (n/a)
# No ionmode found for spectrum 350267 (n/a)
# No ionmode found for spectrum 350272 (n/a)
# No ionmode found for spectrum 350274 (n/a)
# No ionmode found for spectrum 350275 (n/a)
# No ionmode found for spectrum 350278 (n/a)
# No ionmode found for spectrum 350281 (n/a)
# No ionmode found for spectrum 350283 (n/a)
# No ionmode found for spectrum 350291 (n/a)
# No ionmode found for spectrum 350292 (n/a)
# No ionmode found for spectrum 350295 (n/a)
# No ionmode found for spectrum 350298 (n/a)
# No ionmode found for spectrum 350299 (n/a)
# No ionmode found for spectrum 350303 (n/a)
# No ionmode found for spectrum 350305 (n/a)
# No ionmode found for spectrum 350306 (n/a)
# No ionmode found for spectrum 350307 (n/a)
# No ionmode found for spectrum 350315 (n/a)
# No ionmode found for spectrum 350317 (n/a)
# No ionmode found for spectrum 350335 (n/a)
# No ionmode found for spectrum 350336 (n/a)
# No ionmode found for spectrum 350337 (n/a)
# No ionmode found for spectrum 350340 (n/a)
# No ionmode found for spectrum 350344 (n/a)
# No ionmode found for spectrum 350347 (n/a)
# No ionmode found for spectrum 350353 (n/a)
# No ionmode found for spectrum 350355 (n/a)
# No ionmode found for spectrum 350356 (n/a)
# No ionmode found for spectrum 350361 (n/a)
# No ionmode found for spectrum 350362 (n/a)
# No ionmode found for spectrum 350370 (n/a)
# No ionmode found for spectrum 350373 (n/a)
# No ionmode found for spectrum 350386 (n/a)
# No ionmode found for spectrum 350389 (n/a)
# No ionmode found for spectrum 350390 (n/a)
# No ionmode found for spectrum 350392 (n/a)
# No ionmode found for spectrum 350394 (n/a)
# No ionmode found for spectrum 350411 (n/a)
# No ionmode found for spectrum 350414 (n/a)
# No ionmode found for spectrum 350431 (n/a)
# No ionmode found for spectrum 350432 (n/a)
# No ionmode found for spectrum 350439 (n/a)
# No ionmode found for spectrum 350440 (n/a)
# No ionmode found for spectrum 350443 (n/a)
# No ionmode found for spectrum 350450 (n/a)
# No ionmode found for spectrum 350454 (n/a)
# No ionmode found for spectrum 350499 (n/a)
# No ionmode found for spectrum 350500 (n/a)
# No ionmode found for spectrum 350502 (n/a)
# No ionmode found for spectrum 350832 (n/a)
# No ionmode found for spectrum 350833 (n/a)
# No ionmode found for spectrum 351853 (n/a)
# No ionmode found for spectrum 351857 (n/a)
# No ionmode found for spectrum 351877 (n/a)
# No ionmode found for spectrum 352037 (n/a)
# No ionmode found for spectrum 352040 (n/a)
# No ionmode found for spectrum 352041 (n/a)
# No ionmode found for spectrum 352043 (n/a)
# No ionmode found for spectrum 352060 (n/a)
# No ionmode found for spectrum 352345 (n/a)
# No ionmode found for spectrum 352385 (n/a)
# No ionmode found for spectrum 352388 (n/a)
# No ionmode found for spectrum 352395 (n/a)
# No ionmode found for spectrum 352397 (n/a)
# No ionmode found for spectrum 352399 (n/a)
# No ionmode found for spectrum 352435 (n/a)
# No ionmode found for spectrum 352436 (n/a)
# No ionmode found for spectrum 352442 (n/a)
# No ionmode found for spectrum 352443 (n/a)
# No ionmode found for spectrum 352491 (n/a)
# No ionmode found for spectrum 352492 (n/a)
# No ionmode found for spectrum 352493 (n/a)
# No ionmode found for spectrum 352500 (n/a)
# No ionmode found for spectrum 352510 (n/a)
# No ionmode found for spectrum 352683 (n/a)

# %%
print("Total nr of spectra:", len(gnps_spectra))
print("positive_mode_spectra:", len(spectrums_positive))
print("negative_mode_spectra:", len(spectrums_negative))
print("spectra_without_ionmode:", len(gnps_spectra)-len(spectrums_positive)-len(spectrums_negative))
# Out:
# Total nr of spectra: 403840
# positive_mode_spectra: 328550
# negative_mode_spectra: 74696
# spectra_without_ionmode: 594

# %%
pickle.dump(spectrums_positive,
           open(os.path.join(root_folder, "ALL_GNPS_24_11_2021_positive_all.pickle"), "wb"))
pickle.dump(spectrums_negative,
           open(os.path.join(root_folder, "ALL_GNPS_24_11_2021_negative_all.pickle"), "wb"))

# %% [markdown]
# ## Remove not fully annoated spectra
# The not annotated spectra are not used as validation or test spectra, but are used to train Spec2Vec

# %%
outfile = os.path.join(root_folder, "ALL_GNPS_24_11_2021_positive_all.pickle")
with open(outfile, 'rb') as file:
    all_positive_spectra = pickle.load(file)
    
outfile = os.path.join(root_folder, "ALL_GNPS_24_11_2021_negative_all.pickle")
with open(outfile, 'rb') as file:
    all_negative_spectra = pickle.load(file)

# %%
def select_fully_annotated_spectra(spectra):
    fully_annotated_spectra =[]
    not_fully_annotated_spectra =[]
    for spectrum in spectra:
        inchikey = spectrum.get("inchikey")
        if inchikey is not None and len(inchikey) > 13:
            smiles = spectrum.get("smiles")
            inchi = spectrum.get("inchi")
            if smiles is not None and len(smiles)>0:
                if inchi is not None and len(inchi) >0:
                    fully_annotated_spectra.append(spectrum)
                else: 
                    not_fully_annotated_spectra.append(spectrum)
#                     print(smiles)
#                     print(inchi)
#                     print(inchikey)
            else: 
                not_fully_annotated_spectra.append(spectrum)
#                 print(smiles)
#                 print(inchi)
#                 print(inchikey)
        else: 
            not_fully_annotated_spectra.append(spectrum)
    return fully_annotated_spectra, not_fully_annotated_spectra

# %%
complete_spectra_pos, incomplete_spectra_pos = select_fully_annotated_spectra(all_positive_spectra)
print(len(complete_spectra_pos))
print(len(incomplete_spectra_pos))
pickle.dump(complete_spectra_pos,
           open(os.path.join(root_folder, "ALL_GNPS_24_11_2021_positive_annotated.pickle"), "wb"))
pickle.dump(incomplete_spectra_pos,
           open(os.path.join(root_folder, "ALL_GNPS_24_11_2021_positive_not_annotated.pickle"), "wb"))
# Out:
# 293801
# 34749

# %%
complete_spectra_neg, incomplete_spectra_neg = select_fully_annotated_spectra(all_negative_spectra)
print(len(complete_spectra_neg))
print(len(incomplete_spectra_neg))
pickle.dump(complete_spectra_neg,
           open(os.path.join(root_folder, "ALL_GNPS_24_11_2021_negative_annotated.pickle"), "wb"))
pickle.dump(incomplete_spectra_neg,
           open(os.path.join(root_folder, "ALL_GNPS_24_11_2021_negative_not_annotated.pickle"), "wb"))
# Out:
# 58272
# 16424

# %%
import matchms
import os
from omigami import Spec2Vec,MS2DeepScore
import pandas as pd

spec2vec = Spec2Vec()
ms2deepscore = MS2DeepScore()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13144/2765644949.py in <module>
#       1 import matchms
#       2 import os
# ----> 3 from omigami import Spec2Vec,MS2DeepScore
#       4 import pandas as pd
#       5
#
# ModuleNotFoundError: No module named 'omigami'

# %% [markdown]
# # Helper functions:

# %%
def drop_null_spectra(spectra):
    ''''
    Drops spectra which have no peaks.
    
    '''
    Valid_Spectra = [spectrum for spectrum in spectra if len(spectrum.peaks.mz)>0]
    return Valid_Spectra
    
def ppm_calc(mass,mass_error=5):
    """
    Calculates the mass range allowable under a given ppm mass error restriction. 

    Requirements: 
    mass(float): the mass to use as the benchmark
    
    Optional: 
    mass_error(int): the mass error window. Defaults to 5ppm (publication limit)

    Returns: 
    (list): The mass window.  
    
    """
    Pos_error = (mass_error*0.000001*mass)+mass
    Neg_Error = (-mass_error*0.000001*mass)+mass
    return [Neg_Error,Pos_error]
    
def Clean_Metadata(Input_Dataframe):
    New_Dataframe=Input_Dataframe.copy()
    for i in New_Dataframe.index.tolist():
        GNPS_Record= GNPS_Condensed[GNPS_Condensed['spectrum_id']==i]
        parent_mass = GNPS_Record.iloc[0]['ExactMass']
        precursor_mz = GNPS_Record.iloc[0]['Precursor_MZ']
        New_Dataframe.at[i,'ExactMass']=parent_mass
        New_Dataframe.at[i,'precursor_mz']=precursor_mz
    return New_Dataframe

def Retrieve_by_pepmass (spectra,mass,round_to=3):
    return_list = []
    if type(mass)== float:
        for i in range(len(spectra)):
            if round(spectra[i].metadata['pepmass'][0],round_to) == mass:
                return_list.append(i)
    elif type(mass)== tuple:
        mass1 = mass[0]
        mass2 = mass[1]
        for i in range(len(spectra)):
            if mass1 < spectra[i].metadata['pepmass'][0] <mass2:
                return_list.append(i)
    return return_list

def Create_Annotation_Results (spectra, spectra_matches,ion_mode='positive',cutoff_score=0.70,mass_error=5,Savefile=None):
    """
    Creates a list of Annotations by filtering results with a cutoff score and mass error (observed vs records)
    
    """
    High_Match_Dict ={}
    Number_of_spectra = len(spectra_matches)
    for i in range(len(spectra_matches)):
        print(f'There are {Number_of_spectra} left to process.')
        High_matches = spectra_matches[i][spectra_matches[i]['score']>cutoff_score]
        if len(High_matches)>0:
            PEPMASS = spectra[i].metadata['pepmass'][0]
            if ion_mode == 'positive':
                Mass_low,Mass_high = ppm_calc(PEPMASS-1.0078,mass_error=mass_error)
            elif ion_mode =='negative':
                Mass_low,Mass_high = ppm_calc(PEPMASS+1.0078,mass_error=mass_error)
            Process_Result = Clean_Metadata(High_matches)
            Refined_Results = Process_Result[Process_Result['ExactMass'].between(Mass_low,Mass_high)]
            if len(Refined_Results)>0:
                High_Match_Dict[i]=(Refined_Results,"Match Via Exact Mass")
            else:
                Mass_low,Mass_high = ppm_calc(PEPMASS,mass_error=mass_error)
                Refined_Results = Process_Result[Process_Result['precursor_mz'].between(Mass_low,Mass_high)]
                if len(Refined_Results)>0:
                    High_Match_Dict[i]=(Refined_Results,"Match Via Precursor m/z")
        Number_of_spectra-=1
    Annotation_Results = pd.DataFrame(columns=['PEPMASS','Compound_Name','GNPS_Hit'])
    for i in High_Match_Dict: 
        Mass = spectra[i].metadata["pepmass"][0]
        name = High_Match_Dict[i][0].iloc[0]['compound_name']
        DB_spectrum = High_Match_Dict[i][0].iloc[0].name
        Hit_DF = pd.DataFrame.from_dict({'PEPMASS':[Mass],'Compound_Name':[name],'GNPS_Hit':[DB_spectrum]},orient='columns')
        Annotation_Results = pd.concat([Annotation_Results,Hit_DF],ignore_index=True)
    if Savefile:
        Annotation_Results.to_csv(Savefile)
    return Annotation_Results

# %% [markdown]
# # General notes about working with these data:
#
# * Positive mode data were downloaded from https://gnps.ucsd.edu/ProteoSAFe/status.jsp?task=39ed9b19f2e348f1b45bb8c78e11c16d and pertain to MSV000087011.
# * The "Download clustered spectra as MGF file" was used to derive the MSV000087011.mgf
# * This MGF contained null spectra which contained no peaks. -> drop_null_spectra was created and used, resulting in 787 nodes (verified against manuscript).
#
# * The same was repeated for MSV00008622 (https://gnps.ucsd.edu/ProteoSAFe/status.jsp?task=692236f015914501a9b0f2286c1df47f)

# %% [markdown]
# # Data filtration:
#
# Data are filtered from the mgf file imported from the molecular network to drop null spectra and renamed. **Do not run** unless you need it explicitly.

# %%
# f = os.path.join("MSV000087011","MSV000087011.mgf")
f= "METABOLOMICS-SNETS-V2-692236f0-download_clustered_spectra-main.mgf" # Change to destination of file as needed. 

spectra = list(matchms.importing.load_from_mgf(f))
spectrum = spectra[0]
spectra = drop_null_spectra(spectra)
matchms.exporting.save_as_mgf(spectra,'MSV000087012_Filtered.mgf')

# %% [markdown]
# ## Creating the condensed GNPS.json
#
# This is done because the condensed json file is less taxing on memory than the whole thing and we only need a few columns. **Again, do not run unless explicitly needed**

# %%
GNPS_Structure_DF = pd.read_json('ALL_GNPS.json')
GNPS_Structure_DF.columns
selected_columns = GNPS_Structure_DF[['spectrum_id','Precursor_MZ','ExactMass','Compound_Name','Smiles','INCHI']]
GNPS_Condensed = selected_columns.copy()
GNPS_Condensed.to_json('GNPS_Condensed.json')

# %% [markdown]
# # Data Processing

# %%
path_to_mgf='MSV000087011_Filtered.mgf'
spectra = list(matchms.importing.load_from_mgf(path_to_mgf))
len(spectra) # should be 787 for the positive mode data.
# Out:
# 787

# %%
spectra_matches = spec2vec.match_spectra_from_path(
    path_to_mgf, 
    n_best=100, 
    ion_mode="positive",
    include_metadata=["smiles", "compound_name",'parent_mass']
)
# Change to ms2deepscore when needed.
# Out:
# [                            score                  compound_name parent_mass  \
#  matches of spectrum-0
#  CCMSLIB00005759013       0.425402              3-Aminoisobutyrat     103.064
#  CCMSLIB00000223211       0.425402      alpha-Methyl-beta-alanine     103.064
#  CCMSLIB00000221511       0.425361  3-amino-2-methylpropanoic aci     103.064
#  CCMSLIB00000577917        0.28621            3-AMINOISOBUTANOATE     103.063
#  CCMSLIB00005720608       0.241379               4-AMINOBUTANOATE     103.064
#  ...                           ...                            ...         ...
#  CCMSLIB00006552053     0.00998506                   Malonic acid     104.013
#  CCMSLIB00006363486      0.0094881                   Malonic acid     104.013
#  CCMSLIB00005463935     0.00930952             2-AMINOISOBUTYRATE     103.064
#  CCMSLIB00005755952     0.00928514         2-Aminoisobutyric acid     103.073
#  CCMSLIB00000214951     0.00921376     2-Amino-2-methylpropanoate     103.073
#
#                                 smiles
#  matches of spectrum-0
#  CCMSLIB00005759013       CC(CN)C(=O)O
#  CCMSLIB00000223211       NCC(C)C(O)=O
#  CCMSLIB00000221511       CC(CN)C(=O)O
#  CCMSLIB00000577917       CC(CN)C(=O)O
#  CCMSLIB00005720608       C(CC(=O)O)CN
#  ...                               ...
#  CCMSLIB00006552053      O=C(O)CC(=O)O
#  CCMSLIB00006363486      O=C(O)CC(=O)O
#  CCMSLIB00005463935     CC(C)(N)C(O)=O
#  CCMSLIB00005755952     CC(C)(C(=O)O)N
#  CCMSLIB00000214951     CC(C)(C(=O)O)N
#
#  [150 rows x 4 columns],
#                             score                    compound_name parent_mass  \
#  matches of spectrum-1
#  CCMSLIB00005467680      0.297406                          Choline     103.103
#  CCMSLIB00000221546      0.186125  2-hydroxyethyl-trimethylazanium     103.101
#  CCMSLIB00000223229      0.186108                         Lipotril     103.101
#  CCMSLIB00005756167      0.186108                      Bilineurine     103.101
#  CCMSLIB00005884704      0.185359       4-AMINOBUTANOATE - 70.0 eV       103.1
#  ...                          ...                              ...         ...
#  CCMSLIB00000426167    -0.0189318        L-Alpha-aminobutyric acid     103.064
#  CCMSLIB00000426804    -0.0218313        D-Alpha-aminobutyric acid     103.064
#  CCMSLIB00006363395    -0.0222089                     Malonic acid     104.013
#  CCMSLIB00006362214    -0.0225595                     Malonic acid     104.013
#  CCMSLIB00006362442    -0.0226684                     Malonic acid     104.013
#
#                                    smiles
#  matches of spectrum-1
#  CCMSLIB00005467680
#  CCMSLIB00000221546        C[N+](C)(C)CCO
#  CCMSLIB00000223229       OCC[N+1](C)(C)C
#  CCMSLIB00005756167        C[N+](C)(C)CCO
#  CCMSLIB00005884704            NCCCC(O)=O
#  ...                                  ...
#  CCMSLIB00000426167      CC[C@H](N)C(O)=O
#  CCMSLIB00000426804     CC[C@@H](N)C(O)=O
#  CCMSLIB00006363395         O=C(O)CC(=O)O
#  CCMSLIB00006362214         O=C(O)CC(=O)O
#  CCMSLIB00006362442         O=C(O)CC(=O)O
#
#  [150 rows x 4 columns],
#                              score                       compound_name  \
#  matches of spectrum-10
#  CCMSLIB00000568959       0.220546  N-Isopropyl-2-methyl-2-propanamine
#  CCMSLIB00005729998       0.220546  N-Isopropyl-2-methyl-2-propanamine
#  CCMSLIB00005734881       0.218784                 1-nitrosopiperazine
#  CCMSLIB00000568061       0.218784          N-Nitrosopiperazine (NPAZ)
#  CCMSLIB00000567665       0.218216          N-Nitrosopiperazine (NPAZ)
#  ...                           ...                                 ...
#  CCMSLIB00006355730      0.0845669                        Fumaric acid
#  CCMSLIB00000221776      0.0845531       pyrrolidine-2-carboxylic acid
#  CCMSLIB00006356648      0.0844396                        Fumaric acid
#  CCMSLIB00006356471      0.0844373                        Fumaric acid
#  CCMSLIB00000205942      0.0840001                             Proline
#
#                         parent_mass           smiles
#  matches of spectrum-10
#  CCMSLIB00000568959         115.136   CC(C)NC(C)(C)C
#  CCMSLIB00005729998         115.136   CC(C)NC(C)(C)C
#  CCMSLIB00005734881         115.075      O=NN1CCNCC1
#  CCMSLIB00000568061         115.075    C1CN(CCN1)N=O
#  CCMSLIB00000567665         115.075    C1CN(CCN1)N=O
#  ...                            ...              ...
#  CCMSLIB00006355730         116.013  O=C(O)C=CC(=O)O
#  CCMSLIB00000221776         115.064  C1CC(NC1)C(=O)O
#  CCMSLIB00006356648         116.013  O=C(O)C=CC(=O)O
#  CCMSLIB00006356471         116.013  O=C(O)C=CC(=O)O
#  CCMSLIB00000205942         115.064  C1CC(NC1)C(=O)O
#
#  [150 rows x 4 columns],
#                              score                    compound_name  \
#  matches of spectrum-11
#  CCMSLIB00005884643       0.138769      5-AMINOPENTANOATE - 40.0 eV
#  CCMSLIB00000425588       0.128474                    Acetylglycine
#  CCMSLIB00005463927       0.126916                5-AMINOPENTANOATE
#  CCMSLIB00005763963       0.119651                   butan-2-ylurea
#  CCMSLIB00005762996       0.119441                   butan-2-ylurea
#  ...                           ...                              ...
#  CCMSLIB00005757890      0.0388907                    Maleinic acid
#  CCMSLIB00000219823      0.0388457  (Z)-1,2-Ethenedicarboxylic Acid
#  CCMSLIB00005733493      0.0386923              4-nitrosomorpholine
#  CCMSLIB00000570097      0.0386409              N-Nitrosomorpholine
#  CCMSLIB00005730831      0.0386409              4-nitrosomorpholine
#
#                         parent_mass             smiles
#  matches of spectrum-11
#  CCMSLIB00005884643         117.079        NCCCCC(O)=O
#  CCMSLIB00000425588         117.043     CC(=O)NCC(O)=O
#  CCMSLIB00005463927         117.079        NCCCCC(O)=O
#  CCMSLIB00005763963         116.095      CCC(C)NC(N)=O
#  CCMSLIB00005762996         116.095      CCC(C)NC(N)=O
#  ...                            ...                ...
#  CCMSLIB00005757890         116.063  C(=CC(=O)O)C(=O)O
#  CCMSLIB00000219823         116.063  C(=CC(=O)O)C(=O)O
#  CCMSLIB00005733493         116.059        O=NN1CCOCC1
#  CCMSLIB00000570097         116.059        C1COCCN1N=O
#  CCMSLIB00005730831         116.059        O=NN1CCOCC1
#
#  [150 rows x 4 columns],
#                              score                           compound_name  \
#  matches of spectrum-12
#  CCMSLIB00005720364       0.223286                        GUANIDINOACETATE
#  CCMSLIB00000223232       0.203781                             Glykocyamin
#  CCMSLIB00005759854       0.203781                             Betasyamine
#  CCMSLIB00000221552       0.203734  2-(diaminomethylideneamino)acetic acid
#  CCMSLIB00000577918       0.177479                        GUANIDINOACETATE
#  ...                           ...                                     ...
#  CCMSLIB00005884090      0.0244806                   L-NORVALINE - 30.0 eV
#  CCMSLIB00000221031      0.0243805                                L-Valine
#  CCMSLIB00000564937      0.0234348                     N-Nitrosomorpholine
#  CCMSLIB00005726311      0.0234348                     4-Nitrosomorpholine
#  CCMSLIB00000205891      0.0234263                                  Valine
#
#                         parent_mass               smiles
#  matches of spectrum-12
#  CCMSLIB00005720364         117.055     C(C(=O)O)N=C(N)N
#  CCMSLIB00000223232         117.055       NC(=N)NCC(O)=O
#  CCMSLIB00005759854         117.055     C(C(=O)O)N=C(N)N
#  CCMSLIB00000221552         117.055     C(C(=O)O)N=C(N)N
#  CCMSLIB00000577918         117.053     C(C(=O)O)N=C(N)N
#  ...                            ...                  ...
#  CCMSLIB00005884090         117.079   CCC[C@@H](N)C(O)=O
#  CCMSLIB00000221031         116.993  CC(C)[C@H](N)C(O)=O
#  CCMSLIB00000564937         116.059          C1COCCN1N=O
#  CCMSLIB00005726311         116.059          O=NN1CCOCC1
#  CCMSLIB00000205891         117.079      CC(C)C(C(=O)O)N
#
#  [150 rows x 4 columns],
#                              score                 compound_name parent_mass  \
#  matches of spectrum-13
#  CCMSLIB00005720355        0.25587                        VALINE      117.08
#  CCMSLIB00005884646       0.255376   5-AMINOPENTANOATE - 70.0 eV     117.079
#  CCMSLIB00005720467       0.245071             5-AMINOPENTANOATE      117.08
#  CCMSLIB00005884645       0.243338   5-AMINOPENTANOATE - 60.0 eV     117.079
#  CCMSLIB00005463927       0.241104             5-AMINOPENTANOATE     117.079
#  ...                           ...                           ...         ...
#  CCMSLIB00005885070      0.0702939             Valine - 50.00 eV     117.079
#  CCMSLIB00000205890      0.0701517                        Valine     117.079
#  CCMSLIB00005759587      0.0692024                   Betasyamine     117.073
#  CCMSLIB00000219388      0.0691825                   Glykocyamin     117.073
#  CCMSLIB00000217472      0.0677656  2-(Acetylamino)ethanoic Acid     117.083
#
#                                        smiles
#  matches of spectrum-13
#  CCMSLIB00005720355      CC(C)[C@@H](C(=O)O)N
#  CCMSLIB00005884646               NCCCCC(O)=O
#  CCMSLIB00005720467             C(CCN)CC(=O)O
#  CCMSLIB00005884645               NCCCCC(O)=O
#  CCMSLIB00005463927               NCCCCC(O)=O
#  ...                                      ...
#  CCMSLIB00005885070       CC(C)[C@H](N)C(O)=O
#  CCMSLIB00000205890           CC(C)C(C(=O)O)N
#  CCMSLIB00005759587          C(C(=O)O)N=C(N)N
#  CCMSLIB00000219388          C(C(=O)O)N=C(N)N
#  CCMSLIB00000217472            CC(=O)NCC(=O)O
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-14
#  CCMSLIB00005720355       0.272289
#  CCMSLIB00005720467       0.267781
#  CCMSLIB00006673898       0.251528
#  CCMSLIB00005884646       0.232133
#  CCMSLIB00005884645       0.229918
#  ...                           ...
#  CCMSLIB00005788030      0.0898256
#  CCMSLIB00000216253      0.0896775
#  CCMSLIB00005884428      0.0894567
#  CCMSLIB00000205881      0.0882763
#  CCMSLIB00000205887      0.0880308
#
#                                                           compound_name  \
#  matches of spectrum-14
#  CCMSLIB00005720355                                              VALINE
#  CCMSLIB00005720467                                   5-AMINOPENTANOATE
#  CCMSLIB00006673898                                      acetyl_glycine
#  CCMSLIB00005884646                         5-AMINOPENTANOATE - 70.0 eV
#  CCMSLIB00005884645                         5-AMINOPENTANOATE - 60.0 eV
#  ...                                                                ...
#  CCMSLIB00005788030                                              Valine
#  CCMSLIB00000216253      KNA00233 L-Valine|2-Amino-3-methylbutyric acid
#  CCMSLIB00005884428                L-HOMOCYSTEINE THIOLACTONE - 50.0 eV
#  CCMSLIB00000205881                                              Valine
#  CCMSLIB00000205887                                              Valine
#
#                         parent_mass                smiles
#  matches of spectrum-14
#  CCMSLIB00005720355          117.08  CC(C)[C@@H](C(=O)O)N
#  CCMSLIB00005720467          117.08         C(CCN)CC(=O)O
#  CCMSLIB00006673898         117.043        CC(=O)NCC(=O)O
#  CCMSLIB00005884646         117.079           NCCCCC(O)=O
#  CCMSLIB00005884645         117.079           NCCCCC(O)=O
#  ...                            ...                   ...
#  CCMSLIB00005788030         117.079  CC(C)[C@@H](C(=O)O)N
#  CCMSLIB00000216253         117.083   CC(C)[C@H](N)C(O)=O
#  CCMSLIB00005884428         117.025            NC1CCSC1=O
#  CCMSLIB00000205881         117.079       CC(C)C(C(=O)O)N
#  CCMSLIB00000205887         117.079       CC(C)C(C(=O)O)N
#
#  [150 rows x 4 columns],
#                              score                compound_name parent_mass  \
#  matches of spectrum-15
#  CCMSLIB00000217844       0.181028      2,4-Diaminobutyric acid     117.993
#  CCMSLIB00000426920        0.15732     3-Hydroxyisovaleric acid     118.064
#  CCMSLIB00005884643       0.137166  5-AMINOPENTANOATE - 40.0 eV     117.079
#  CCMSLIB00000425588       0.131729                Acetylglycine     117.043
#  CCMSLIB00000426948       0.118622     3-Hydroxyisovaleric acid     118.064
#  ...                           ...                          ...         ...
#  CCMSLIB00000217846      0.0141251      2,4-Diaminobutyric acid     117.993
#  CCMSLIB00005756346      0.0139707            5-Aminopentanoate     117.093
#  CCMSLIB00000217339      0.0139556         Homopiperidinic acid     117.093
#  CCMSLIB00000426509      0.0139152                       Indole     117.059
#  CCMSLIB00000217848      0.0127849      2,4-Diaminobutyric acid     117.993
#
#                                     smiles
#  matches of spectrum-15
#  CCMSLIB00000217844      NCC[C@H](N)C(O)=O
#  CCMSLIB00000426920        CC(C)(O)CC(O)=O
#  CCMSLIB00005884643            NCCCCC(O)=O
#  CCMSLIB00000425588         CC(=O)NCC(O)=O
#  CCMSLIB00000426948        CC(C)(O)CC(O)=O
#  ...                                   ...
#  CCMSLIB00000217846      NCC[C@H](N)C(O)=O
#  CCMSLIB00005756346          C(CCN)CC(=O)O
#  CCMSLIB00000217339          C(CCN)CC(=O)O
#  CCMSLIB00000426509      N1C=CC2=C1C=CC=C2
#  CCMSLIB00000217848      NCC[C@H](N)C(O)=O
#
#  [150 rows x 4 columns],
#                              score                           compound_name  \
#  matches of spectrum-16
#  CCMSLIB00000217844       0.190124                 2,4-Diaminobutyric acid
#  CCMSLIB00000208931       0.168226                             L-Threonine
#  CCMSLIB00000220723       0.163582                         L-Allothreonine
#  CCMSLIB00000426920       0.153631                3-Hydroxyisovaleric acid
#  CCMSLIB00000220725       0.150448                         L-Allothreonine
#  ...                           ...                                     ...
#  CCMSLIB00005884093      0.0452363                   L-NORVALINE - 60.0 eV
#  CCMSLIB00000578027      0.0442129                       5-AMINOPENTANOATE
#  CCMSLIB00005763493      0.0436346  N,N,N'-trimethylcarbamimidothioic acid
#  CCMSLIB00005883403      0.0434668                METHYLMALONATE - 50.0 eV
#  CCMSLIB00005883409      0.0434668                METHYLMALONATE - 50.0 eV
#
#                         parent_mass                    smiles
#  matches of spectrum-16
#  CCMSLIB00000217844         117.993         NCC[C@H](N)C(O)=O
#  CCMSLIB00000208931         118.993  C[C@H]([C@@H](C(=O)O)N)O
#  CCMSLIB00000220723         118.993  C[C@@H](O)[C@H](N)C(O)=O
#  CCMSLIB00000426920         118.064           CC(C)(O)CC(O)=O
#  CCMSLIB00000220725         118.993  C[C@@H](O)[C@H](N)C(O)=O
#  ...                            ...                       ...
#  CCMSLIB00005884093         117.079        CCC[C@@H](N)C(O)=O
#  CCMSLIB00000578027         117.083             C(CCN)CC(=O)O
#  CCMSLIB00005763493         118.057              CNC(=S)N(C)C
#  CCMSLIB00005883403         118.027          CC(C(O)=O)C(O)=O
#  CCMSLIB00005883409         118.027          CC(C(O)=O)C(O)=O
#
#  [150 rows x 4 columns],
#                                score                           compound_name  \
#  matches of spectrum-17
#  CCMSLIB00005738720         0.535406  (2R,3S)-2-azaniumyl-3-hydroxybutanoate
#  CCMSLIB00000221290         0.494019     (2S)-2-amino-4-hydroxybutanoic acid
#  CCMSLIB00000223120         0.493929          2-Amino-4-hydroxybutanoic acid
#  CCMSLIB00005759348         0.493929     (2S)-2-amino-4-hydroxybutanoic acid
#  CCMSLIB00005738353         0.492891  (2R,3S)-2-azaniumyl-3-hydroxybutanoate
#  ...                             ...                                     ...
#  CCMSLIB00005463960       0.00548873                            ANTHRANILATE
#  CCMSLIB00005726732       0.00543121                        2H-Benzotriazole
#  CCMSLIB00000220726       0.00331777                         L-Allothreonine
#  CCMSLIB00003135628       0.00090353                  Benzoic acid, 3-amino-
#  CCMSLIB00000207185      5.25441e-05                        1H-Benzotriazole
#
#                         parent_mass                    smiles
#  matches of spectrum-17
#  CCMSLIB00005738720         119.058  C[C@@H]([C@H](C(=O)O)N)O
#  CCMSLIB00000221290         119.059           C(CO)C(C(=O)O)N
#  CCMSLIB00000223120         119.059         OCC[C@H](N)C(O)=O
#  CCMSLIB00005759348         119.059           C(CO)C(C(=O)O)N
#  CCMSLIB00005738353         119.058  C[C@@H]([C@H](C(=O)O)N)O
#  ...                            ...                       ...
#  CCMSLIB00005463960         119.037        NC1=CC=CC=C1C(O)=O
#  CCMSLIB00005726732         119.049         N1N=NC2=CC=CC=C12
#  CCMSLIB00000220726         118.993  C[C@@H](O)[C@H](N)C(O)=O
#  CCMSLIB00003135628         119.038    C1=CC(=CC(=C1)N)C(=O)O
#  CCMSLIB00000207185         119.049        c12c(nn[nH]1)cccc2
#
#  [150 rows x 4 columns],
#                              score                      compound_name  \
#  matches of spectrum-18
#  CCMSLIB00006675479       0.136988                            tyrosol
#  CCMSLIB00000217235       0.129297                       Tromethamine
#  CCMSLIB00005758197       0.129117  (R)-3-Amino-4-hydroxybutyric acid
#  CCMSLIB00000216503       0.128979  (R)-3-Amino-4-hydroxybutyric acid
#  CCMSLIB00005756952       0.128364                        L-Threonine
#  ...                           ...                                ...
#  CCMSLIB00000217358     -0.0263945                        Benzamidine
#  CCMSLIB00005772964     -0.0273946             benzenecarboximidamide
#  CCMSLIB00000220116     -0.0274274                   Phenylethylamine
#  CCMSLIB00000574466     -0.0282062                  Purine nucleoside
#  CCMSLIB00005773622     -0.0304376             benzenecarboximidamide
#
#                         parent_mass  \
#  matches of spectrum-18
#  CCMSLIB00006675479         120.057
#  CCMSLIB00000217235         120.993
#  CCMSLIB00005758197         119.103
#  CCMSLIB00000216503         119.103
#  CCMSLIB00005756952         119.073
#  ...                            ...
#  CCMSLIB00000217358         119.993
#  CCMSLIB00005772964         120.069
#  CCMSLIB00000220116         120.993
#  CCMSLIB00000574466         119.993
#  CCMSLIB00005773622         120.069
#
#                                                                            smiles
#  matches of spectrum-18
#  CCMSLIB00006675479                                             C1=CC(=CC=C1CCO)O
#  CCMSLIB00000217235                                                  OCC(N)(CO)CO
#  CCMSLIB00005758197                                               C(C(CO)N)C(=O)O
#  CCMSLIB00000216503                                               C(C(CO)N)C(=O)O
#  CCMSLIB00005756952                                               CC(C(C(=O)O)N)O
#  ...                                                                          ...
#  CCMSLIB00000217358                                              NC(=N)c(c1)cccc1
#  CCMSLIB00005772964                                              c1ccc(cc1)C(=N)N
#  CCMSLIB00000220116                                                 NCCc(c1)cccc1
#  CCMSLIB00000574466      C1=C2C(=NC=N1)N(C=N2)[C@H]3[C@@H]([C@@H]([C@H](O3)CO)O)O
#  CCMSLIB00005773622                                              c1ccc(cc1)C(=N)N
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-19
#  CCMSLIB00000216383       0.165518
#  CCMSLIB00000208933       0.142406
#  CCMSLIB00000219696       0.115356
#  CCMSLIB00000220002       0.114885
#  CCMSLIB00000220262       0.111665
#  ...                           ...
#  CCMSLIB00004721246      0.0483918
#  CCMSLIB00006359692      0.0478434
#  CCMSLIB00000218989       0.047738
#  CCMSLIB00003137568      0.0477252
#  CCMSLIB00005738107      0.0473587
#
#                                                                compound_name  \
#  matches of spectrum-19
#  CCMSLIB00000216383      KNA00342 L-Homoserine|2-Amino-4-hydroxybutyric acid
#  CCMSLIB00000208933                                               L-Cysteine
#  CCMSLIB00000219696                                              Niacinamide
#  CCMSLIB00000220002                                       2-Phenylethylamine
#  CCMSLIB00000220262                                             Picolinamide
#  ...                                                                     ...
#  CCMSLIB00004721246                                              NIACINAMIDE
#  CCMSLIB00006359692                                             Benzoic acid
#  CCMSLIB00000218989                                         Isonicotineamide
#  CCMSLIB00003137568                                              Niacinamide
#  CCMSLIB00005738107                                   pyridine-3-carboxamide
#
#                         parent_mass               smiles
#  matches of spectrum-19
#  CCMSLIB00000216383         120.063    OCC[C@H](N)C(O)=O
#  CCMSLIB00000208933         120.993  C([C@@H](C(=O)O)N)S
#  CCMSLIB00000219696         121.993     NC(=O)c(c1)cncc1
#  CCMSLIB00000220002         120.993        NCCc(c1)cccc1
#  CCMSLIB00000220262         121.993     NC(=O)c(c1)nccc1
#  ...                            ...                  ...
#  CCMSLIB00004721246         122.048       N=C(O)c1cccnc1
#  CCMSLIB00006359692         122.033    O=C(O)C=1C=CC=CC1
#  CCMSLIB00000218989         121.993     NC(=O)c(c1)ccnc1
#  CCMSLIB00003137568         122.048  C1=CC(=CN=C1)C(=O)N
#  CCMSLIB00005738107         122.048     c1cc(cnc1)C(=O)N
#
#  [150 rows x 4 columns],
#                             score                     compound_name  \
#  matches of spectrum-2
#  CCMSLIB00000220793      0.190876  2-hydroxy-2-methylpropanoic acid
#  CCMSLIB00000222878      0.190644                     Acetonic Acid
#  CCMSLIB00005759301      0.190644  2-Hydroxy-2-methylpropionic acid
#  CCMSLIB00006551853      0.180075                      Malonic acid
#  CCMSLIB00006552075      0.158722                      Malonic acid
#  ...                          ...                               ...
#  CCMSLIB00000219104     0.0185082       2,3-Dihydroxypropanoic acid
#  CCMSLIB00000217834     0.0164114      DL-2,3-Diaminopropionic acid
#  CCMSLIB00006363395     0.0162564                      Malonic acid
#  CCMSLIB00006363350     0.0154248                      Malonic acid
#  CCMSLIB00005759277     0.0144177          DL-2,3-Diaminopropionate
#
#                        parent_mass          smiles
#  matches of spectrum-2
#  CCMSLIB00000220793        104.048  CC(C)(C(=O)O)O
#  CCMSLIB00000222878        104.048  OC(=O)C(C)(C)O
#  CCMSLIB00005759301        104.048  CC(C)(C(=O)O)O
#  CCMSLIB00006551853        104.013   O=C(O)CC(=O)O
#  CCMSLIB00006552075        104.013   O=C(O)CC(=O)O
#  ...                           ...             ...
#  CCMSLIB00000219104        104.023  C(C(C(=O)O)O)O
#  CCMSLIB00000217834        103.993    NCC(N)C(O)=O
#  CCMSLIB00006363395        104.013   O=C(O)CC(=O)O
#  CCMSLIB00006363350        104.013   O=C(O)CC(=O)O
#  CCMSLIB00005759277        104.073  C(C(C(=O)O)N)N
#
#  [150 rows x 4 columns],
#                              score             compound_name parent_mass  \
#  matches of spectrum-20
#  CCMSLIB00005884100       0.835736  PICOLINIC ACID - 70.0 eV     123.032
#  CCMSLIB00005884099       0.759948  PICOLINIC ACID - 60.0 eV     123.032
#  CCMSLIB00005884098       0.671163  PICOLINIC ACID - 50.0 eV     123.032
#  CCMSLIB00005778040        0.54662   FIO00682 Picolinic acid     123.032
#  CCMSLIB00005884096       0.537755  PICOLINIC ACID - 30.0 eV     123.032
#  ...                           ...                       ...         ...
#  CCMSLIB00006356479      0.0344403           Isovaleric acid     102.071
#  CCMSLIB00006356409      0.0343333           Isovaleric acid     102.071
#  CCMSLIB00006357979      0.0340974           Isovaleric acid     102.071
#  CCMSLIB00006354642      0.0339357           Isovaleric acid     102.071
#  CCMSLIB00006357432      0.0339103           Isovaleric acid     102.071
#
#                                     smiles
#  matches of spectrum-20
#  CCMSLIB00005884100      OC(=O)C1=CC=CC=N1
#  CCMSLIB00005884099      OC(=O)C1=CC=CC=N1
#  CCMSLIB00005884098      OC(=O)C1=CC=CC=N1
#  CCMSLIB00005778040       OC(=O)c(c1)nccc1
#  CCMSLIB00005884096      OC(=O)C1=CC=CC=N1
#  ...                                   ...
#  CCMSLIB00006356479           O=C(O)CC(C)C
#  CCMSLIB00006356409           O=C(O)CC(C)C
#  CCMSLIB00006357979           O=C(O)CC(C)C
#  CCMSLIB00006354642           O=C(O)CC(C)C
#  CCMSLIB00006357432           O=C(O)CC(C)C
#
#  [150 rows x 4 columns],
#                              score                  compound_name parent_mass  \
#  matches of spectrum-21
#  CCMSLIB00006455275       0.111922                         Maltol     126.032
#  CCMSLIB00006454983       0.101801                         Maltol     126.032
#  CCMSLIB00006455455        0.10128                         Maltol     126.032
#  CCMSLIB00000221936       0.100345                                    127.028
#  CCMSLIB00000841641      0.0803786                4-Chloroaniline     127.019
#  ...                           ...                            ...         ...
#  CCMSLIB00006363622     -0.0758699                   Malonic acid     104.011
#  CCMSLIB00006363487     -0.0760633                   Malonic acid     104.011
#  CCMSLIB00005755221     -0.0761995              TUE00491 Melamine     126.066
#  CCMSLIB00006363396     -0.0762942                   Malonic acid     104.011
#  CCMSLIB00006673102     -0.0771149  2_3_dimethyl_maleic_anhydride     126.032
#
#                                      smiles
#  matches of spectrum-21
#  CCMSLIB00006455275        O=C1C=COC(=C1O)C
#  CCMSLIB00006454983        O=C1C=COC(=C1O)C
#  CCMSLIB00006455455        O=C1C=COC(=C1O)C
#  CCMSLIB00000221936       C1CC(=O)NC1C(=O)O
#  CCMSLIB00000841641        NC1=CC=C(Cl)C=C1
#  ...                                    ...
#  CCMSLIB00006363622           O=C(O)CC(=O)O
#  CCMSLIB00006363487           O=C(O)CC(=O)O
#  CCMSLIB00005755221       c1(nc(nc(n1)N)N)N
#  CCMSLIB00006363396           O=C(O)CC(=O)O
#  CCMSLIB00006673102      CC1=C(C(=O)OC1=O)C
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-22
#  CCMSLIB00003134508       0.332247
#  CCMSLIB00006674362       0.151283
#  CCMSLIB00000427130       0.136222
#  CCMSLIB00000216064       0.134502
#  CCMSLIB00006674361       0.129619
#  ...                           ...
#  CCMSLIB00005770117      0.0140831
#  CCMSLIB00005769853      0.0140831
#  CCMSLIB00005767512      0.0140831
#  CCMSLIB00000220015       0.012691
#  CCMSLIB00000220421      0.0122623
#
#                                                          compound_name  \
#  matches of spectrum-22
#  CCMSLIB00003134508                                        Adipic acid
#  CCMSLIB00006674362                                           furaneol
#  CCMSLIB00000427130                         Pyrrolidonecarboxylic acid
#  CCMSLIB00000216064      KNA00066 L-Glutamine|L-2-Aminoglutaramic acid
#  CCMSLIB00006674361                                           furaneol
#  ...                                                               ...
#  CCMSLIB00005770117                                            Coniine
#  CCMSLIB00005769853                                            Coniine
#  CCMSLIB00005767512                                            Coniine
#  CCMSLIB00000220015                                  DL-Pipecolic acid
#  CCMSLIB00000220421                                          Quinoline
#
#                         parent_mass                  smiles
#  matches of spectrum-22
#  CCMSLIB00003134508         128.047      C(CCC(=O)O)CC(=O)O
#  CCMSLIB00006674362         128.048     CC1C(=O)C(=C(O1)C)O
#  CCMSLIB00000427130         129.043       OC(=O)C1CCC(=O)N1
#  CCMSLIB00000216064         129.043  NC(=O)CC[C@H](N)C(O)=O
#  CCMSLIB00006674361         128.048     CC1C(=O)C(=C(O1)C)O
#  ...                            ...                     ...
#  CCMSLIB00005770117         127.136         CCC[C@H]1CCCCN1
#  CCMSLIB00005769853         127.136         CCC[C@H]1CCCCN1
#  CCMSLIB00005767512         127.136         CCC[C@H]1CCCCN1
#  CCMSLIB00000220015         128.993   OC(=O)C([H])(C1)NCCC1
#  CCMSLIB00000220421         128.993    c(c2)cc(c1)c(c2)ncc1
#
#  [150 rows x 4 columns],
#                              score                        compound_name  \
#  matches of spectrum-23
#  CCMSLIB00000427002        0.57992                       Pipecolic acid
#  CCMSLIB00005733680       0.519157  6-amino-5-fluoro-1H-pyrimidin-2-one
#  CCMSLIB00000566792       0.519157                              ancobon
#  CCMSLIB00000565862       0.519157                          flucytosine
#  CCMSLIB00000566793       0.517132                              ancobon
#  ...                           ...                                  ...
#  CCMSLIB00005760998      0.0131986   1-(2-Hydroxyethyl)pyrrolidin-2-one
#  CCMSLIB00005735956      0.0131474              4-Amino-5-hexenoic acid
#  CCMSLIB00000219816      0.0127337
#  CCMSLIB00005755773      0.0127262
#  CCMSLIB00005775056      0.0122961  6-amino-5-fluoro-1H-pyrimidin-2-one
#
#                         parent_mass               smiles
#  matches of spectrum-23
#  CCMSLIB00000427002          129.08       OC(=O)C1CCCCN1
#  CCMSLIB00005733680         129.034  FC=1\C=N/C(=O)NC=1N
#  CCMSLIB00000566792         129.034   C1=NC(=O)NC(=C1F)N
#  CCMSLIB00000565862         129.034   C1=NC(=O)NC(=C1F)N
#  CCMSLIB00000566793         129.034   C1=NC(=O)NC(=C1F)N
#  ...                            ...                  ...
#  CCMSLIB00005760998         129.079         OCCN1CCCC1=O
#  CCMSLIB00005735956         129.079      C=CC(CCC(=O)O)N
#  CCMSLIB00000219816         129.133     C1CCNC(C1)C(=O)O
#  CCMSLIB00005755773         129.133     C1CCNC(C1)C(=O)O
#  CCMSLIB00005775056         129.034  FC=1\C=N/C(=O)NC=1N
#
#  [150 rows x 4 columns],
#                              score                     compound_name  \
#  matches of spectrum-24
#  CCMSLIB00006673380       0.240954            3_hydroxymethyl_indole
#  CCMSLIB00006673376       0.213034            3_hydroxymethyl_indole
#  CCMSLIB00000425752       0.212347  Pyrroline hydroxycarboxylic acid
#  CCMSLIB00000425583       0.212347        Pyrrolidonecarboxylic acid
#  CCMSLIB00000220020       0.158661                 DL-Pipecolic acid
#  ...                           ...                               ...
#  CCMSLIB00000219817      0.0343561                      5-Oxoproline
#  CCMSLIB00000222498      0.0337659          2-methylbutanedioic acid
#  CCMSLIB00000222500      0.0334901          2-methylbutanedioic acid
#  CCMSLIB00000221930      0.0319115         (2S)-2-aminohexanoic acid
#  CCMSLIB00000219270      0.0310516                         Metformin
#
#                         parent_mass                   smiles
#  matches of spectrum-24
#  CCMSLIB00006673380         129.058  C1=CC=C2C(=C1)C(=CN2)CO
#  CCMSLIB00006673376         129.058  C1=CC=C2C(=C1)C(=CN2)CO
#  CCMSLIB00000425752         129.043        OC1CC(N=C1)C(O)=O
#  CCMSLIB00000425583         129.043        OC(=O)C1CCC(=O)N1
#  CCMSLIB00000220020         128.993    OC(=O)C([H])(C1)NCCC1
#  ...                            ...                      ...
#  CCMSLIB00000219817         128.993      O=C(C1)NC(C1)C(O)=O
#  CCMSLIB00000222498         130.027        CC(CC(=O)O)C(=O)O
#  CCMSLIB00000222500         130.027        CC(CC(=O)O)C(=O)O
#  CCMSLIB00000221930          129.08           CCCCC(C(=O)O)N
#  CCMSLIB00000219270         128.993        NC(=N)NC(=N)N(C)C
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-25
#  CCMSLIB00005758927       0.837371
#  CCMSLIB00000223036       0.837371
#  CCMSLIB00000221106        0.83728
#  CCMSLIB00005884688       0.819966
#  CCMSLIB00005884040       0.816782
#  ...                           ...
#  CCMSLIB00000214999      0.0158466
#  CCMSLIB00005757876      0.0158442
#  CCMSLIB00005884216      0.0156345
#  CCMSLIB00005884218      0.0147792
#  CCMSLIB00000213567      0.0147695
#
#                                                           compound_name  \
#  matches of spectrum-25
#  CCMSLIB00005758927                                           Oxaceprol
#  CCMSLIB00000223036                                           Oxaceprol
#  CCMSLIB00000221106      (2S,4R)-4-hydroxypyrrolidine-2-carboxylic acid
#  CCMSLIB00005884688                   CIS-4-HYDROXY-D-PROLINE - 70.0 eV
#  CCMSLIB00005884040                    TRANS-4-HYDROXYPROLINE - 70.0 eV
#  ...                                                                ...
#  CCMSLIB00000214999                        N-(Aminomethyl)-beta-alanine
#  CCMSLIB00005757876                        beta-Guanidinopropionic acid
#  CCMSLIB00005884216                             MEVALOLACTONE - 30.0 eV
#  CCMSLIB00005884218                             MEVALOLACTONE - 50.0 eV
#  CCMSLIB00000213567                      (R)-(+)-2-Hydroxysuccinic acid
#
#                         parent_mass                        smiles
#  matches of spectrum-25
#  CCMSLIB00005758927         131.059              C1C(CNC1C(=O)O)O
#  CCMSLIB00000223036         131.059  [H]C(O)(C1)CC([H])(N1)C(O)=O
#  CCMSLIB00000221106         131.059              C1C(CNC1C(=O)O)O
#  CCMSLIB00005884688         131.059      O[C@H]1CN[C@H](C1)C(O)=O
#  CCMSLIB00005884040         131.059     O[C@H]1CN[C@@H](C1)C(O)=O
#  ...                            ...                           ...
#  CCMSLIB00000214999         131.113             C(CN=C(N)N)C(=O)O
#  CCMSLIB00005757876         131.113             C(CN=C(N)N)C(=O)O
#  CCMSLIB00005884216         130.063           C[C@]1(O)CCOC(=O)C1
#  CCMSLIB00005884218         130.063           C[C@]1(O)CCOC(=O)C1
#  CCMSLIB00000213567         132.053           C(C(C(=O)O)O)C(=O)O
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-26
#  CCMSLIB00000427232       0.197162
#  CCMSLIB00000425824       0.194334
#  CCMSLIB00005759288       0.185889
#  CCMSLIB00000223117       0.185889
#  CCMSLIB00000221282       0.185837
#  ...                           ...
#  CCMSLIB00005757685      0.0752286
#  CCMSLIB00000216037      0.0750471
#  CCMSLIB00000218741      0.0748665
#  CCMSLIB00000426858      0.0746616
#  CCMSLIB00000216796      0.0743214
#
#                                                          compound_name  \
#  matches of spectrum-26
#  CCMSLIB00000427232                                           Creatine
#  CCMSLIB00000425824                                 N-Acetyl-L-alanine
#  CCMSLIB00005759288                              L-beta-homovaline-HCl
#  CCMSLIB00000223117                   (R)-3-Amino-4-methylvaleric acid
#  CCMSLIB00000221282                (3R)-3-amino-4-methylpentanoic acid
#  ...                                                               ...
#  CCMSLIB00005757685                                     Glycyl-glycine
#  CCMSLIB00000216037      KNA00040 4-Hydroxy-L-proline|L-Hydroxyproline
#  CCMSLIB00000218741                            cis-4-Hydroxy-D-proline
#  CCMSLIB00000426858                                   Propionylglycine
#  CCMSLIB00000216796             N-(4-Aminobutyl)guanidine sulfate salt
#
#                         parent_mass                        smiles
#  matches of spectrum-26
#  CCMSLIB00000427232          131.07             CN(CC(O)=O)C(N)=N
#  CCMSLIB00000425824         131.059         C[C@H](NC(C)=O)C(O)=O
#  CCMSLIB00005759288         131.095              CC(C)C(CC(=O)O)N
#  CCMSLIB00000223117         131.095         CC(C)[C@@H](N)CC(O)=O
#  CCMSLIB00000221282         131.095              CC(C)C(CC(=O)O)N
#  ...                            ...                           ...
#  CCMSLIB00005757685         131.993               NCC(O)=NCC(=O)O
#  CCMSLIB00000216037         131.063            OC(C1)CC(N1)C(O)=O
#  CCMSLIB00000218741         130.993  O[C@@H](C1)C[C@@H](N1)C(O)=O
#  CCMSLIB00000426858         131.059               CCC(=O)NCC(O)=O
#  CCMSLIB00000216796         130.113                C(CCN=C(N)N)CN
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-27
#  CCMSLIB00006581625       0.361689
#  CCMSLIB00005720449       0.248542
#  CCMSLIB00005489318       0.221986
#  CCMSLIB00000216433       0.183188
#  CCMSLIB00004716312       0.173404
#  ...                           ...
#  CCMSLIB00006673412      0.0482135
#  CCMSLIB00006581634      0.0481652
#  CCMSLIB00006673407      0.0475455
#  CCMSLIB00000425824      0.0475112
#  CCMSLIB00005720610      0.0472512
#
#                                                                                     compound_name  \
#  matches of spectrum-27
#  CCMSLIB00006581625                                                                      creatine
#  CCMSLIB00005720449                                                            N-ACETYL-L-ALANINE
#  CCMSLIB00005489318      2-amino-4-methylsulfanylbutanoic acid [IIN-based on: CCMSLIB00000221761]
#  CCMSLIB00000216433        KNA00393 Creatine|alpha-Methylguanidino acetic acid|Methylglycocyamine
#  CCMSLIB00004716312                                                               Diallyl Sulfide
#  ...                                                                                          ...
#  CCMSLIB00006673412                                                               3_methyl_indole
#  CCMSLIB00006581634                                                                  L-asparagine
#  CCMSLIB00006673407                                                               3_methyl_indole
#  CCMSLIB00000425824                                                            N-Acetyl-L-alanine
#  CCMSLIB00005720610                                                                    ISOLEUCINE
#
#                         parent_mass                     smiles
#  matches of spectrum-27
#  CCMSLIB00006581625          131.07          CN(CC(O)=O)C(N)=N
#  CCMSLIB00005720449         131.059     C[C@@H](C(=O)O)NC(=O)C
#  CCMSLIB00005489318         132.025             CSCCC(C(=O)O)N
#  CCMSLIB00000216433         131.073          OC(=O)CN(C)C(N)=N
#  CCMSLIB00004716312          114.05                  C=CCSCC=C
#  ...                            ...                        ...
#  CCMSLIB00006673412         131.074         CC1=CNC2=CC=CC=C12
#  CCMSLIB00006581634         132.054     N[C@@H](CC(N)=O)C(O)=O
#  CCMSLIB00006673407         131.074         CC1=CNC2=CC=CC=C12
#  CCMSLIB00000425824         131.059      C[C@H](NC(C)=O)C(O)=O
#  CCMSLIB00005720610         131.095  CC[C@H](C)[C@@H](C(=O)O)N
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-28
#  CCMSLIB00000427232       0.177775
#  CCMSLIB00005489318       0.147839
#  CCMSLIB00004716314       0.136378
#  CCMSLIB00006673408       0.131181
#  CCMSLIB00005738237       0.130191
#  ...                           ...
#  CCMSLIB00005884127       0.065759
#  CCMSLIB00005738639      0.0656858
#  CCMSLIB00000216601      0.0656133
#  CCMSLIB00000216810      0.0654806
#  CCMSLIB00000425567      0.0650554
#
#                                                                                     compound_name  \
#  matches of spectrum-28
#  CCMSLIB00000427232                                                                      Creatine
#  CCMSLIB00005489318      2-amino-4-methylsulfanylbutanoic acid [IIN-based on: CCMSLIB00000221761]
#  CCMSLIB00004716314                                                               Diallyl Sulfide
#  CCMSLIB00006673408                                                               3_methyl_indole
#  CCMSLIB00005738237                                        (2S)-2-azaniumyl-3,3-dimethylbutanoate
#  ...                                                                                          ...
#  CCMSLIB00005884127                                                         D-ORNITHINE - 40.0 eV
#  CCMSLIB00005738639                                                     (2S)-2-azaniumylhexanoate
#  CCMSLIB00000216601                                                                  L-Asparagine
#  CCMSLIB00000216810                                                           6-Aminocaproic acid
#  CCMSLIB00000425567                                                              4-Hydroxyproline
#
#                         parent_mass                     smiles
#  matches of spectrum-28
#  CCMSLIB00000427232          131.07          CN(CC(O)=O)C(N)=N
#  CCMSLIB00005489318         132.025             CSCCC(C(=O)O)N
#  CCMSLIB00004716314          114.05                  C=CCSCC=C
#  CCMSLIB00006673408         131.074         CC1=CNC2=CC=CC=C12
#  CCMSLIB00005738237         131.095    CC(C)(C)[C@@H](C(=O)O)N
#  ...                            ...                        ...
#  CCMSLIB00005884127          132.09        NCCC[C@@H](N)C(O)=O
#  CCMSLIB00005738639         131.095        CCCC[C@@H](C(=O)O)N
#  CCMSLIB00000216601         131.993     NC(=O)C[C@@H](N)C(O)=O
#  CCMSLIB00000216810         130.993               NCCCCCC(O)=O
#  CCMSLIB00000425567         131.059  O[C@H]1CN[C@@H](C1)C(O)=O
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-29
#  CCMSLIB00005736254       0.166375
#  CCMSLIB00000568211       0.166375
#  CCMSLIB00006673408       0.157973
#  CCMSLIB00000426790       0.137674
#  CCMSLIB00000426576       0.134035
#  ...                           ...
#  CCMSLIB00005885086       0.043716
#  CCMSLIB00005720386      0.0432491
#  CCMSLIB00000216046      0.0430361
#  CCMSLIB00003139519      0.0428561
#  CCMSLIB00005724011      0.0424586
#
#                                                                      compound_name  \
#  matches of spectrum-29
#  CCMSLIB00005736254                                      N,N-dipropylnitrous amide
#  CCMSLIB00000568211                                       N,N-DIPROPYLNITROSOAMINE
#  CCMSLIB00006673408                                                3_methyl_indole
#  CCMSLIB00000426790                                            Methylsuccinic acid
#  CCMSLIB00000426576                                            Methylsuccinic acid
#  ...                                                                           ...
#  CCMSLIB00005885086                                           Ornithine - 30.00 eV
#  CCMSLIB00005720386                                         TRANS-4-HYDROXYPROLINE
#  CCMSLIB00000216046      KNA00051 L-Aspartate|L-Aspartic acid|2-Aminosuccinic acid
#  CCMSLIB00003139519                                             Hydrocinnamic acid
#  CCMSLIB00005724011                                                 Cinnamaldehyde
#
#                         parent_mass                     smiles
#  matches of spectrum-29
#  CCMSLIB00005736254         130.111               O=NN(CCC)CCC
#  CCMSLIB00000568211         130.111               CCCN(CCC)N=O
#  CCMSLIB00006673408         131.074         CC1=CNC2=CC=CC=C12
#  CCMSLIB00000426790         132.043          CC(CC(O)=O)C(O)=O
#  CCMSLIB00000426576         132.043          CC(CC(O)=O)C(O)=O
#  ...                            ...                        ...
#  CCMSLIB00005885086          132.09         NCCC[C@H](N)C(O)=O
#  CCMSLIB00005720386         131.059  C1[C@H](CN[C@@H]1C(=O)O)O
#  CCMSLIB00000216046         132.053          OC(=O)CC(N)C(O)=O
#  CCMSLIB00003139519         132.053      C1=CC=C(C=C1)CCC(=O)O
#  CCMSLIB00005724011         132.057      C1=CC=C(C=C1)/C=C/C=O
#
#  [150 rows x 4 columns],
#                            score  \
#  matches of spectrum-3
#  CCMSLIB00000216091     0.144915
#  CCMSLIB00005757034     0.144854
#  CCMSLIB00000425691     0.136826
#  CCMSLIB00000215999     0.115063
#  CCMSLIB00000220455     0.106922
#  ...                         ...
#  CCMSLIB00000205872    -0.134345
#  CCMSLIB00000205874    -0.134951
#  CCMSLIB00000578033    -0.145032
#  CCMSLIB00000205868    -0.146996
#  CCMSLIB00000205870    -0.147444
#
#                                                                                                                      compound_name  \
#  matches of spectrum-3
#  CCMSLIB00000216091                                                                                         3-Pyridinecarbonitrile
#  CCMSLIB00005757034                                                                                        Pyridine-3-carbonitrile
#  CCMSLIB00000425691                                                                                                        Choline
#  CCMSLIB00000215999     KNA00007 4-Aminobutanoate|4-Aminobutanoic acid|4-Aminobutyrate|4-Aminobutyric acid|gamma-Aminobutyric acid
#  CCMSLIB00000220455                                                                                            L-3-Hydroxy-alanine
#  ...                                                                                                                           ...
#  CCMSLIB00000205872                                                                                                         Serine
#  CCMSLIB00000205874                                                                                                         Serine
# ...
#  CCMSLIB00003129376                                                                                                                                                                                                                                                       PC(18:0/22:4)
#  CCMSLIB00006550595      (7S,9E,11S,12R,13S,14S,15S,16R,17S,18S,19E,21Z)-26-[benzyl(methyl)amino]-2,15,17-trihydroxy-11-methoxy-3,7,12,14,16,18,22-heptamethyl-6,23,27,29-tetraoxo-8,30-dioxa-24-azatetracyclo[23.3.1.1^{4,7}.0^{5,28}]triaconta-1,3,5(28),9,19,21,25-heptaen-13-yl ...
#  CCMSLIB00006546771      (3R,4S,5S,6R,7R,9R,11S,12R,13S,14R,E)-6-(((2S,3R,6R)-4-(dimethylamino)-3-hydroxy-6-methyltetrahydro-2H-pyran-2-yl)oxy)-14-ethyl-7,12,13-trihydroxy-4-(((2R,4R,5S,6S)-5-hydroxy-4-methoxy-4,6-dimethyltetrahydro-2H-pyran-2-yl)oxy)-10-(((2-methoxyethoxy)me...
#
#                         parent_mass  \
#  matches of spectrum-85
#  CCMSLIB00006551676         814.371
#  CCMSLIB00004704588         816.321
#  CCMSLIB00000214019         837.633
#  CCMSLIB00005755509         837.633
#  CCMSLIB00006463328         814.411
#  ...                            ...
#  CCMSLIB00006550613         814.371
#  CCMSLIB00006550882         814.371
#  CCMSLIB00003129376         836.618
#  CCMSLIB00006550595         814.371
#  CCMSLIB00006546771         836.523
#
#                                                                                                                                                                            smiles
#  matches of spectrum-85
#  CCMSLIB00006551676                                          O=C(OC1C(C)C(OC)C=COC2(OC3=C(C2=O)C=4C(=O)C(NC=5C=CC=CC5CC)=C(NC(=O)C(=CC=CC(C)C(O)C(C)C(O)C1C)C)C(=O)C4C(O)=C3C)C)C
#  CCMSLIB00004704588      CCC(C)C(=O)O[C@@H]1C[C@@]2(C)[C@H](c3ccoc3)OC(=O)CC23OC2(C)O[C@@]34[C@H](OC(C)=O)[C@@]3(O)C(OC(=O)C5(C)OC5C)C5(C)CC3(O)[C@@](C)([C@H]5CC(=O)OC)[C@@]14O2
#  CCMSLIB00000214019                                                         CC(C)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C2N=CN=C3N)O)OP(=O)(O)O)O
#  CCMSLIB00005755509                                                         CC(C)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C2N=CN=C3N)O)OP(=O)(O)O)O
#  CCMSLIB00006463328                                                  O=C(OC1C(OC(=O)C)C2(C)C(C(=O)C)CCC32OC43CCC5CC(OC6OC(C)C(OC7OC(C)C(O)C(OC)C7O)C(OC)C6)CCC5(C)C14)C=8C=CC=CC8
#  ...                                                                                                                                                                          ...
#  CCMSLIB00006550613                                        O=C(OC1C(C)C(OC)C=COC2(OC3=C(C2=O)C=4C(=O)C(=C(NC(=O)C(=CC=CC(C)C(O)C(C)C(O)C1C)C)C(=O)C4C(O)=C3C)N(C)CC=5C=CC=CC5)C)C
#  CCMSLIB00006550882                                        O=C(OC1C(C)C(OC)C=COC2(OC3=C(C2=O)C=4C(=O)C(=C(NC(=O)C(=CC=CC(C)C(O)C(C)C(O)C1C)C)C(=O)C4C(O)=C3C)N(C)CC=5C=CC=CC5)C)C
#  CCMSLIB00003129376
#  CCMSLIB00006550595                                        O=C(OC1C(C)C(OC)C=COC2(OC3=C(C2=O)C=4C(=O)C(=C(NC(=O)C(=CC=CC(C)C(O)C(C)C(O)C1C)C)C(=O)C4C(O)=C3C)N(C)CC=5C=CC=CC5)C)C
#  CCMSLIB00006546771                                                      O=C1OC(CC)C(O)(C)C(O)C(C(=NOCOCCOC)C(C)CC(O)(C)C(OC2OC(C)CC(N(C)C)C2O)C(C)C(OC3OC(C)C(O)C(OC)(C)C3)C1C)C
#
#  [150 rows x 4 columns],
#                              score  \
#  matches of spectrum-86
#  CCMSLIB00006422974       0.160017
#  CCMSLIB00006463328       0.148567
#  CCMSLIB00006490101       0.142492
#  CCMSLIB00006463210       0.136917
#  CCMSLIB00003121464       0.134731
#  ...                           ...
#  CCMSLIB00003096856      0.0320774
#  CCMSLIB00003133741      0.0317892
#  CCMSLIB00003102081      0.0314034
#  CCMSLIB00003121893      0.0312642
#  CCMSLIB00003132838      0.0311966
#
#                                                                                                                                                                                                                                                                                                                                           compound_name  \
#  matches of spectrum-86
#  CCMSLIB00006422974                                                                                                                                                                                                                                                                                                                     Tenacissoside I
#  CCMSLIB00006463328                                                                                                                                                                                                                                                                                                                     Tenacissoside I
#  CCMSLIB00006490101      (8R,9S,11S,11aS,12aR,13S)-7-(2-(((3S,5S,14S,17R)-5,14-dihydroxy-10-(methoxycarbonyl)-13-methyl-17-(5-oxo-2,5-dihydrofuran-3-yl)hexadecahydro-1H-cyclopenta[a]phenanthren-3-yl)oxy)-2-oxoethyl)-9-ethyl-8,13-dihydroxy-5-methyl-5,5a,6,7,8,9,10,11,11a,12-decahydro-6,10:11,12a-dimethanoindolo[3,2-b]quinolizin-7-ium chloride
#  CCMSLIB00006463210                                                                                                                                                                                                                                                                                                                     Tenacissoside I
#  CCMSLIB00003121464                                                                                                                                                                                                                                                                                                                       PC(18:0/22:4)
#  ...                                                                                                                                                                                                                                                                                                                                                ...
#  CCMSLIB00003096856                                                                                                                                                                                                                                                                                                                       PC(18:0/22:4)
#  CCMSLIB00003133741                                                                                                                                                                                                                                                                                                                       PC(18:0/22:4)
#  CCMSLIB00003102081                                                                                                                                                                                                                                                                                                                       PC(18:0/22:4)
#  CCMSLIB00003121893                                                                                                                                                                                                                                                                                                                       PC(18:0/22:4)
#  CCMSLIB00003132838                                                                                                                                                                                                                                                                                                                       PC(18:0/22:4)
#
#                         parent_mass  \
#  matches of spectrum-86
#  CCMSLIB00006422974         814.411
#  CCMSLIB00006463328         814.411
#  CCMSLIB00006490101         836.403
#  CCMSLIB00006463210         814.411
#  CCMSLIB00003121464         836.618
#  ...                            ...
#  CCMSLIB00003096856         836.618
#  CCMSLIB00003133741         836.618
#  CCMSLIB00003102081         836.618
#  CCMSLIB00003121893         836.618
#  CCMSLIB00003132838         836.618
#
#                                                                                                                                                smiles
#  matches of spectrum-86
#  CCMSLIB00006422974                      O=C(OC1C(OC(=O)C)C2(C)C(C(=O)C)CCC32OC43CCC5CC(OC6OC(C)C(OC7OC(C)C(O)C(OC)C7O)C(OC)C6)CCC5(C)C14)C=8C=CC=CC8
#  CCMSLIB00006463328                      O=C(OC1C(OC(=O)C)C2(C)C(C(=O)C)CCC32OC43CCC5CC(OC6OC(C)C(OC7OC(C)C(O)C(OC)C7O)C(OC)C6)CCC5(C)C14)C=8C=CC=CC8
#  CCMSLIB00006490101      [Cl-].O=C1OCC(=C1)C2CCC3(O)C4CCC5(O)CC(OC(=O)C[N+]67C(O)C(CC)C8CC7C9N(C=%10C=CC=CC%10C%119CC6C8C%11O)C)CCC5(C(=O)OC)C4CCC23C
#  CCMSLIB00006463210                      O=C(OC1C(OC(=O)C)C2(C)C(C(=O)C)CCC32OC43CCC5CC(OC6OC(C)C(OC7OC(C)C(O)C(OC)C7O)C(OC)C6)CCC5(C)C14)C=8C=CC=CC8
#  CCMSLIB00003121464
#  ...                                                                                                                                              ...
#  CCMSLIB00003096856
#  CCMSLIB00003133741
#  CCMSLIB00003102081
#  CCMSLIB00003121893
#  CCMSLIB00003132838
#
#  [150 rows x 4 columns],
#                             score  \
#  matches of spectrum-9
#  CCMSLIB00006396101      0.172331
#  CCMSLIB00006396141      0.156683
#  CCMSLIB00006554795      0.151817
#  CCMSLIB00004689181      0.141905
#  CCMSLIB00006565858      0.138919
#  ...                          ...
#  CCMSLIB00006515498     0.0693164
#  CCMSLIB00006552274     0.0691922
#  CCMSLIB00006548648     0.0684647
#  CCMSLIB00006478448     0.0684432
#  CCMSLIB00006548629     0.0683032
#
#                                                                                                                                                             compound_name  \
#  matches of spectrum-9
#  CCMSLIB00006396101                                                                                                                                             paxilline
#  CCMSLIB00006396141                                                                                                                                             paxilline
#  CCMSLIB00006554795                                                                                                                                          ursolic acid
#  CCMSLIB00004689181     6-[(3E,6E)-2,5-dihydroxy-4,6-dimethyl-7-(1,2,4-trimethyl-3,6-dioxabicyclo[3.1.0]hexan-4-yl)hepta-3,6-dien-2-yl]-4-methoxy-3,5-dimethylpyran-2-one
#  CCMSLIB00006565858                                                                                                                                             paxilline
#  ...                                                                                                                                                                  ...
#  CCMSLIB00006515498                                                                                                                      Dehydrolucidenic acid A, 20(21)-
#  CCMSLIB00006552274                                                                                                                                          ursolic acid
#  CCMSLIB00006548648                                                               2-(7,8-dimethoxy-4-methyl-2-oxo-2H-chromen-3-yl)-N-(1-isopropyl-1H-indol-4-yl)acetamide
#  CCMSLIB00006478448                                                                                                                       Naringenin-7-O-beta-D-glucoside
#  CCMSLIB00006548629                                                               2-(7,8-dimethoxy-4-methyl-2-oxo-2H-chromen-3-yl)-N-(1-isopropyl-1H-indol-4-yl)acetamide
#
#                        parent_mass  \
#  matches of spectrum-9
#  CCMSLIB00006396101        435.241
#  CCMSLIB00006396141        435.241
#  CCMSLIB00006554795        456.363
#  CCMSLIB00004689181        456.196
#  CCMSLIB00006565858        435.241
#  ...                           ...
#  CCMSLIB00006515498        456.253
#  CCMSLIB00006552274        456.363
#  CCMSLIB00006548648        434.181
#  CCMSLIB00006478448        434.121
#  CCMSLIB00006548629        434.181
#
#                                                                                      smiles
#  matches of spectrum-9
#  CCMSLIB00006396101            O=C1C=C2C(OC1C(O)(C)C)CCC3(C)C2(O)CCC4CC=5C=6C=CC=CC6NC5C43C
#  CCMSLIB00006396141            O=C1C=C2C(OC1C(O)(C)C)CCC3(C)C2(O)CCC4CC=5C=6C=CC=CC6NC5C43C
#  CCMSLIB00006554795         O=C(O)C12CCC(C)C(C)C2C3=CCC4C5(C)CCC(O)C(C)(C)C5CCC4(C)C3(C)CC1
#  CCMSLIB00004689181      COc1c(C)c(C(C)(O)/C=C(\C)C(O)/C(C)=C/C2(C)OC(C)C3(C)OC23)oc(=O)c1C
#  CCMSLIB00006565858            O=C1C=C2C(OC1C(O)(C)C)CCC3(C)C2(O)CCC4CC=5C=6C=CC=CC6NC5C43C
#  ...                                                                                    ...
#  CCMSLIB00006515498     O=C(O)CCC(=C)C1CC(=O)C2(C3=C(C(=O)CC12C)C4(C)CCC(=O)C(C)(C)C4CC3O)C
#  CCMSLIB00006552274         O=C(O)C12CCC(C)C(C)C2C3=CCC4C5(C)CCC(O)C(C)(C)C5CCC4(C)C3(C)CC1
#  CCMSLIB00006548648            O=C1OC=2C(OC)=C(OC)C=CC2C(=C1CC(=O)NC3=CC=CC4=C3C=CN4C(C)C)C
#  CCMSLIB00006478448            O=C1C2=C(O)C=C(OC3OC(CO)C(O)C(O)C3O)C=C2OC(C4=CC=C(O)C=C4)C1
#  CCMSLIB00006548629            O=C1OC=2C(OC)=C(OC)C=CC2C(=C1CC(=O)NC3=CC=CC4=C3C=CN4C(C)C)C
#
#  [150 rows x 4 columns]]

# %%
GNPS_Condensed = pd.read_json('GNPS_Condensed.json')
Annotation_Results = Create_Annotation_Results(spectra, spectra_matches,ion_mode='positive',cutoff_score=0.7,mass_error=20)
Manual_Annotations = pd.read_csv('Manual_Annotations.csv') #positive (extra column due to manual eval of data. )
Manual_Annotations.columns = ['PEPMASS','MN_Annotation',"Manual_ID",'Truth']

# %%
Comparison_Table = pd.merge(Annotation_Results.round(2),Manual_Annotations.round(2),how='inner')
# Comparison_Table.to_csv('S2V_20_ppm_vs_Manual_positive.csv') #option to save.

# %% [markdown]
# ## Streamlined negative mode implimentation

# %%
path_to_mgf = os.path.join("MSV000087012_Filtered.mgf")
spectra = list(matchms.importing.load_from_mgf(path_to_mgf))
spectra_matches = spec2vec.match_spectra_from_path(
    path_to_mgf, 
    n_best=100, 
    ion_mode="negative",
    include_metadata=["smiles", "compound_name",'parent_mass']
)
Annotation_Results = Create_Annotation_Results(spectra, spectra_matches,ion_mode='negative',cutoff_score=0.7,mass_error=10)
Manual_Annotations = pd.read_csv('Manual_Annotations_Negative_mode.csv') 
Manual_Annotations.columns = ['PEPMASS','MN_Annotation',"Manual_ID"]
Comparison_Table = pd.merge(Annotation_Results.round(2),Manual_Annotations.round(2),how='inner')

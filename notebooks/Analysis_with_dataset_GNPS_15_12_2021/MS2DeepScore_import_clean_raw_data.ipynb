# %% [markdown]
# # Import and clean large GNPS MS/MS dataset

# %% [markdown]
# ## Using matchms to harmonize, clean, and complete metadata
# Here we run matchms filters and additional custom filters to do extensive cleaning of a large spectral dataset (>210,000 spectra).
#
# This notebook will expect that you have ``spec2vec`` installed via conda, which (currently) automatically include ``matchms`` and ``rdkit`` as well.
# You can do this by creating an environment in anaconda and installing matchms via conda:
#
# ``conda create --name spec2vec_analysis python=3.8
# conda activate spec2vec_analysis
# conda install --channel nlesc --channel bioconda --channel conda-forge spec2vec``

# %%
import os
import numpy as np
from matchms.importing import load_from_mgf
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

ROOT = os.path.dirname(os.getcwd())
path_data = os.path.join(os.path.dirname(ROOT), "Data")  # add your local data folder here

# %% [markdown]
# ## Load spectra raw data from GNPS
# - Retrieved on 25/01/2021 from https://gnps-external.ucsd.edu/gnpslibrary

# %%
filename = os.path.join(path_data, 'GNPS_all', 'ALL_GNPS.mgf')
spectrums = list(load_from_mgf(filename))

print("number of spectra:", len(spectrums))
# Out:
# number of spectra: 210407

# %%
import pickle
pickle.dump(spectrums, 
            open(os.path.join(path_data, 'GNPS_all', 'ALL_GNPS.pickle'), "wb"))

# %%
import pickle
outfile = os.path.join(path_data, 'GNPS_all', 'ALL_GNPS.pickle')
with open(outfile, 'rb') as file:
    spectrums = pickle.load(file)

# %%
def count_annotations(spectra):
    inchi_lst = []
    smiles_lst = []
    inchikey_lst = []
    for i, spec in enumerate(spectra):
        inchi_lst.append(spec.get("inchi"))
        smiles_lst.append(spec.get("smiles"))
        inchikey = spec.get("inchikey")
        if inchikey is None:
            inchikey = spec.get("inchikey_inchi")
        inchikey_lst.append(inchikey)

    inchi_count = sum([1 for x in inchi_lst if x])
    smiles_count = sum([1 for x in smiles_lst if x])
    inchikey_count = sum([1 for x in inchikey_lst if x])
    print("Inchis:", inchi_count, "--", len(set(inchi_lst)), "unique")
    print("Smiles:", smiles_count, "--", len(set(smiles_lst)), "unique")
    print("Inchikeys:", inchikey_count, "--", 
          len(set([x[:14] for x in inchikey_lst if x])), "unique (first 14 characters)")

# %%
count_annotations(spectrums)
# Out:
# Inchis: 207243 -- 18697 unique
# Smiles: 208516 -- 22996 unique
# Inchikeys: 0 -- 0 unique (first 14 characters)

# %% [markdown]
# ## Run basic matchs filters

# %%
from matchms.filtering import default_filters
from matchms.filtering import add_parent_mass, derive_adduct_from_name

def apply_filters(s):
    s = default_filters(s)
    s = derive_adduct_from_name(s)
    s = add_parent_mass(s, estimate_from_adduct=True)
    return s

spectrums = [apply_filters(s) for s in spectrums]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17428/760548578.py in <module>
#       8     return s
#       9
# ---> 10 spectrums = [apply_filters(s) for s in spectrums]
#
# NameError: name 'spectrums' is not defined

# %%
formulas = []
name_to_formulas = []
for spec in spectrums:
    if spec.get("formula"):
        formulas.append(spec.get("formula"))
        name_to_formulas.append(spec.get("compound_name") + "---" + spec.get("formula"))

# %%
name_to_formulas[:1000]
# Out:
# ['Microcystin---LR',
#  'Coproporphyrin---III',
#  'Coproporphyrin I or---III',
#  'Phosphatidylethanolamine (22:0/16:1) Abbr:---BPoPE',
#  'Phosphatidylethanolamine GOPE or---ALPE',
#  'Phosphatidylethanolamine (20:1/16:1) Abbr:---GPoPE',
#  'Phosphatidylethanolamine (20:1/16:1) Abbr:---GPoPE',
#  'Phosphatidylethanolamine (12:0/18:3) Abbr:---LaLnPE',
#  'Phosphatidylethanolamine (16:0/18:2) Abbr:---PLPE',
#  'Phosphatidylethanolamine (16:0/18:2) Abbr:---PLPE',
#  'Phosphatidylethanolamine (16:1/18:3) Abbr:---PoLnPE',
#  'Phosphatidylethanolamine (16:1/18:2) Abbr:---PoLPE',
#  'Phosphatidylethanolamine PoLPE or---PLnPE',
#  'Phosphatidylethanolamine PoOPE or---PLPE',
#  'Phosphatidylethanolamine POPE or---PoSPE',
#  'Phosphatidylethanolamine (16:1/18:0) Abbr:---PoSPE',
#  'Phosphatidylethanolamine (16:0/16:1) Abbr: PPoPE or (14:0/18:1) Abbr:---MOPE',
#  'Phosphatidylethanolamine (18:0/18:1) Abbr:---SOPE',
#  'Protoporphyrin---IX',
#  '---GE37468',
#  '---GE37468',
#  'Putative match to B.subtilis---SKF',
#  'Putative match to B.subtilis---SKF',
#  'Putative match to B.subtilis---SKF',
#  'Putative match to B.subtilis---SKF',
#  'Norpterphyllin---III',
#  'Stendomycin---II',
#  '---NARCOTIN',
#  'protoporphyrin---IX',
#  'Coproporphyrin---III',
#  '---SAHA',
#  'Theonellapeptolide---IId',
#  'Theonellapeptolide---IId',
#  'Araplysillin---II',
#  'Araplysillin---II',
#  'Tashinone---IIA',
#  'm/z 311 of diterpene esters (including phorbol ester) collected from---TPA',
#  'Mesoporphyrin---IX',
#  '3-hydroxybutanoyl---CoA',
#  'acetoacetyl---CoA',
#  'cinnamoyl---CoA',
#  'benzoyl---CoA',
#  'acetyl---CoA',
#  '2,3-butenoyl---CoA',
#  'salinamidoyl---CoA',
#  'pyrrolyl---CoA',
#  'alphahydroxyphenyl---CoA',
#  'betamethoxyvaleroyl---CoA',
#  'alphamethylacetoacetyl---CoA',
#  'phenylalanyl---CoA',
#  'Chiococcasaponin---II',
#  'Chiococcasaponin---IV',
#  'Methyl---EGCG',
#  '---FR900359',
#  '---FR900359',
#  'Putative amphotericin-related---C48H77NO17',
#  'Lipid---IVa',
#  'Penta acylated lipid---IVa',
#  'DEHYDROEPIANDROSTERONE---SULFATE',
#  'GLYCOCHENODEOXYCHOLIC---ACID',
#  '---OII3167',
#  'Tobramycin, ion source fragment---BC',
#  'Mascaroside---II',
#  'Tunicamycin---VI',
#  '---TC3',
#  '---TC2',
#  '---TC1',
#  '---TC4',
#  '---IT143B',
#  '---SF2583B',
#  'Peptide TAELLEL or---LELLEAT',
#  'coproporphyrin---III',
#  'zinc coproporphyrin---III',
#  '---DAPG',
#  '---DAPG',
#  '---NA',
#  '---CELIN',
#  '---AFB1',
#  'Ethylenediaminetetraacetic acid---EDTA',
#  'Ethylenediaminetetraacetic acid---EDTA',
#  'butyrolactone---II',
#  'butyrolactone---VII',
#  'NNEI - N-1-naphthalenyl-1-pentyl-1H-indole-3-carboxamide 20---NCE',
#  'NNEI - N-1-naphthalenyl-1-pentyl-1H-indole-3-carboxamide 40---NCE',
#  'NNEI - N-1-naphthalenyl-1-pentyl-1H-indole-3-carboxamide 30---NCE',
#  'NNEI - N-1-naphthalenyl-1-pentyl-1H-indole-3-carboxamide 20---NCE',
#  'NNEI - N-1-naphthalenyl-1-pentyl-1H-indole-3-carboxamide 30---NCE',
#  'NNEI - N-1-naphthalenyl-1-pentyl-1H-indole-3-carboxamide 40---NCE',
#  "NNEI 2'-naphthyl isomer 20---NCE",
#  "NNEI 2'-naphthyl isomer 30---NCE",
#  "NNEI 2'-naphthyl isomer 40---NCE",
#  "NNEI 2'-naphthyl isomer 30---NCE",
#  '---HNP1',
#  'Aceroside---VII',
#  'Aceroside---VIII',
#  'batatasin---III',
#  '---PQS',
#  '---UN',
#  '---FR900359',
#  '---FR900359',
#  '---FR900359',
#  '---FR1',
#  '---FR1',
#  '---FR2',
#  '---FR2',
#  '---FR3',
#  '---FR3',
#  'Gibberellic acid---GA3',
#  'unknown---CLP',
#  'unknown---CLP',
#  '---NAD',
#  '---NADPH',
#  '---DHAP',
#  '---C16H25NS',
#  '---C16H25NS',
#  '---C16H25NS',
#  '---C16H25NS',
#  'abloxime /---IC202C',
#  '---NA',
#  'C2 acyl glutaric---DFO',
#  'Emindole---SB',
#  'Withanoside---IV',
#  'Withanoside---IV',
#  '5-methoxy---AMT',
#  'Erlotinib---HCl',
#  'Bendamustine---HCL',
#  'Idarubicin---HCl',
#  'Topotecan---HCl',
#  'Granisetron---HCl',
#  'Prazosin---HCl',
#  'Naratriptan---HCl',
#  'Proparacaine---HCl',
#  'Roxatidine acetate---HCl',
#  'Sarafloxacin---HCl',
#  'Sarafloxacin---HCl',
#  'Amiodarone---HCl',
#  'Moexipril---HCl',
#  'Naltrexone---HCl',
#  'Azasetron---HCl',
#  'Xylometazoline---HCl',
#  'Buflomedil---HCl',
#  'Lurasidone---HCl',
#  'Lurasidone---HCl',
#  'Palonosetron---HCl',
#  'Medetomidine---HCl',
#  'Naloxone---HCl',
#  'Milnacipran---HCl',
#  'Darifenacin---HBr',
#  'Tripelennamine---HCl',
#  'Articaine---HCl',
#  'Butenafine---HCl',
#  'Naftifine---HCl',
#  'Meptazinol---HCl',
#  'Fexofenadine---HCl',
#  'Doxycycline---HCl',
#  'Pentamidine---HCl',
#  'Pentamidine---HCl',
#  'Acebutolol---HCl',
#  'Procaine (Novocaine)---HCl',
#  'Doxapram---HCl',
#  'Dibucaine (Cinchocaine)---HCl',
#  'Tetrahydrozoline---HCl',
#  'Sertraline---HCl',
#  'Propranolol---HCl',
#  'PTEROCARPIN---METHYLETHER',
#  'STICTIC---ACID',
#  'PRECOCENE---II',
#  'KINETIN---RIBOSIDE',
#  'FOLIOSIDINE---ACETONIDE',
#  'NORDIHYDROGUAIARETIC---ACID',
#  '7-METHYL ETHER---HETEROPEUCENIN',
#  'LOBARIC---ACID',
#  'TANSHINONE---IIA',
#  'XANTHURENIC---ACID',
#  'BUPROPION---HYDROCHLORIDE',
#  '---PAZUFLOXACIN',
#  '---NAFTOPIDIL',
#  '---NAFTOPIDIL',
#  'ROSIGLITAZONE---MALEATE',
#  '---BICALUTAMIDE',
#  'DOXORUBICIN---HYDROCHLORIDE',
#  'IRSOGLADINE---MALEATE',
#  'ESCITALOPRAM---OXALATE',
#  'BENIDIPINE---HCl',
#  '---FINASTERIDE',
#  '---AMLEXANOX',
#  'BENAZEPRIL---HYDROCHLORIDE',
#  'BENPROPERINE---PHOSPHATE',
#  '---OLANZAPINE',
#  '---OLANZAPINE',
#  '---RISPERIDONE',
#  '---RISPERIDONE',
#  'ZOLPIDEM---TARTRATE',
#  '---LATANOPROST',
#  '---HYPEROSIDE',
#  'PEFLOXACIN---MESYLATE',
#  'PEFLOXACIN---MESYLATE',
#  '---ICARIIN',
#  '---RIFABUTIN',
#  '---SULFASALAZINE',
#  '---TOPIRAMATE',
#  '---OXAPROZIN',
#  'ESMOLOL---HYDROCHLORIDE',
#  '---TORASEMIDE',
#  'NELFINAVIR---MESYLATE',
#  '---ARGATROBAN',
#  '---ARGATROBAN',
#  '---VORICONAZOLE',
#  '---TRIPTOLIDE',
#  '---TADALAFIL',
#  'FLUTICASONE---PROPIONATE',
#  '---LOMIFYLLINE',
#  '---VALDECOXIB',
#  'FENOLDOPAM---MESYLATE',
#  'EPIRUBICIN---HYDROCHLORIDE',
#  'ROSIGLITAZONE---HCl',
#  'MOSAPRIDE---CITRATE',
#  '---LEVOSULPIRIDE',
#  '---DOCETAXEL',
#  '---DOCETAXEL',
#  '---FLUBENDAZOLE',
#  '---PICEID',
#  '---ACTARIT',
#  '---HONOKIOL',
#  'HALOMETASONE---MONOHYDRATE',
#  '---TACROLIMUS',
#  '---RAMIPRIL',
#  '---LETROZOLE',
#  '---MECILLINAM',
#  '---TRICLABENDAZOLE',
#  '---KITASAMYCIN',
#  '---TOCAINIDE',
#  '---ROFECOXIB',
#  '---CLARITHROMYCIN',
#  '---CLARITHROMYCIN',
#  '---NATEGLINIDE',
#  '---FAMCICLOVIR',
#  '---ORLISTAT',
#  '---ORLISTAT',
#  '---ALFUZOSIN',
#  '---PAROXETINE',
#  '---ARTESUNATE',
#  'BISOPROLOL---FUMARATE',
#  '---ARIPIPRAZOLE',
#  '---LEVOFLOXACIN',
#  'OLMESARTAN---MEDOXOMIL',
#  '---EZETIMIBE',
#  'TRIMEBUTINE---MALEATE',
#  '---ORMETOPRIM',
#  'CEFPODOXIME---PROXETIL',
#  'TIAGABINE---HCl',
#  '---IDEBENONE',
#  'CETRAXATE---HCl',
#  'PEROSPIRONE---HCl',
#  'Buflomedil---HCl',
#  '---BESTATIN',
#  'TOREMIFENE---CITRATE',
#  'GOSERELIN---ACETATE',
#  'DEXCHLORPHENIRAMINE---MALEATE',
#  'DEXCHLORPHENIRAMINE---MALEATE',
#  'CEFIXIME---TRIHYDRATE',
#  '---HOMOHARRINGTONINE',
#  '---SECOISOLARICIRESINOL',
#  '---RALTITREXED',
#  'VARDENAFIL---CITRATE',
#  'VARDENAFIL---CITRATE',
#  'DOLASETRON---MESYLATE',
#  'DOXAPRAM---HYDROCHLORIDE',
#  '---BALSALAZIDE',
#  '---TIBOLONE',
#  '---ANASTROZOLE',
#  '---HTMT',
#  '---TREMULACIN',
#  'OLOPATADINE---HYDROCHLORIDE',
#  '---ENROFLOXACIN',
#  '---ENROFLOXACIN',
#  '---LINEZOLID',
#  'DEXBROMPHENIRAMINE---MALEATE',
#  '---ZAFIRLUKAST',
#  '---ZAFIRLUKAST',
#  'LOTEPREDNOL---ETABONATE',
#  'SUMATRIPTAN---SUCCINATE',
#  '---DIPHENOXYLATE',
#  'LOMERIZINE---DiHCl',
#  '---ENALAPRILAT',
#  '---EXEMESTANE',
#  '---EFAVIRENZ',
#  'TEGASEROD---MALEATE',
#  '---ISRADIPINE',
#  'BENACTYZINE---HYDROCHLORIDE',
#  '---NITAZOXANIDE',
#  '---IRBESARTAN',
#  '---MILRINONE',
#  '---VALSARTAN',
#  '---VALSARTAN',
#  '---LEVOCETIRIZINE',
#  '---DOFETILIDE',
#  'QUETIAPINE---HEMIFUMARATE',
#  'FORMOTEROL FUMARATE---DIHYDRATE',
#  '---CLOTRIMAZOLE',
#  'LOBELINE---HYDROCHLORIDE',
#  'LOBELINE---HYDROCHLORIDE',
#  'TETRAETHYLTHIURAM---DISULFIDE',
#  'TETRAETHYLTHIURAM---DISULFIDE',
#  'URAPIDIL---HYDROCHLORIDE',
#  'URAPIDIL---HYDROCHLORIDE',
#  '---TFMPP',
#  '---FAMOTIDINE',
#  'SALBUTAMOL---SULFATE',
#  '---SDM25N',
#  'VINDESINE---SULFATE',
#  'VINDESINE---SULFATE',
#  '---CLOFAZIMINE',
#  'IMATINIB---MESYLATE',
#  'IMATINIB---MESYLATE',
#  'VINCRISTINE---SULFATE',
#  'VINCRISTINE---SULFATE',
#  '---LACIDIPINE',
#  '---LACIDIPINE',
#  '---DEHYDROEPIANDROSTERONE',
#  '---GLIMEPIRIDE',
#  '---GLIMEPIRIDE',
#  '---ARTEMETHER',
#  '---CCPA',
#  '---RUTIN',
#  '---RITONAVIR',
#  '---RITONAVIR',
#  'RIZATRIPTAN---BENZOATE',
#  'ITOPRIDE---HCl',
#  'SAQUINAVIR---MESYLATE',
#  'SAQUINAVIR---MESYLATE',
#  '---RIFAPENTINE',
#  '---RIFAXIMIN',
#  '---RIFAXIMIN',
#  '---HYDROCORTISONE',
#  '---RIFAMPICIN',
#  '---FLUTAMIDE',
#  '---PINDOLOL',
#  'MINOCYCLINE---HYDROCHLORIDE',
#  'MINOCYCLINE---HYDROCHLORIDE',
#  'MINOCYCLINE---HYDROCHLORIDE',
#  '---ATROPINE',
#  '---METYRAPONE',
#  'PREDNISOLONE---ACETATE',
#  '---DIGOXIN',
#  '---DIGOXIN',
#  'HYDROCORTISONE---HEMISUCCINATE',
#  '19-NORETHINDRONE---ACETATE',
#  '---THIABENDAZOLE',
#  '---AMOXAPINE',
#  '---AMOXAPINE',
#  '---CAPTOPRIL',
#  '---NABUMETONE',
#  'NALOXONE---HYDROCHLORIDE',
#  '---DANAZOL',
#  '---MITOXANTRONE',
#  '---MITOXANTRONE',
#  '---DOXYCYCLINE',
#  '---DOXYCYCLINE',
#  'ENALAPRIL---MALEATE',
#  '---FLUDARABINE',
#  '---RAMIPRIL',
#  'CORTISONE---ACETATE',
#  '---AMCINONIDE',
#  'AMOXICILLIN---CRYSTALLINE',
#  'QUINAPRIL---HYDROCHLORIDE',
#  'QUINAPRIL---HYDROCHLORIDE',
#  'QUINAPRIL---HYDROCHLORIDE',
#  '---METHYLPREDNISOLONE',
#  '---METHYLPREDNISOLONE',
#  'DAUNORUBICIN---HYDROCHLORIDE',
#  '---RIFAPENTINE',
#  'N-ACETYLPROCAINAMIDE---HYDROCHLORIDE',
#  'RANITIDINE---HYDROCHLORIDE',
#  'IDAZOXAN---HYDROCHLORIDE',
#  'MORANTEL TARTRATE---SALT',
#  'VINCRISTINE---SULFATE',
#  'VINCRISTINE---SULFATE',
#  'QUETIAPINE---HEMIFUMARATE',
#  'QUETIAPINE---HEMIFUMARATE',
#  'PROCATEROL---HYDROCHLORIDE',
#  'APOMORPHINE HYDROCHLORIDE---HEMIHYDRATE',
#  'CORTISONE---ACETATE',
#  'AMILORIDE---HYDROCHLORIDE',
#  '(-)-SCOPOLAMINE N-BUTYL---BROMIDE',
#  'URSODEOXYCHOLIC---ACID',
#  'PUROMYCIN---DIHYDROCHLORIDE',
#  'PHENYLTOLOXAMINE---CITRATE',
#  'ROSIGLITAZONE---HCl',
#  'BRETYLIUM---TOSYLATE',
#  'ALPHA-METHYL-P-[1-OXO-2-ISOINDOLINYL]-BENZENEACETIC---ACID',
#  'TIAPRIDE---HYDROCHLORIDE',
#  'SUMATRIPTAN---SUCCINATE',
#  '(TYR0)-MELANOCYTE-STIMULATING HORMONE-RELEASE INHIBITING---FACTOR',
#  'CEFPODOXIME---PROXETIL',
#  'LOBELINE---HYDROCHLORIDE',
#  'OLOPATADINE---HYDROCHLORIDE',
#  'DOXORUBICIN---HYDROCHLORIDE',
#  'MONTELUKAST---SODIUM',
#  'PHYSOSTIGMINE---SALICYLATE',
#  'HYDROCORTISONE---ACETATE',
#  '(-)-BICUCULLINE---METHIODIDE',
#  'ITOPRIDE---HCl',
#  'ATROPINE METHYL---NITRATE',
#  'HEXESTROL---DIPROPIONATE',
#  '(R)-(+)-SKF-38393---HYDROCHLORIDE',
#  'NAFTOPIDIL---DIHYDROCHLORIDE',
#  'NAFTOPIDIL---DIHYDROCHLORIDE',
#  'DEOXYCORTICOSTERONE---ACETATE',
#  'BUTETHAMATE---CITRATE',
#  'SAQUINAVIR---MESYLATE',
#  'SAQUINAVIR---MESYLATE',
#  '(+)-ISOPROTERENOL (+)-BITARTRATE---SALT',
#  'SAQUINAVIR---MESYLATE',
#  'SAQUINAVIR---MESYLATE',
#  'DEXBROMPHENIRAMINE---MALEATE',
#  'VARDENAFIL---CITRATE',
#  'VARDENAFIL---CITRATE',
#  'ANTAZOLINE---PHOSPHATE',
#  'KETOTIFEN---FUMARATE',
#  'PREDNISOLONE---ACETATE',
#  'HYDROCORTISONE---HEMISUCCINATE',
#  'NEOSTIGMINE METHYL---SULFATE',
#  'FENOLDOPAM---MESYLATE',
#  'FLUMETHASONE---PIVALATE',
#  'ESCITALOPRAM---OXALATE',
#  'PANCURONIUM---BROMIDE',
#  'TELENZEPINE---DIHYDROCHLORIDE',
#  'ANISOTROPINE---METHYLBROMIDE',
#  '(+)-BUTACLAMOL---HYDROCHLORIDE',
#  'VINBLASTINE---SULFATE',
#  'VINBLASTINE---SULFATE',
#  'NAPROXEN---SODIUM',
#  'CGS---HYDROCHLORIDE',
#  'KETANSERIN---TARTRATE',
#  'GUANABENZ---ACETATE',
#  'BENIDIPINE---HCl',
#  'BENAZEPRIL---HYDROCHLORIDE',
#  'NOMIFENSINE MALEATE---SALT',
#  '(+)-CIS-DILTIAZEM---HYDROCHLORIDE',
#  'ZOLPIDEM---TARTRATE',
#  '7-CHLORO-6-DEMETHYLTETRACYCLINE---HYDROCHLORIDE',
#  'TEGASEROD---MALEATE',
#  'PHENETHYLBIGUANIDE---HYDROCHLORIDE',
#  '1-(2-PYRIMIDYL)PIPERAZINE---DIHYDROCHLORIDE',
#  'BROMOCRIPTINE---MESYLATE',
#  'NELFINAVIR---MESYLATE',
#  'VALACICLOVIR---HYDROCHLORIDE',
#  'FORMOTEROL FUMARATE---DIHYDRATE',
#  'CYCLOPENTOLATE---HYDROCHLORIDE',
#  'DEFEROXAMINE---MESYLATE',
#  'TERBUTALINE---SULFATE',
#  'METOPROLOL---TARTRATE',
#  'DEXCHLORPHENIRAMINE---MALEATE',
#  'TOREMIFENE---CITRATE',
#  'PEROSPIRONE---HCl',
#  'PYRILAMINE---MALEATE',
#  'IMATINIB---MESYLATE',
#  'TRIMETHOPRIM---LACTATE',
#  '1-(1-ADAMANTYL)ETHYLAMINE---HYDROCHLORIDE',
#  'NALOXONE---HYDROCHLORIDE',
#  'MAPROTILINE---HYDROCHLORIDE',
#  '(-)-BICUCULLINE---METHOBROMIDE',
#  'MOSAPRIDE---CITRATE',
#  'MOXONIDINE---HCl',
#  'ESMOLOL---HYDROCHLORIDE',
#  'CEFOTAXIME SODIUM---SALT',
#  'CETRAXATE---HCl',
#  'HYOSCINE---HYDROCHLORIDE',
#  'PHENTOLAMINE---MESYLATE',
#  'TOLFENAMIC---ACID',
#  'IRSOGLADINE---MALEATE',
#  'RITODRINE---HYDROCHLORIDE',
#  'TIAGABINE---HCl',
#  'TRIMEBUTINE---MALEATE',
#  'TOLTERODINE---TARTRATE',
#  'LOMERIZINE---DiHCl',
#  'TIMOLOL---MALEATE',
#  'HALOPERIDOL METABOLITE---II',
#  'PREGNENOLONE---ACETATE',
#  '1-ADAMANTANAMINE---HYDROCHLORIDE',
#  'CHLORPROTHIXENE---HYDROCHLORIDE',
#  'TETRAMISOLE---HYDROCHLORIDE',
#  'BROMPHENIRAMINE---MALEATE',
#  'CARBINOXAMINE---MALEATE',
#  '1-(5-ISOQUINOLINESULFONYL)-3-METHYLPIPERAZINE---DIHYDROCHLORIDE',
#  'QUINAPRIL---HYDROCHLORIDE',
#  'BUPIVACAINE---HYDROCHLORIDE',
#  'ESTRADIOL---BENZOATE',
#  'DIBUCAINE---HYDROCHLORIDE',
#  '---B10A27',
#  '---B28A19',
#  '---B21A21',
#  '---B27A19',
#  '---B19A14',
#  '---B13A22',
#  '---B26A13',
#  '---B21A17',
#  '---B28A22',
#  '---B13A32',
#  '---B23A11',
#  '---B12A21',
#  '---B27A17',
#  '---B25A14',
#  '---B24A19',
#  '---B12A13',
#  '---B13A13',
#  '---B24A33',
#  '---B22A10',
#  '---B23A12',
#  '---B10A18',
#  '---B16A16',
#  '---B12A22',
#  '---B15A16',
#  '---B23A33',
#  '---B12A36',
#  '---B19A15',
#  '---B26A11',
#  '---B10A36',
#  '---B19A23',
#  '---B27A12',
#  '---B19A17',
#  '---B21A19',
#  '---B20A25',
#  '---B28A24',
#  '---B26A24',
#  '---B24A24',
#  '---NAD',
#  '---HYPOTAURINE',
#  '---PURINE',
#  '---PYRIMIDINE',
#  '---QUINATE',
#  '---MALONATE',
#  '---ADENINE',
#  '---URIDINE',
#  '---NICOTINAMIDE',
#  '---HYPOXANTHINE',
#  '---CREATINE',
#  '---GUANOSINE',
#  '---GUANINE',
#  '---HOMOSERINE',
#  '---PYRIDOXINE',
#  '---DAMP',
#  '---DIETHANOLAMINE',
#  '---GUANIDINOACETATE',
#  '---CREATININE',
#  '---DEOXYCYTIDINE',
#  '---THEOPHYLLINE',
#  '---LEUCINE',
#  '---BETAINE',
#  '---SELENOMETHIONINE',
#  '---PARAXANTHINE',
#  '---GALACTITOL',
#  '---METHYLGUANIDINE',
#  '---CAFFEINE',
#  '---UROCANATE',
#  '---KYNURENINE',
#  '---DOPAMINE',
#  'PICOLINIC---ACID',
#  'THYROTROPIN RELEASING---HORMONE',
#  'N-METHYL-D-ASPARTIC---ACID',
#  'L-PIPECOLIC---ACID',
#  'BETA-NICOTINAMIDE ADENINE DINUCLEOTIDE---PHOSPHATE',
#  'AGMATINE---SULFATE',
#  'N-ACETYL-L-ASPARTIC---ACID',
#  '---DEOXYCARNITINE',
#  '---PHOSPHOCHOLINE',
#  '---THIAMINE',
#  '5-METHYLCYTOSINE---HYDROCLORIDE',
#  'D-(-)-3-PHOSPHOGLYCERIC---ACID',
#  '---OCTOPAMINE',
#  '---PYRIDOXAMINE',
#  'FLAVIN ADENINE---DINUCLEOTIDE',
#  '---LAUROYLCARNITINE',
#  '---ADENINE',
#  '---PHOSPHOCREATINE',
#  '---HISTAMINE',
#  'INDOXYL---SULFATE',
#  'THIAMINE---MONOPHOSPHATE',
#  '---RIBOFLAVIN',
#  '---GLUCOSAMINATE',
#  'N-ACETYL-DL-GLUTAMIC---ACID',
#  'D-PANTOTHENIC---ACID',
#  'ANILINE-2-SULFONIC---ACID',
#  '---NORLEUCINE',
#  '---ADENOSINE',
#  'D-SACCHARIC---ACID',
#  '---CHOLINE',
#  '---ACETYLCHOLINE',
#  '---THEOBROMINE',
#  'CREATINE---PHOSPHATE',
#  'OPHTHALMIC---ACID',
#  '---TRIGONELLINE',
#  '---EPINEPHRINE',
#  '3-METHYGLUTARIC---ACID',
#  '---TYRAMINE',
#  'XANTHURENIC---ACID',
#  '---MELATONIN',
#  '---TRYPTAMINE',
#  '---CAFFEATE',
#  '---GLYCOCHOLATE',
#  '---PANTOLACTONE',
#  '---LIPOAMIDE',
#  '---HIPPURATE',
#  '---BENZALDEHYDE',
#  '2-QUINOLINECARBOXYLIC---ACID',
#  '---SEROTONIN',
#  '---PTERIN',
#  'INDOLE-3-PYRUVIC---ACID',
#  '---HYDROQUINONE',
#  '---DETHIOBIOTIN',
#  '---PHENETHYLAMINE',
#  'GERANYL---PYROPHOSPHATE',
#  'BENZYL---ALCOHOL',
#  '---PYRIDOXAL',
#  '---BIOTIN',
#  '---ACETOACETATE',
#  '---HYPOTAURINE',
#  '---CITRATE',
#  '---PURINE',
#  '---URATE',
#  '---TAURINE',
#  '---NICOTINATE',
#  '---INOSINE',
#  '---CYTOSINE',
#  '---ASCORBATE',
#  'GLUCONIC---ACID',
#  '---QUINATE',
#  '---MALONATE',
#  '---GLYCINE',
#  '---ADENINE',
#  '---THYMIDINE',
#  '---GLYCERATE',
#  '---OROTATE',
#  'ETHANOLAMINE---PHOSPHATE',
#  '---XANTHINE',
#  '---URIDINE',
#  '---CARNOSINE',
#  '---SUCCINATE',
#  '---URACIL',
#  '---HYPOXANTHINE',
#  '---CREATINE',
#  '---GUANOSINE',
#  '---GUANINE',
#  '---HOMOSERINE',
#  '---PYRIDOXINE',
#  '---DAMP',
#  'FOLIC---ACID',
#  'ISOCITRIC---ACID',
#  '---CREATININE',
#  '---DEOXYCYTIDINE',
#  '---THEOPHYLLINE',
#  '---LEUCINE',
#  '---ALLANTOIN',
#  '---GLYCERALDEHYDE',
#  '---PARAXANTHINE',
#  '---GALACTITOL',
#  'D-GLUCURONIC---ACID',
#  '---DEOXYURIDINE',
#  '---UROCANATE',
#  '---DOPAMINE',
#  '---HOMOCYSTINE',
#  '---XANTHOSINE',
#  'THYROTROPIN RELEASING---HORMONE',
#  '---GALACTARATE',
#  'L-PIPECOLIC---ACID',
#  'BETA-NICOTINAMIDE ADENINE DINUCLEOTIDE---PHOSPHATE',
#  'N-ACETYL-L-ASPARTIC---ACID',
#  'NICOTINAMIDE HYPOXANTHINE---DINUCLEOTIDE',
#  '6-PHOSPHOGLUCONIC---ACID',
#  '5-METHYLCYTOSINE---HYDROCLORIDE',
#  'D-GLYCERIC---ACID',
#  'PHOSPHO(ENOL)PYRUVIC---ACID',
#  'PHOSPHO(ENOL)PYRUVIC---ACID',
#  '2-AMINOETHYL DIHYDROGEN---PHOSPHATE',
#  '---OCTOPAMINE',
#  '---PYRIDOXAMINE',
#  '---LAUROYLCARNITINE',
#  '---ADENINE',
#  "URIDINE 5'-DIPHOSPHOGLUCURONIC---ACID",
#  '---HISTAMINE',
#  '---DEOXYRIBOSE',
#  '---RIBOFLAVIN',
#  '---CMP',
#  '---GLUTATHIONE',
#  '---GLUCOSAMINATE',
#  'N-ACETYL-DL-GLUTAMIC---ACID',
#  'D-PANTOTHENIC---ACID',
#  'ANILINE-2-SULFONIC---ACID',
#  'THIAMINE---PYROPHOSPHATE',
#  '---NORLEUCINE',
#  '---ADENOSINE',
#  'D-SACCHARIC---ACID',
#  '3-HYDROXYBUTANOIC---ACID',
#  '4-IMIDAZOLEACETIC---ACID',
#  'D-(+)-GALACTURONIC---ACID',
#  'L-METHIONINE---SULFOXIMINE',
#  'FORMYL-L-METHIONYL---PEPTIDE',
#  '---THEOBROMINE',
#  '---CITRAMALATE',
#  'OPHTHALMIC---ACID',
#  '2-HYDROXYBUTYRIC---ACID',
#  '---STACHYOSE',
#  '3-METHYGLUTARIC---ACID',
#  '---SORBATE',
#  '---TYRAMINE',
#  '---CORTISOL',
#  'XANTHURENIC---ACID',
#  '---MELATONIN',
#  'MALEIC---ACID',
#  '4-HYDROXY-2-QUINOLINECARBOXYLIC---ACID',
#  '3-HYDROXYBENZYL---ALCOHOL',
#  '---OXALOACETATE',
#  '---FERULATE',
#  '---GLYCOCHOLATE',
#  '3-AMINO-5-HYDROXYBENZOIC---ACID',
#  '---CATECHOL',
#  '2-HYDROXYPHENYLACETIC---ACID',
#  'METHYL---VANILLATE',
#  '---HIPPURATE',
#  'ETHYLMALONIC---ACID',
#  '---FUMARATE',
#  '3-AMINO-4-HYDROXYBENZOIC---ACID',
#  'DIHYDROXYMANDELIC---ACID',
#  '---ANTHRANILATE',
#  '---HYDROQUINONE',
#  '---DETHIOBIOTIN',
#  'AZELAIC---ACID',
#  'MONO-METHYL---GLUTARATE',
#  '---HOMOVANILLATE',
#  '4-QUINOLINECARBOXYLIC---ACID',
#  '---SALICYLAMIDE',
#  '---HOMOGENTISATE',
#  '---BIOTIN',
#  'PHENYLACETIC---ACID',
#  'RESORCINOL---MONOACETATE',
#  '---XYLITOL',
#  '---SUCROSE',
#  '---MANNITOL',
#  '---MMV1110498',
#  '---MMV553002',
#  '---MMV188296',
#  '---MMV690028',
#  '---MMV688798',
#  '---MMV688756',
#  '---MMV676539',
#  '---MMV676526',
#  '---MMV676476',
#  '---MMV202458',
#  '---MMV688553',
#  '---MMV676603',
#  '---MMV676431',
#  '---MMV676444',
#  '---MMV676520',
#  '---MMV676379',
#  '---MMV690027',
#  '---MMV652003',
#  '---MMV687801',
#  '---MMV687803',
#  '---MMV687776',
#  '---MMV687775',
#  '---MMV637229',
#  '---MMV687800',
#  '---MMV675997',
#  '---MMV688508',
#  '---MMV688410',
#  '---MMV676053',
#  '---MMV676191',
#  '---MMV675969',
#  '---MMV676204',
#  '---MMV688179',
#  '---MMV687243',
#  '---MMV687146',
#  '---MMV688846',
#  '---MMV688125',
#  '---MMV687273',
#  '---MMV1198433',
#  '---MMV689060',
#  '---MMV687807',
#  '---MMV689061',
#  '---MMV688124',
#  '---MMV689709',
#  '---MMV688891',
#  '---MMV595321',
#  '---MMV689028',
#  '---MMV689029',
#  '---MMV688371',
#  '---MMV676269',
#  '---MMV676877',
#  '---MMV676064',
#  '---MMV688467',
#  '---MMV676063',
#  '---MMV688372',
#  '---MMV688362',
#  '---MMV688279',
#  '---MMV688271',
#  '---MMV688941',
#  '---MMV688980',
#  '---MMV146306',
#  '---MMV688330',
#  '---MMV676468',
#  '---MMV676470',
#  '---MMV200748',
#  '---MMV688771',
#  '---MMV671636',
#  '---MMV687798',
#  '---MMV676270',
#  '---MMV688978',
#  '---MMV688775',
#  '---MMV688754',
#  '---MMV688990',
#  '---MMV687729',
#  '---MMV407834',
#  '---MMV161996',
#  '---MMV688543',
#  '---MMV553002',
#  '---MMV188296',
#  '---MMV690028',
#  '---MMV688798',
#  '---MMV676539',
#  '---MMV676526',
#  '---MMV676476',
#  '---MMV202458',
#  '---MMV676431',
#  '---MMV676379',
#  '---MMV690027',
#  '---MMV687800',
#  '---MMV676053',
#  '---MMV676191',
#  '---MMV688179',
#  '---MMV687146',
#  '---MMV688125',
#  '---MMV1198433',
#  '---MMV687807',
#  '---MMV689061',
#  '---MMV688124',
#  '---MMV689709',
#  '---MMV688891',
#  '---MMV595321',
#  '---MMV689028',
#  '---MMV689029',
#  '---MMV688371',
#  '---MMV676269',
#  '---MMV676877',
#  '---MMV688467',
#  '---MMV688372',
#  '---MMV688279',
#  '---MMV688271',
#  '---MMV688330',
#  '---MMV676470',
#  '---MMV200748',
#  'Phe-Leu from---NIST14',
#  'N-.alpha.-Acetyl-L-arginine from---NIST14',
#  '.beta.-D-Glucose from---NIST14',
#  'Sissotrin from---NIST14',
#  'Kaempferol from---NIST14',
#  'Phe-Leu from---NIST14',
#  'Leu-Val-Lys from---NIST14',
#  "Adenosine, 5'-S-methyl-5'-thio- from---NIST14",
#  '1,3-Dicyclohexylurea from---NIST14',
#  'Met-Val from---NIST14',
#  'Rutin from---NIST14',
#  'Palmitelaidic acid from---NIST14',
#  'Oleuropein from---NIST14',
#  'Malvidin 3-O-galactoside cation from---NIST14',
#  'Quercetin from---NIST14',
#  '2-Amino-1-phenylethanol from---NIST14',
#  'Chlorogenic acid from---NIST14',
#  '2-Butanone, 4-(2,6,6-trimethyl-2-cyclohexen-1-yl)- from---NIST14',
#  '1-Myristoyl-2-stearoyl-sn-glycero-3-phosphocholine from---NIST14',
#  '8S-Hydroxy-9E,11Z,14Z-eicosatrienoic acid from---NIST14',
#  'Nalidixic acid from---NIST14',
#  'Adipic acid from---NIST14',
#  'Trazodone from---NIST14',
#  '1-Hexadecanoyl-sn-glycero-3-phosphocholine from---NIST14',
#  '13-Docosenamide, (Z)- from---NIST14',
#  '1-Stearoyl-2-linoleoyl-sn-glycero-3-phosphoethanolamine from---NIST14',
#  '6.alpha.-Methylprednisolone from---NIST14',
#  '13-Docosenamide, (Z)- from---NIST14',
#  '6.alpha.-Methylprednisolone from---NIST14',
#  'Pentaerythritol tetrakis(3,5-di-tert-butyl-4-hydroxyhydrocinnamate) from---NIST14',
#  '9-Octadecenamide, (Z)- from---NIST14',
#  'Naltrexone from---NIST14',
#  'Val-Gly-Val from---NIST14',
#  '1-Stearoyl-2-linoleoyl-sn-glycero-3-phosphoethanolamine from---NIST14',
#  '1-Heptadecanoyl-sn-glycero-3-phosphocholine from---NIST14',
#  'D-(+)-Trehalose from---NIST14',
#  'DL-Arginine from---NIST14',
#  '1-(9Z-Octadecenoyl)-sn-glycero-3-phosphocholine from---NIST14',
#  'Chlorogenic acid from---NIST14',
#  'Pinolenic acid from---NIST14',
#  'Lauroyl L-carnitine from---NIST14',
#  'DL-Indole-3-lactic acid from---NIST14',
#  'Ethylenediaminetetraacetic acid from---NIST14',
#  '1-Arachidoyl-2-hydroxy-sn-glycero-3-phosphocholine from---NIST14',
#  '1-Hexadecanoyl-sn-glycerol from---NIST14',
#  '1-Stearoyl-2-hydroxy-sn-glycero-3-phosphoethanolamine from---NIST14',
#  'Monolaurin from---NIST14',
#  'His Trp from---METLIN',
#  "1,2-Dipalmitoyl-sn-glycero-3-phospho-(1'-rac-glycerol) from---NIST14",
#  'Linolenic acid ethyl ester from---NIST14',
#  'Maltotriose from---NIST14',
#  'Trp-Glu from---NIST14',
#  'L-Carnitine from---NIST14',
#  'L-Glutathione, reduced from---NIST14',
#  'Quetiapine from---METLIN',
#  'Gly-Leu from---NIST14',
#  'L-Tyrosine from---NIST14',
#  'Hydrocortisone from---NIST14',
#  'Monensin from---NIST14',
#  '1-Myristoyl-sn-glycero-3-phosphocholine from---NIST14',
#  'Datiscetin from---NIST14',
#  'Trp-Glu from---NIST14',
#  '9,10-Dihydroxy-12Z-octadecenoic acid from---NIST14',
#  '(+)-4-Cholesten-3-one from---NIST14',
#  '1-Hexadecyl-2-(9Z-octadecenoyl)-sn-glycero-3-phosphocholine from---NIST14',
#  'Glycocholic acid from---NIST14',
#  '1-Hexadecyl-sn-glycero-3-phosphocholine from---NIST14',
#  '.beta.-D-Allose from---NIST14',
#  '4(5)-EpDPE methyl ester from---NIST14',
#  'Isovitexin from---NIST14',
#  'Glycoursodeoxycholic acid from---NIST14',
#  'Arachidonoylthio-PC from---NIST14',
#  'Cyclizine from---NIST14',
#  '14(15)-EET methyl ester from---NIST14',
#  'Pentadecanoic acid, 14-methyl- from---NIST14',
#  'Delphinidin 3-O-glucoside cation from---NIST14',
#  "4',7-Dimethoxyisoflavone from---NIST14",
#  '.gamma.-CEHC from---NIST14',
#  'Glutathione, oxidized from---NIST14',
#  '1-Arachidoyl-2-hydroxy-sn-glycero-3-phosphocholine from---NIST14',
#  'Biochanin A from---NIST14',
#  'Pindolol from---NIST14',
#  'HEPC from---NIST14',
#  '1-(1Z-Octadecenyl)-2-(9Z-octadecenoyl)-sn-glycero-3-phosphocholine from---NIST14',
#  'Tris(2-butoxyethyl) phosphate from---NIST14',
#  "2'-Methoxyflavone from---NIST14",
#  '2-Butanone, 4-(2,6,6-trimethyl-2-cyclohexen-1-yl)- from---NIST14',
#  'Cyclizine from---NIST14',
#  '1,2-Dihexadecanoyl-sn-glycero-3-phosphocholine from---NIST14',
#  '11(12)-EET from---NIST14',
#  'Abrine from---NIST14',
#  'Monolinolenin (9c,12c,15c) from---NIST14',
#  'Phe-Ile-Lys from---NIST14',
#  'Corticosterone from---NIST14',
#  'Norharmane from---NIST14',
#  '1-Octadecanoyl-2-(5Z,8Z,11Z,14Z-eicosatetraenoyl)-sn-glycero-3-phosphoserine from---NIST14',
#  'DL-Phenylalanine from---NIST14',
#  '1,2-Dipalmitoleoyl-sn-glycero-3-phosphocholine from---NIST14',
#  'R-Palmitoyl-(1-methyl) ethanolamide from---NIST14',
#  "Adenosine 5'-diphosphate from---NIST14",
#  'Glycan Lacto-N-biose from---NIST14',
#  'Pyocyanin from---NIST14',
#  'Pinolenic acid from---NIST14',
#  '1-Octadecanoyl-2-(4Z,7Z,10Z,13Z,16Z,19Z-docosahexaenoyl)-sn-glycero-3-phospho-L-serine from---NIST14',
#  'Midazolam from---NIST14',
#  'Farnesol from---NIST14',
#  'Fumonisin B1 from---NIST14',
#  'Isorhamnetin 3-O-glucoside from---NIST14',
#  '1-Octadecanoyl-2-octadecenoyl-sn-glycero-3-phosphocholine from---NIST14',
#  'Coniferyl aldehyde from---NIST14',
#  'D-erythro-Sphinganine from---NIST14',
#  'L-.gamma.-Glutamyl-L-glutamic Acid from---NIST14',
#  '3,4,5-Trimethoxycinnamic acid from---NIST14',
#  '[4-(Aminomethyl)phenyl]methanamine from---NIST14',
#  'Benzoic acid from---NIST14',
#  "Adenosine 5'-triphosphate from---NIST14",
#  '4-Methylcinnamic acid from---NIST14',
#  'Desferrioxamine from---NIST14',
#  '3-Iodo-L-tyrosine from---NIST14',
#  'L-Histidine, 3-methyl- from---NIST14',
#  '1-Palmitoyl-2-myristoyl-sn-glycero-3-phosphocholine from---NIST14',
#  'Kaempferol 3-O-rutinoside from---NIST14',
#  'N-Isovaleroylglycine from---NIST14',
#  'Diethyl azelate from---NIST14',
#  'Hexaethylene glycol from---NIST14',
#  'Palatinose from---NIST14',
#  'Oleoyl ethylamide from---NIST14',
#  '5,6-Dihydroxy-7-methoxyflavone from---NIST14',
#  'DL-Arginine from---NIST14',
#  '1-Hexadecanoyl-sn-glycerol from---NIST14',
#  'Lactulose from---NIST14',
#  'L-Tyrosine from---NIST14',
#  '14,15-Epoxy-5Z,8Z,11Z-eicosatrienoic acid from---NIST14',
#  "3,5,7,3',4'-Pentahydroxyflavanone from---NIST14",
#  '(+)-Catechin from---NIST14',
#  '(-)-Epicatechin from---NIST14',
#  'D-Fructose from---NIST14',
#  'Xanthine from---NIST14',
#  'Pterostilbene from---NIST14',
#  'Clomipramine from---NIST14',
#  'Adenosine from---NIST14',
#  'Avobenzone from---NIST14',
#  '[Precursor mass wrong]  Lauric acid leelamide from---NIST14',
#  'Phenyl-p-tolyl-amine from---NIST14',
#  'Azithromycin from---NIST14',
#  "Adenosine 3',5'-cyclic monophosphate from---NIST14",
#  'Taurocholic acid from---NIST14',
#  '2-Butanone, 4-(2,6,6-trimethyl-2-cyclohexen-1-yl)- from---NIST14',
#  'Palmitic acid ethyl ester from---NIST14']

# %%
len(formulas)
# Out:
# 57036

# %%
len(list(set(formulas)))
# Out:
# 1748

# %%
list(set(formulas))
# Out:
# ['C43H74O13P1',
#  'C20H41N1O7P1',
#  'OXAPROZIN',
#  'C45H89N1O7P1',
#  'HOMOSERINE',
#  'C21H43N1O7P1',
#  'C50H91N1O8P1',
#  'C48H89N1O7P1',
#  'VALSARTAN',
#  'NITRATE',
#  'C39H80N2O6P1',
#  'SACCHARATE',
#  'SULFOXIMINE',
#  'C59H104N1O6',
#  'C14H30N1O2',
#  'B27A12',
#  'C48H94N1O8',
#  'MMV676270',
#  'C57H114N1O6',
#  'C2H5S',
#  'IC202C',
#  'C51H92N1O6',
#  'QUINATE',
#  'NIN',
#  'C45H81N1O8P1',
#  'MMV676269',
#  'C43H79N1O7P1',
#  'C29H54O12P1',
#  'C65H102N1O6',
#  'GLN',
#  'METHYLMALONATE',
#  'MMV688553',
#  'MMV688179',
#  'P8S',
#  'C44H79N1O10P1',
#  'ANASTROZOLE',
#  'C65H110N1O6',
#  'C53H106N1O6',
#  'C46H91N1O8P1',
#  'MALEATE',
#  'PEP',
#  'C42H76O10P1',
#  'MMV652003',
#  'C43H88N1O5',
#  'DEET',
#  'SUBERATE',
#  'C45H82N1O12S1',
#  'C75H137O17P2',
#  'NORLEUCINE',
#  'LEUCINE',
#  'TRYPTAMINE',
#  'C41H72O13P1',
#  'C42H70O10P1',
#  'C43H84N1O6',
#  'C49H90N1O6',
#  'C43H79N1O8P1',
#  'C73H133O17P2',
#  'TETRACONAZOLE',
#  'HEMIHYDRATE',
#  'CAFFEINE',
#  'C22H43N1O7P1',
#  'TRIFLUMURON',
#  'BC',
#  'C37H68O8P1',
#  'DBP',
#  'PROLINE',
#  'C55H104N1O6',
#  'GLUCONATE',
#  'C47H91N1O8P1',
#  'DIBOA',
#  'C42H78N1O7',
#  'C45H82N1O10',
#  'NYSTATIN',
#  'C49H86O13P1',
#  'PALATINOSE',
#  'C39H70O10P1',
#  'ACETOACETATE',
#  'B28A19',
#  'MMV688372',
#  'PTERIN',
#  'URSODEOXYCHOLATE',
#  'IRBESARTAN',
#  'PHENETHYLAMINE',
#  'C61H94N1O6',
#  'C44H86N1O3',
#  'PAEDEROSIDE',
#  'LITHOCHOLYLTAURINE',
#  'MMV688362',
#  'C36H71N1O8P1',
#  'C40H79N1O13P1',
#  'BENALAXYL',
#  'C50H73N1O10P1',
#  'C41H79N1O8P1',
#  'C41H78O13P1',
#  'DOXYCYCLINE',
#  'C47H82O13P1',
#  'C50H83N1O8P1',
#  'C38H71N1O8P1',
#  'C39H72O13P1',
#  'PARABEN',
#  'C45H80N1O2',
#  'C34H64N1O3',
#  'C44H83N1O8P1',
#  'C33H65N1O10P1',
#  'C39H72O10P1',
#  'C46H82O13P1',
#  'LIOTHYRONINE',
#  'C28H57N1O7P1',
#  'C83H147O17P2',
#  'SALICIN',
#  'FIPRONIL',
#  'REDUCED',
#  'DIMETHYLBENZIMIDAZOLE',
#  'C4H5N3O2',
#  'XANTHURENATE',
#  'NADPH',
#  'ADSGEGDFXAEGGGVR',
#  'C47H87N1O8P1',
#  'C38H71N1O10P1',
#  'C41H76O10P1',
#  'XED',
#  'C23H41N1O7P1',
#  'PQS',
#  'C43H82O13P1',
#  'CORTISOL',
#  'C50H94N1O6',
#  'CMP',
#  'C55H92N1O6',
#  'C44H74O13P1',
#  'MMV1110498',
#  'METHYLTHIOADENOSINE',
#  'HOMOCYSTINE',
#  'C40H77N1O10P1',
#  'NIL',
#  'C34H68N1O3',
#  'DIPHOSPHATEGALACTOSE',
#  'SULFANILYCARBAMATE',
#  'PoLPE',
#  'SEBACATE',
#  'C44H88N1O3',
#  'C40H85N1O6P1',
#  'DIGITONIN',
#  'GLUCURONOLACTONE',
#  'MESOXALATE',
#  'C44H80O10P1',
#  'IRIGENIN',
#  'C48H97N1O8P1',
#  'MUPIROCIN',
#  'HISTIDINOL',
#  'C50H74O10P1',
#  'MMV676468',
#  'EMETINE',
#  'C55H98N1O6',
#  'B4P',
#  'MORIN',
#  'C51H88N1O15',
#  'NEROL',
#  'C43H85N1O7P1',
#  'C36H70O10P1',
#  'C48H90N1O15',
#  'MMV689060',
#  'C57H96N1O6',
#  'C81H133O17P2',
#  'C44H84N1O12S1',
#  'ORNITHINE',
#  'GLYCERALDEHYDE',
#  'C43H73N1O8P1',
#  'VALDECOXIB',
#  'THEOPHYLLINE',
#  'RIBITOL',
#  'C50H99N1O8P1',
#  'METHYGLUTARATE',
#  'C42H75N1O8P1',
#  'C56H98N1O6',
#  'B19A23',
#  'C25H51N1O7P1',
#  'NORVALINE',
#  'C59H108N1O6',
#  'YOHIMBINE',
#  'ISOLEUCINE',
#  'C44H86N1O7',
#  'C46H88N1O8',
#  'C52H91N1O8P1',
#  'C65H118N1O6',
#  'SPECTINOMYCIN',
#  'OXOPROLINE',
#  'C83H141O17P2',
#  'C44H89N1O7P1',
#  'MMV687801',
#  'RHN',
#  'C54H108N1O6',
#  'FORAMSULFURON',
#  'ESA',
#  'C34H68N1O5',
#  'C23H42N1O4',
#  'C41H84N2O6P1',
#  'C80H147O17P2',
#  'C32H62N1O3',
#  'C35H68N1O3',
#  'FR2',
#  'PHOSPHOENOLPYRUVATE',
#  'C38H66O10P1',
#  'B15A16',
#  'BRUCINE',
#  'C44H87N1O8P1',
#  'GLUTATHIONE',
#  'FAD',
#  'C20H43N1O7P1',
#  'C53H102N1O6',
#  'MALONATE',
#  'C47H90N1O7',
#  'C26H51N1O7P1',
#  'VII',
#  'B26A11',
#  'ROFECOXIB',
#  'ARIPIPRAZOLE',
#  'CELIN',
#  'KITASAMYCIN',
#  'C42H74N1O7',
#  'MMV688756',
#  'C41H72O8P1',
#  'AZELATE',
#  'PCA',
#  'HOMOCYSTEINE',
#  'C47H73N1O8P1',
#  'PYRIDOXAL',
#  'SAHA',
#  'B10A18',
#  'LEVOFLOXACIN',
#  'OXIDE',
#  'MMV553002',
#  'C55H90N1O6',
#  'LEVOSULPIRIDE',
#  'C24H48O9P1',
#  'C46H81N1O10P1',
#  'C61H120N1O6',
#  'C41H78N1O12S1',
#  'C79H147O17P2',
#  'BESTATIN',
#  'C51H84N1O15',
#  'ARTESUNATE',
#  'C31H62N1O6',
#  'CAPSAICIN',
#  'B23A11',
#  'II',
#  'ARTEMETHER',
#  'EUGENOL',
#  'C49H88N1O15',
#  'C47H82N1O12S1',
#  'ETABONATE',
#  'C24H51N1O7P1',
#  'ITACONATE',
#  'IVa',
#  'III',
#  'C48H87N1O7P1',
#  'ARTENIMOL',
#  'C46H94N2O6P1',
#  'C50H96N1O6',
#  'C49H96N1O6',
#  'C47H84O13P1',
#  'TAURINE',
#  'C43H74N1O5',
#  'MEVALOLACTONE',
#  'OXALATE',
#  'B19A15',
#  'C37H72O8P1',
#  'MBT',
#  'METLIN',
#  'C38H74N1O7',
#  'C35H71N1O8P1',
#  'C53H88N1O15',
#  'C39H69N1O8P1',
#  'METHYLETHER',
#  'MMV676379',
#  'C47H93N1O8P1',
#  'RIFAMPICIN',
#  'TC3',
#  'ABOA',
#  'PZI',
#  'C42H80O10P1',
#  'B16A16',
#  'OLEANDOMYCIN',
#  'NA',
#  'B24A24',
#  'C21H45N1O7P1',
#  'C50H93N1O8P1',
#  'DINOSEB',
#  'MMV687146',
#  'ERYTHROMYCIN',
#  'MMV675969',
#  'MANDELATE',
#  'DEOXYURIDINE',
#  'PSICOSE',
#  'HYDROCHLORIDE',
#  'C40H71N1O8P1',
#  'C35H70N1O3',
#  'C45H83N1O8P1',
#  'HBr',
#  'C5H9',
#  'NICOTINAMIDE',
#  'MMV407834',
#  'C44H72O10P1',
#  'C6H9O5',
#  'EXEMESTANE',
#  'AMPA',
#  'C39H73N1O7P1',
#  'C41H77N1O8P1',
#  'ROTENONE',
#  'C52H100N1O6',
#  'C24H46O9P1',
#  'C45H78O13P1',
#  'C42H80N1O8',
#  'PHOSPHOSERINE',
#  'C41H70N1O5',
#  'C40H80N1O8',
#  'C40H79N1O12P1',
#  'C50H99N1O12P1',
#  'METHOBROMIDE',
#  'DIGOXIGENIN',
#  'METHIDATHION',
#  'MSX',
#  'PREDNISOLONE',
#  'C34H66O10P1',
#  'C47H94N2O6P1',
#  'C42H77N1O8P1',
#  'C27H57N1O7P1',
#  'DICTAMNINE',
#  'EPE',
#  'C38H72O10P1',
#  'NCE',
#  'ABAMECTIN',
#  'C46H74O10P1',
#  'MYOINOSITOL',
#  'C18H38N1O2',
#  'FLUTAMIDE',
#  'PANTOLACTONE',
#  'C28H43N1O9P1',
#  'SPHINGANINE',
#  'MILRINONE',
#  'CHLORIDE',
#  'C41H76O13P1',
#  'C67H102N1O6',
#  'HYDRATE',
#  'C43H80N1O5',
#  'ANETHOLE',
#  'BILIVERDIN',
#  'C46H85N1O8P1',
#  'C33H66N1O3',
#  'C50H101N1O8P1',
#  'C35H66N1O5',
#  'C39H68O8P1',
#  'C39H74O13P1',
#  'C63H100N1O6',
#  'C81H147O17P2',
#  'C54H94N1O6',
#  'SODIUM',
#  'HWESASXX',
#  'DIGITOXIN',
#  'PACLITAXEL',
#  'DANTHRON',
#  'C32H63N1O9P1',
#  'CA6PE2C',
#  'C36H68O10P1',
#  'C38H76N1O5',
#  'DTMP',
#  'C39H75N1O7P1',
#  'B22A10',
#  'B13A32',
#  'C44H85N1O7P1',
#  'C42H77N1O10P1',
#  'C43H82N1O10',
#  'MMV687243',
#  'C37H71N1O8P1',
#  'DiHCl',
#  'C41H75N1O7P1',
#  'TRIPHOSPHATE',
#  'VORICONAZOLE',
#  'C36H72N1O5',
#  'C32H64N1O3',
#  'PLnPE',
#  'PGI2',
#  'B24A33',
#  'C51H78O13P1',
#  'TRIPTOLIDE',
#  'CLARITHROMYCIN',
#  'MMV202458',
#  'BROMACIL',
#  'C56H100N1O6',
#  'C48H89N1O8P1',
#  'MMV687803',
#  'C43H72N1O10',
#  'C24H49N1O9P1',
#  'C38H74N1O5',
#  'RAFFINOSE',
#  'RUTIN',
#  'C42H73N1O10P1',
#  'ESTRIOL',
#  'C50H97N1O8P1',
#  'RIBOSE',
#  'C34H70N1O4',
#  'C42H87N1O7P1',
#  'CATECHOL',
#  'C50H85N1O8P1',
#  'C39H75N1O8P1',
#  'C21H41N1O7P1',
#  'AMINOPYRINE',
#  'HISTAMINE',
#  'ORMETOPRIM',
#  'C44H77N1O8P1',
#  'PHENYLPYRUVATE',
#  'C45H82O13P1',
#  'AMOXAPINE',
#  'ACTIPHENOL',
#  'C56H94N1O6',
#  'TREMULACIN',
#  'C35H69N1O7P1',
#  'SELENOMETHIONINE',
#  'C56H108N1O6',
#  'PSCMC',
#  'HAEMATOPORPHYRIN',
#  'SHIKIMATE',
#  'FFA',
#  'C39H76N1O5',
#  'RITONAVIR',
#  'NORADRENALINE',
#  'CARBOFURAN',
#  'C45H86N1O12S1',
#  'IT143B',
#  'C36H69N1O8P1',
#  'TACROLIMUS',
#  'MMV689061',
#  'XANTHOSINE',
#  'METHYLPREDNISOLONE',
#  'C37H70O8P1',
#  'C51H82N1O15',
#  'C45H88N1O7',
#  'THREONINE',
#  'LOMIFYLLINE',
#  'C41H82N1O12S1',
#  'C83H143O17P2',
#  'C57H98N1O6',
#  'NIST14',
#  'C37H68N1O5',
#  'C47H88N1O6',
#  'PROXETIL',
#  'C48H90N1O6',
#  'METYRAPONE',
#  'C46H86N1O8',
#  'C52H98N1O6',
#  'C38H77N1O7P1',
#  'ESTRADIOL',
#  'BPoPE',
#  'C43H83N1O7P1',
#  'DIHYDRATE',
#  'DINUCLEOTIDE',
#  'C38H72O9P1',
#  'C66H124N1O6',
#  'ADP',
#  'C44H79N1O7P1',
#  'ALLOSE',
#  'C46H94N1O3',
#  'C81H149O17P2',
#  'C49H84O13P1',
#  'C49H77N1O8P1',
#  'MCPB',
#  'SULFLURAMID',
#  'C39H78N1O5',
#  'C39H73N1O8P1',
#  'C49H86N1O15',
#  'C55H110N1O6',
#  'FLUAZINAM',
#  'C58H110N1O6',
#  'GRISEOFULVIN',
#  'C42H86N1O4',
#  'DIETHANOLAMINE',
#  'C38H67N1O8P1',
#  'C49H75N1O8P1',
#  'C61H102N1O6',
#  'C23H47N1O7P1',
#  'C63H96N1O6',
#  'C55H94N1O6',
#  'MMV637229',
#  'C61H104N1O6',
#  'B23A12',
#  'C47H92N1O6',
#  'C18H40N1O2',
#  'C35H67N1O8P1',
#  'C59H106N1O6',
#  'C47H76O13P1',
#  'PAZUFLOXACIN',
#  'C63H120N1O6',
#  'CHOLATE',
#  'C55H102N1O6',
#  'C51H94N1O6',
#  'MIL',
#  'C47H77N1O8P1',
#  'C46H87N1O8P1',
#  'C65H128N1O6',
#  'ARABINOSE',
#  'ARABITOL',
#  'CITRULLINE',
#  'XYLITOL',
#  'C40H69N1O8P1',
#  'MMV671636',
#  'TAGATOSE',
#  'GUANIDINOSUCCINATE',
#  'C43H86N1O5',
#  'C65H106N1O6',
#  'C59H110N1O6',
#  'C61H98N1O6',
#  'MONOACETATE',
#  'FAMOTIDINE',
#  'TRYPTOPHANAMIDE',
#  'VANILLATE',
#  'C37H67N1O8P1',
#  'CITRATE',
#  'I7B',
#  'C44H79N1O8P1',
#  'C38H69N1O8P1',
#  'C47H86O13P1',
#  'C59H94N1O6',
#  'DEOXYGUANOSINE',
#  'C38H75N1O8P1',
#  'C47H81N1O7P1',
#  'C28H44O9P1',
#  'B10A36',
#  'MUL',
#  'PENTAACETATE',
#  'C65H112N1O6',
#  'C46H90N1O8',
#  'C48H84O13P1',
#  'THYMIDINE',
#  'ASPARAGINE',
#  'IMAZAMOX',
#  'NORSPERMIDINE',
#  'C51H92N1O15',
#  'C56H104N1O6',
#  'C43H80N1O12S1',
#  'C33H66N1O5',
#  'C44H82N1O12S1',
#  'MMV688891',
#  'MMV676063',
#  'PYROPHOSPHATE',
#  'C43H76N1O5',
#  'C40H71N1O10P1',
#  'SEROTONIN',
#  'SALICYLATE',
#  'C59H91O4',
#  'C47H84N1O15',
#  'TC2',
#  'C52H94N1O6',
#  'MPA',
#  'C13H21O2',
#  'PYROGALLIN',
#  'C49H94N1O15',
#  'MOPE',
#  'B12A21',
#  'C43H84N1O10',
#  'ASCORBATE',
#  'C39H77N1O8P1',
#  'ASULAM',
#  'DAMP',
#  'MMV676470',
#  'MOCA',
#  'ARGATROBAN',
#  'C33H65N1O9P1',
#  'THYMOQUINONE',
#  'TH',
#  'SERINE',
#  'DANAZOL',
#  'C45H79N1O7P1',
#  'C40H78O10P1',
#  'EQ',
#  'MMV687800',
#  'ERYTHRITOL',
#  'CHOLESTANE',
#  'PLPE',
#  'HCZ',
#  'C62H116N1O6',
#  'RAMIPRIL',
#  'ARGININE',
#  'C46H79N1O10P1',
#  'C39H72O8P1',
#  'C43H86N1O12S1',
#  'C26H53N1O8P1',
#  'C79H141O17P2',
#  'MMV688279',
#  'KUHLMANNIN',
#  'C50H78O10P1',
#  'CYSTEATE',
#  'C64H118N1O6',
#  'C54H102N1O6',
#  'SULFASALAZINE',
#  'C25H43N1O7P1',
#  'C40H76O10P1',
#  'C37H72N1O5',
#  'C39H78N1O12S1',
#  'CYCLOSPORINE',
#  'URIDINE',
#  'C61H100N1O6',
#  'EDTA',
#  'RESORCINOL',
#  'C49H98N1O6',
#  'C50H99N1O13P1',
#  'ISRADIPINE',
#  'C42H81N1O7P1',
#  'C35H69N1O8P1',
#  'LINEZOLID',
#  'HYOSCYAMINE',
#  'C38H76N1O3',
#  'AMT',
#  'C51H98N1O6',
#  'INOSINE',
#  'TOSYLATE',
#  'ALPE',
#  'TAUROLITHOCHOLATE',
#  'LACTATE',
#  'C42H75N1O10P1',
#  'C36H70O8P1',
#  'SARCOSINE',
#  'C46H73N1O10P1',
#  'C40H74N1O8',
#  'C46H83N1O10P1',
#  'GUAIAZULENE',
#  'ALLOTHREONINE',
#  'C59H98N1O6',
#  'MMV687807',
#  'GALACTOSE',
#  'HTMT',
#  'THYMINE',
#  'FRUCTOSE',
#  'DIPHENYLCARBAZIDE',
#  'C39H79N1O7P1',
#  'C36H70N1O5',
#  'C43H84N1O5',
#  'C25H41N1O7P1',
#  'SOLASODINE',
#  'C40H78N1O5',
#  'CLOTHIANIDINE',
#  'RF',
#  'C48H76O10P1',
#  'C40H73N1O10P1',
#  'C61H108N1O6',
#  'C57H94N1O6',
#  'RIBOFLAVIN',
#  'SORBOSE',
#  'C25H48O9P1',
#  'C53H94N1O6',
#  'C43H76O8P1',
#  'C45H92N2O6P1',
#  'C44H85N1O8P1',
#  'C39H76N1O12S1',
#  'URACIL',
#  'MMV688978',
#  'C35H68O8P1',
#  'BETAINE',
#  'C45H84O13P1',
#  'TETRAHYDRATE',
#  'HYDROXYPHENYLLACTATE',
#  'C38H78N1O4',
#  'C54H96N1O6',
#  'MELATONIN',
#  'C37H72N1O3',
#  'C11H12O4',
#  'C41H78N1O5',
#  'C25H49N1O7P1',
#  'DEOXYCARNITINE',
#  'TC1',
#  'C28H59N1O7P1',
#  'RALTITREXED',
#  'METAMITRON',
#  'C45H82N1O2',
#  'C46H91N1O13P1',
#  'C40H72N1O8',
#  'C62H112N1O6',
#  'DETHIOBIOTIN',
#  'HOMOVANILLATE',
#  'B27A17',
#  'ACETYLCHOLINE',
#  'ADIPATE',
#  'PALMITOYLCARNITINE',
#  'PIRIMICARB',
#  'C51H96N1O6',
#  'C53H90N1O6',
#  'C51H98N1O15',
#  'C43H78N1O12S1',
#  'HNP1',
#  'ASPARTATE',
#  'C63H102N1O6',
#  'C42H85N1O8P1',
#  'B12A13',
#  'CoA',
#  'KOBUSONE',
#  'C16H34N1O2',
#  'C47H88O13P1',
#  'C59H100N1O6',
#  'B23A33',
#  'PYRROMYCIN',
#  'SPIRAMYCIN',
#  'UROCANATE',
#  'FLUDARABINE',
#  'DEOXYRIBOSE',
#  'PHTHALATE',
#  'SELENOCYSTAMINE',
#  'ACONITATE',
#  'BALSALAZIDE',
#  'C38H70N1O5',
#  'FLUBENDAZOLE',
#  'NARCOTIN',
#  'C57H106N1O6',
#  'C36H73N1O7P1',
#  'C48H79N1O8P1',
#  'MBOA',
#  'C45H86N1O15',
#  'C50H94N1O8',
#  'C51H100N1O6',
#  'C65H114N1O6',
#  'G6P',
#  'C40H70O10P1',
#  'C41H80N1O3',
#  'C39H71N1O8P1',
#  'C50H96N1O8',
#  'HX',
#  'C27H52O12P1',
#  'HCl',
#  'C20H39N1O7P1',
#  'B27A19',
#  'C48H95N1O8P1',
#  'C45H85N1O8P1',
#  'XANTHINE',
#  'C44H73N1O10P1',
#  'C43H82N1O12S1',
#  'RIFAPENTINE',
#  'C40H78N1O7',
#  'C59H118N1O6',
#  'C39H74N1O5',
#  'AMLEXANOX',
#  'C41H78N1O3',
#  'HYPEROSIDE',
#  'TC4',
#  'C63H112N1O6',
#  'C40H75N1O8P1',
#  'C46H92N1O6',
#  'C43H85N1O8P1',
#  'DINOTEFURAN',
#  'RESERPINE',
#  'C38H78N1O3',
#  'CAPENSIN',
#  'ALFUZOSIN',
#  'C41H76N1O5',
#  'C60H116N1O6',
#  'C37H74N2O6P1',
#  'C43H77N1O8P1',
#  'HYDROCORTISONE',
#  'VALINE',
#  'C24H44O9P1',
#  'C53H86N1O15',
#  'ADpSGEGDFXAEGGGVR',
#  'C49H90N1O15',
#  'C39H78N1O6',
#  'STRYCHNINE',
#  'TRIDESACETOXYKHIVORIN',
#  'C52H104N1O6',
#  'C29H52O12P1',
#  'AVOCADYNE',
#  'C42H72O10P1',
#  'THIAZOPYR',
#  'C59H112N1O6',
#  'QUINMERAC',
#  'SORBATE',
#  'C44H87N1O7P1',
#  'C37H74N1O5',
#  'B13A13',
#  'RHAMNOSE',
#  'GPoPE',
#  'C52H103N1O13P1',
#  'C43H80O13P1',
#  'C48H80O10P1',
#  'UNL',
#  'PLM',
#  'C63H114N1O6',
#  'C41H69N1O8P1',
#  'C47H94N1O6',
#  'C30H51N1O7P1',
#  'C44H90N2O6P1',
#  'C49H95N1O8P1',
#  'DACTINOMYCIN',
#  'C34H70N1O5',
#  'C42H82N1O8',
#  'MMV676191',
#  'TADALAFIL',
#  'VIII',
#  'C52H103N1O8P1',
#  'DIMETHOMORF',
#  'SPERMINE',
#  'HYDROBROMIDE',
#  'FACTOR',
#  'MMV688124',
#  'PLATYPHYLLENONE',
#  'C59H90N1O6',
#  'MMV188296',
#  'C30H55N1O7P1',
#  'C42H79N1O8P1',
#  'MMV676444',
#  'C54H98N1O6',
#  'C35H64O8P1',
#  'B26A24',
#  'HIPPURATE',
#  'C44H90N1O3',
#  'CORTICOSTERONE',
#  'C40H74O10P1',
#  'FINASTERIDE',
#  'THIABENDAZOLE',
#  'C35H72N1O5',
#  'C32H67N1O7P1',
#  'C61H116N1O6',
#  'PTERINE',
#  'AMCINONIDE',
#  'C40H77N1O8P1',
#  'DMSA',
#  'C51H100N1O15',
#  'METHYLGUANIDINE',
#  'C54H100N1O6',
#  'MMV676476',
#  'TRIFLUOPERAZINE',
#  'MMV676431',
#  'TPS',
#  'DNDI1246774',
#  'HCL',
#  'DOFETILIDE',
#  'MMV688371',
#  'C47H85N1O8P1',
#  'C46H89N1O8P1',
#  'CHENODEOXYCHOLATE',
#  'C61H96N1O6',
#  'EGCG',
#  'C59H96N1O6',
#  'C47H81N1O8P1',
#  'C48H85N1O8P1',
#  'C45H80N1O5',
#  'C81H135O17P2',
#  'C44H81N1O7P1',
#  'GLYCOCHOLATE',
#  'C36H72N1O3',
#  'MALATE',
#  'FERULATE',
#  'METHIONINE',
#  'C47H90N1O15',
#  'B21A19',
#  'C46H88N1O7',
#  'CYSTATHIONINE',
#  'C41H71N1O7P1',
#  'C40H79N1O7P1',
#  'C65H108N1O6',
#  'C51H90N1O15',
#  'C38H73N1O8P1',
#  'MMV689028',
#  'C43H72O8P1',
#  'BENZALDEHYDE',
#  'C45H87N1O7P1',
#  'MIY',
#  'COUMARIN',
#  'GLYCOCHENODEOXYCHOLATE',
#  'C65H100N1O6',
#  'C50H89N1O8P1',
#  'PIPERINE',
#  'C44H82N1O8',
#  'C69H104N1O6',
#  'C41H83N1O7P1',
#  'CLP',
#  'OA',
#  'C57H104N1O6',
#  'C44H86N1O12S1',
#  'B28A22',
#  'C44H82O13P1',
#  'LEVODOPA',
#  'MONOPHOSPHATE',
#  'MMV687273',
#  'C50H75N1O10P1',
#  'OUABAIN',
#  'SPERMIDINE',
#  'C26H55N1O6P1',
#  'DNDI1246784',
#  'C47H78O13P1',
#  'PLP',
#  'C42H78N1O8',
#  'C39H74O8P1',
#  'CYSTINE',
#  'C45H74O10P1',
#  'PHENOBARBITAL',
#  'PYRIDOXAMINE',
#  'BENZOATE',
#  'TRIIODOTHYRONINE',
#  'C22H47N1O7P1',
#  'DISULFIDE',
#  'C48H95N1O12P1',
#  'HISTIDINE',
#  'C37H76N1O5',
#  'C63H122N1O6',
#  'B28A24',
#  'C37H78N2O6P1',
#  'C47H79N1O8P1',
#  'C24H49N1O7P1',
#  'IIB',
#  'C46H83N1O7P1',
#  'FARNESOL',
#  'HEMISUCCINATE',
#  'TREHALOSE',
#  'C40H75N1O10P1',
#  'C49H92N1O15',
#  'C13H17O3',
#  'C57H102N1O6',
#  'C53H88N1O6',
#  'C38H77N1O8P1',
#  'NOA407475',
#  'HORMONE',
#  'C21H44N1O4',
#  'C37H75N1O8P1',
#  'C37H70O10P1',
#  'TPA',
#  'C45H77N1O8P1',
#  'ATROPINE',
#  'IDEBENONE',
#  'C44H84N1O8',
#  'C41H80N2O6P1',
#  'MONOHYDRATE',
#  'URSODIOL',
#  'C60H108N1O6',
#  'C38H79N1O7P1',
#  'PHENYLETHANOLAMINE',
#  'C49H79N1O8P1',
#  'C51H94N1O15',
#  'AC4464',
#  'C40H76N1O5',
#  'DEOXYADENOSINE',
#  'C53H100N1O6',
#  'CLOFAZIMINE',
#  'C61H112N1O6',
#  'C47H83N1O7P1',
#  'NAFTOPIDIL',
#  'C47H83N1O8P1',
#  'ZAFIRLUKAST',
#  'C45H77N1O7P1',
#  'MESYLATE',
#  'C35H70N1O5',
#  'C41H72N1O5',
#  'C46H78O13P1',
#  'ETHER',
#  'C39H68N1O5',
#  'ENALAPRILAT',
#  'SALSOLINOL',
#  'C56H110N1O6',
#  'C51H86N1O15',
#  'GLECHOMAFURAN',
#  'GLUCOSAMINATE',
#  'C49H78O13P1',
#  'RIMSULFURON',
#  'C49H88O13P1',
#  'C46H85N1O10P1',
#  'B12A22',
#  'C46H77N1O10P1',
#  'C39H68O10P1',
#  'PROPYZAMIDE',
#  'BX',
#  'C43H73N1O7P1',
#  'C51H82O13P1',
#  'C54H104N1O6',
#  'MMV688271',
#  'SUCROSE',
#  'C43H84N1O12S1',
#  'C60H112N1O6',
#  'C55H100N1O6',
#  'MMV146306',
#  'C45H89N1O8P1',
#  'MELIBIOSE',
#  'MMV688798',
#  'SORBITOL',
#  'C41H84N1O5',
#  'TYROSINE',
#  'MMV689709',
#  'CYTOSINE',
#  'C87H139O17P2',
#  'THEOBROMINE',
#  'C44H88N1O4',
#  'C37H71N1O7P1',
#  'C43H78O13P1',
#  'SKF',
#  'C26H49N1O7P1',
#  'C46H80O10P1',
#  'C24H51N1O6P1',
#  'CINNAMATE',
#  'C45H78N1O12S1',
#  'LATANOPROST',
#  'C24H47N1O9P1',
#  'C46H81N1O8P1',
#  'TSC',
#  'C58H108N1O6',
#  'NAD',
#  'NABUMETONE',
#  'HYPOXANTHINE',
#  ...]

# %% [markdown]
# ## Clean (and extend) metadata
#
# ### 1) Harmization
# + Here, undefiend entries will be harmonized (instead of having a huge variation of None,"", "N/A" etc.)
# + The ``repair_inchi_inchikey_smiles`` function will correct misplaced metadata (e.g. inchikeys entered as inchi etc.) and harmonize the entry strings.

# %%
from tqdm.notebook import tqdm
from matchms.filtering import harmonize_undefined_inchikey, harmonize_undefined_inchi, harmonize_undefined_smiles
from matchms.filtering import repair_inchi_inchikey_smiles

def clean_metadata(s):
    s = harmonize_undefined_inchikey(s)
    s = harmonize_undefined_inchi(s)
    s = harmonize_undefined_smiles(s)
    s = repair_inchi_inchikey_smiles(s)
    return s

spectrums = [clean_metadata(s) for s in tqdm(spectrums)]

# %%
count_annotations(spectrums)
# Out:
# Inchis: 138059 -- 14901 unique
# Smiles: 100075 -- 23061 unique
# Inchikeys: 452 -- 303 unique (first 14 characters)

# %% [markdown]
# ### 2) Convert entries where possible
# Where possible (and necessary, i.e. missing): Convert between smiles, inchi, inchikey to complete metadata. This is done using functions from rdkit.

# %%
from tqdm.notebook import tqdm
from matchms.filtering import derive_inchi_from_smiles, derive_smiles_from_inchi
from matchms.filtering import derive_inchikey_from_inchi

def clean_metadata2(s):
    s = derive_inchi_from_smiles(s)
    s = derive_smiles_from_inchi(s)
    s = derive_inchikey_from_inchi(s)
    return s

spectrums = [clean_metadata2(s) for s in tqdm(spectrums)]
# Out:
#   0%|          | 0/210407 [00:00<?, ?it/s]

# %%
count_annotations(spectrums)
# Out:
# Inchis: 149639 -- 19520 unique
# Smiles: 149232 -- 27401 unique
# Inchikeys: 149202 -- 16427 unique (first 14 characters)

# %%
pickle.dump(spectrums, 
            open(os.path.join(path_data, 'GNPS_all', 'ALL_GNPS_cleaned_by_matchms.pickle'), "wb"))

# %%
import pickle
outfile = os.path.join(path_data, 'GNPS_all', 'ALL_GNPS_cleaned_by_matchms.pickle')
with open(outfile, 'rb') as file:
    spectrums = pickle.load(file)

# %%
count_annotations(spectrums)
# Out:
# Inchis: 149639 -- 19520 unique
# Smiles: 149232 -- 27401 unique
# Inchikeys: 149202 -- 16427 unique (first 14 characters)

# %% [markdown]
# ## Run spectra with missing SMILES/InChI against PubChem
#
# - Using function from `matchmsextras` which can be installed with `pip install matchmsextras`

# %%
final_names = []
for spectrum in tqdm(spectrums):
    name_original = spectrum.get("compound_name")
    name = name_original.replace("F dial M", "")
    # Remove last word if likely not correct:
    if name.split(" ")[-1] in ["M", "M?", "?", "M+2H/2", "MS34+Na", "M]", "Cat+M]", "Unk", "--"]:
        name = " ".join(name.split(" ")[:-1]).strip()
    if name != name_original:
        final_names.append((name_original, name))
        print(f"Changed compound name from {name_original} to {name}.")
        spectrum.set("compound_name", name)

# %%
from matchmsextras.pubchem_lookup import lookup_metadata_completion

spectrums_lookup = []
for i, s in enumerate(tqdm(spectrums)):
    spectrums_lookup.append(lookup_metadata_completion(s, search_depth=10))

# %%
count_annotations(spectrums)
# Out:
# Inchis: 184755 -- 22494 unique
# Smiles: 184718 -- 29919 unique
# Inchikeys: 184698 -- 17738 unique (first 14 characters)

# %%
pickle.dump(spectrums_lookup, 
            open(os.path.join(path_data, 'GNPS_all', 'ALL_GNPS_matchms_manual_pubchem.pickle'), "wb"))

# %% [markdown]
# ### To import the cleaned data:

# %%
import pickle
outfile = os.path.join(path_data, 'GNPS_all', 'ALL_GNPS_matchms_manual_pubchem.pickle')
with open(outfile, 'rb') as file:
    spectrums = pickle.load(file)

# %%
#from matchms.exporting import save_as_msp
filename = os.path.join(path_data, "GNPS_all",
                        "ALL_GNPS_210125_matchms_pubchem_cleaned.msp")  
save_as_msp(spectrums, filename)

# %%
len(spectrums), spectrums[0].get("ionmode")
# Out:
# (210407, 'positive')

# %%
for spec in spectrums:
    if spec.get("adduct") in ['[M+CH3COO]-/[M-CH3]-',
                             '[M-H]-/[M-Ser]-',
                             '[M-CH3]-']:
        if spec.get("ionmode") != "negative":
            spec.set("ionmode", "negative")

# %%
spectrums_positive = []
spectrums_negative = []
for i, spec in enumerate(spectrums):
    if spec.get("ionmode") == "positive":
        spectrums_positive.append(spec)
    elif spec.get("ionmode") == "negative":
        spectrums_negative.append(spec)
    else:
        print(f"No ionmode found for spectrum {i} ({spec.get('ionmode')})")
# Out:
# No ionmode found for spectrum 152657 (n/a)
# No ionmode found for spectrum 152712 (n/a)
# No ionmode found for spectrum 156170 (n/a)
# No ionmode found for spectrum 156189 (n/a)
# No ionmode found for spectrum 158895 (n/a)
# No ionmode found for spectrum 158896 (n/a)
# No ionmode found for spectrum 160921 (n/a)

# %%
len(spectrums_negative), len(spectrums_positive)
# Out:
# (65709, 144691)

# %%
len(spectrums) - (len(spectrums_negative) + len(spectrums_positive))
# Out:
# 7

# %%
pickle.dump(spectrums_negative, 
            open(os.path.join(path_data, 'GNPS_all', 'ALL_GNPS_210125_negative_cleaned.pickle'), "wb"))

# %%
pickle.dump(spectrums_positive, 
            open(os.path.join(path_data, 'GNPS_all', 'ALL_GNPS_210125_positive_cleaned.pickle'), "wb"))

# %%
count_annotations(spectrums_positive)
# Out:
# Inchis: 123908 -- 19500 unique
# Smiles: 123885 -- 24606 unique
# Inchikeys: 123866 -- 15489 unique (first 14 characters)

# %%
len(spectrums_positive)
# Out:
# 144691

# %% [markdown]
# ## Many spectra contain very few peaks!
# - We here remove spectra with less than 5 peaks with m/z values in the range between 10.0 and 1000.0 Da
# - We then make another subselection of only spectra which are fully annotated (InChIKey + SMILES/InChI)

# %%
number_of_peaks = np.array([len(s.peaks) for s in spectrums_positive])

# %%
print(f"{np.sum(number_of_peaks < 5)} spectra have < 5 peaks")
# Out:
# 15215 spectra have < 5 peaks

# %%
from matchms.filtering import select_by_mz
from matchms.filtering import normalize_intensities
from matchms.filtering import require_minimum_number_of_peaks

def minimal_processing(spectrum):
    spectrum = normalize_intensities(spectrum)
    spectrum = select_by_mz(spectrum, mz_from=10.0, mz_to=1000.0)
    spectrum = require_minimum_number_of_peaks(spectrum, n_required=5)
    return spectrum

# %%
spectrums_pos_processing = [minimal_processing(s) for s in spectrums_positive]
spectrums_pos_processing = [s for s in spectrums_pos_processing if s is not None]
count_annotations(spectrums_pos_processing)
# Out:
# Inchis: 109775 -- 18686 unique
# Smiles: 109751 -- 23726 unique
# Inchikeys: 109739 -- 15062 unique (first 14 characters)

# %%
pickle.dump(spectrums_pos_processing, 
            open(os.path.join(path_data, 'GNPS_all', 'ALL_GNPS_210125_positive_processed.pickle'), "wb"))
len(spectrums_pos_processing)
# Out:
# 129411

# %% [markdown]
# ## Creating a subselection with only fully annotated spectra
# - all annotated with InChIKey + SMILES and/or InChI
# - all with >= 5 peaks with m/z between 10.0 and 1000.0 Da
# - all positive ionization mode

# %%
spectrums_pos_annotated = []
for spec in spectrums_pos_processing:
    inchikey = spec.get("inchikey")
    if inchikey is not None and len(inchikey)>13:
        if spec.get("smiles") or spec.get("inchi"):
            spectrums_pos_annotated.append(spec)

len(spectrums_pos_annotated)
# Out:
# 109734

# %%
count_annotations(spectrums_pos_annotated)
# Out:
# Inchis: 109734 -- 18671 unique
# Smiles: 109734 -- 23710 unique
# Inchikeys: 109734 -- 15062 unique (first 14 characters)

# %%
pickle.dump(spectrums_pos_processing, 
            open(os.path.join(path_data, 'GNPS_all', 'ALL_GNPS_210125_positive_processed_annotated.pickle'), "wb"))
len(spectrums_pos_processing)

# %% [markdown]
# # Optimize feature selection
# Many different features were calculated (49 in total). In this notebook we try different combinations of these features, to select the best combination.
# Also different weighting methods are selected for the "chemical neighbourhood score"
#
# Different models trained are in order:
#
# Run with 30 features for similar structures, without chemical neighbourhood score
# Duplicate score to check how random forest behaves
# Results training with cos scores

# %% [markdown]
# # IMPORTANT NOTE:
# This notebook will only run in the github branch add_cosine_to_features

# %% [markdown]
# ### Load in scores

# %%
import os
from ms2query.utils import load_pickled_file
from matplotlib import pyplot as plt
# Out:
# c:\users\jonge094\anaconda3\envs\ms2query\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
training_scores, training_labels, validation_scores, validation_labels = load_pickled_file("C:/Users/jonge094/PycharmProjects/PhD_MS2Query/ms2query/data/libraries_and_models/gnps_15_12_2021/ms2q_training_data_with_additional_weigthing_scores.pickle")

# %%
print(training_scores.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 56 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   query_precursor_mz                                       467600 non-null  float64
#  1   precursor_mz_difference                                  467600 non-null  float64
#  2   s2v_score                                                467600 non-null  float64
#  3   ms2ds_score                                              467600 non-null  float64
#  4   average_ms2ds_score_for_inchikey14                       467600 non-null  float64
#  5   nr_of_spectra_with_same_inchikey14                       467600 non-null  int64
#  6   chemical_neighbourhood_score                             467600 non-null  float64
#  7   average_tanimoto_score_for_chemical_neighbourhood_score  467600 non-null  float64
#  8   nr_of_spectra_for_chemical_neighbourhood_score           467600 non-null  int64
#  9   cosine_score                                             467600 non-null  float64
#  10  modified_cosine_score                                    467600 non-null  float64
#  11  lib_instrument_orbitrap                                  467600 non-null  int64
#  12  lib_instrument_ion_trap                                  467600 non-null  int64
#  13  lib_instrument_tof                                       467600 non-null  int64
#  14  lib_instrument_quadrupole                                467600 non-null  int64
#  15  query_instrument_orbitrap                                467600 non-null  int64
#  16  query_instrument_ion_trap                                467600 non-null  int64
#  17  query_instrument_tof                                     467600 non-null  int64
#  18  query_instrument_quadrupole                              467600 non-null  int64
#  19  average_ms2deepscore_0                                   467600 non-null  float64
#  20  tanimoto_score_structure_0                               467600 non-null  float64
#  21  nr_of_spectra_structure_0                                467600 non-null  int64
#  22  average_ms2deepscore_1                                   467600 non-null  float64
#  23  tanimoto_score_structure_1                               467600 non-null  float64
#  24  nr_of_spectra_structure_1                                467600 non-null  int64
#  25  average_ms2deepscore_2                                   467600 non-null  float64
#  26  tanimoto_score_structure_2                               467600 non-null  float64
#  27  nr_of_spectra_structure_2                                467600 non-null  int64
#  28  average_ms2deepscore_3                                   467600 non-null  float64
#  29  tanimoto_score_structure_3                               467600 non-null  float64
#  30  nr_of_spectra_structure_3                                467600 non-null  int64
#  31  average_ms2deepscore_4                                   467600 non-null  float64
#  32  tanimoto_score_structure_4                               467600 non-null  float64
#  33  nr_of_spectra_structure_4                                467600 non-null  int64
#  34  average_ms2deepscore_5                                   467600 non-null  float64
#  35  tanimoto_score_structure_5                               467600 non-null  float64
#  36  nr_of_spectra_structure_5                                467600 non-null  int64
#  37  average_ms2deepscore_6                                   467600 non-null  float64
#  38  tanimoto_score_structure_6                               467600 non-null  float64
#  39  nr_of_spectra_structure_6                                467600 non-null  int64
#  40  average_ms2deepscore_7                                   467600 non-null  float64
#  41  tanimoto_score_structure_7                               467600 non-null  float64
#  42  nr_of_spectra_structure_7                                467600 non-null  int64
#  43  average_ms2deepscore_8                                   467600 non-null  float64
#  44  tanimoto_score_structure_8                               467600 non-null  float64
#  45  nr_of_spectra_structure_8                                467600 non-null  int64
#  46  average_ms2deepscore_9                                   467600 non-null  float64
#  47  tanimoto_score_structure_9                               467600 non-null  float64
#  48  nr_of_spectra_structure_9                                467600 non-null  int64
#  49  chemical_neighbourhood_no_spectrum_nr_tanimoto_power1    467600 non-null  float64
#  50  chemical_neighbourhood_no_spectrum_nr_tanimoto_power2    467600 non-null  float64
#  51  chemical_neighbourhood_no_spectrum_nr_tanimoto_power3    467600 non-null  float64
#  52  chemical_neighbourhood_no_spectrum_nr_tanimoto_power4    467600 non-null  float64
#  53  chemical_neighbourhood_no_spectrum_nr_tanimoto_power5    467600 non-null  float64
#  54  chemical_neighbourhood_no_spectrum_nr_tanimoto_power0    467600 non-null  float64
#  55  chemical_neighbourhood_tanimoto_0                        467600 non-null  float64
# dtypes: float64(36), int64(20)
# memory usage: 199.8 MB
# None

# %% [markdown]
# # Test additional features
# Different features are tested in different steps. The order of the tests is given below:
# - Final selection of features
# - (modified) cosine score
# - Instrument types
# - Method for taking average of multiple library structures
# - Method for weighting average of multiple library structures

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def train_random_forest(training_scores, validation_scores):
    # train rf using optimised parameters from below

    rf = RandomForestRegressor(n_estimators = 250, 
                               random_state = 42, 
                               max_depth = 5, 
                               verbose=1,
                               min_samples_leaf=50,
                               n_jobs=7)
    rf.fit(selection_of_training_scores, training_labels)

    # predict on train
    rf_train_predictions = rf.predict(selection_of_training_scores)
    mse_train_rf = mean_squared_error(training_labels, rf_train_predictions)
    print('Training MSE', mse_train_rf)

    # predict on test
    rf_predictions = rf.predict(selection_of_validation_scores)
    mse_rf = mean_squared_error(validation_labels, rf_predictions)
    print('Validation MSE', mse_rf)

    # get feature importances
    importances = list(rf.feature_importances_)
    feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(selection_of_training_scores.columns, importances)]
    feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
    [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]

# %% [markdown]
# # Final selection of features
# The model trained with the final selection of features

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power0",
                            "average_tanimoto_score_for_chemical_neighbourhood_score"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 6 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   query_precursor_mz                                       467600 non-null  float64
#  1   precursor_mz_difference                                  467600 non-null  float64
#  2   s2v_score                                                467600 non-null  float64
#  3   ms2ds_score                                              467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power0    467600 non-null  float64
#  5   average_tanimoto_score_for_chemical_neighbourhood_score  467600 non-null  float64
# dtypes: float64(6)
# memory usage: 21.4 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_3400/843284625.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.5min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.02822048791511903
# Validation MSE 0.025649444294042374
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power0 Importance: 0.61
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.14
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# Variable: average_tanimoto_score_for_chemical_neighbourhood_score Importance: 0.01
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished

# %% [markdown]
# # (modified) cosine score
# The cosine and modified cosine score are added as features.

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power0",
                            "cosine_score",
                            "modified_cosine_score"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 7 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power0  467600 non-null  float64
#  5   cosine_score                                           467600 non-null  float64
#  6   modified_cosine_score                                  467600 non-null  float64
# dtypes: float64(7)
# memory usage: 25.0 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_3400/843284625.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.7min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.2s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.028244165570602768
# Validation MSE 0.025764406064172858
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power0 Importance: 0.61
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.14
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# Variable: cosine_score         Importance: 0.0
# Variable: modified_cosine_score Importance: 0.0
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished

# %% [markdown]
# ### Cosine without other scores

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "cosine_score",
                            "modified_cosine_score"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   query_precursor_mz       467600 non-null  float64
#  1   precursor_mz_difference  467600 non-null  float64
#  2   cosine_score             467600 non-null  float64
#  3   modified_cosine_score    467600 non-null  float64
# dtypes: float64(4)
# memory usage: 14.3 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_10312/2359213779.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:   47.2s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.03624574130161057
# Validation MSE 0.034595751645214
# Variable: query_precursor_mz   Importance: 0.56
# Variable: precursor_mz_difference Importance: 0.4
# Variable: cosine_score         Importance: 0.03
# Variable: modified_cosine_score Importance: 0.02
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished
# [None, None, None, None]

# %% [markdown]
# # Instrument type
# The instrument type of the query and library spectrum are given as features.

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power0",
                            "lib_instrument_orbitrap",
                            "lib_instrument_ion_trap",
                            "lib_instrument_tof",
                            "lib_instrument_quadrupole",
                            "query_instrument_orbitrap",
                            "query_instrument_ion_trap",
                            "query_instrument_tof",
                            "query_instrument_quadrupole"
                            ]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 13 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power0  467600 non-null  float64
#  5   lib_instrument_orbitrap                                467600 non-null  int64
#  6   lib_instrument_ion_trap                                467600 non-null  int64
#  7   lib_instrument_tof                                     467600 non-null  int64
#  8   lib_instrument_quadrupole                              467600 non-null  int64
#  9   query_instrument_orbitrap                              467600 non-null  int64
#  10  query_instrument_ion_trap                              467600 non-null  int64
#  11  query_instrument_tof                                   467600 non-null  int64
#  12  query_instrument_quadrupole                            467600 non-null  int64
# dtypes: float64(5), int64(8)
# memory usage: 46.4 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_3400/843284625.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.3min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.028262590756230818
# Validation MSE 0.025694134516425868
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power0 Importance: 0.61
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.14
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# Variable: lib_instrument_orbitrap Importance: 0.0
# Variable: lib_instrument_ion_trap Importance: 0.0
# Variable: lib_instrument_tof   Importance: 0.0
# Variable: lib_instrument_quadrupole Importance: 0.0
# Variable: query_instrument_orbitrap Importance: 0.0
# Variable: query_instrument_ion_trap Importance: 0.0
# Variable: query_instrument_tof Importance: 0.0
# Variable: query_instrument_quadrupole Importance: 0.0
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished

# %% [markdown]
# # Compare average on structure vs average on spectra

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power0",
                           "chemical_neighbourhood_tanimoto_0"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 6 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power0  467600 non-null  float64
#  5   chemical_neighbourhood_tanimoto_0                      467600 non-null  float64
# dtypes: float64(6)
# memory usage: 21.4 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_24424/696082445.py:22: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.3min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.028238497618477378
# Validation MSE 0.025736053101000977
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power0 Importance: 0.61
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.14
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# Variable: chemical_neighbourhood_tanimoto_0 Importance: 0.0
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished
# [None, None, None, None, None, None]

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                           "chemical_neighbourhood_tanimoto_0"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   query_precursor_mz                 467600 non-null  float64
#  1   precursor_mz_difference            467600 non-null  float64
#  2   s2v_score                          467600 non-null  float64
#  3   ms2ds_score                        467600 non-null  float64
#  4   chemical_neighbourhood_tanimoto_0  467600 non-null  float64
# dtypes: float64(5)
# memory usage: 17.8 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_24424/389796848.py:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.2min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.8s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.03014091876604286
# Validation MSE 0.028607621186213544
# Variable: chemical_neighbourhood_tanimoto_0 Importance: 0.54
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.17
# Variable: s2v_score            Importance: 0.1
# Variable: ms2ds_score          Importance: 0.02
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished
# [None, None, None, None, None]

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power0"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 5 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power0  467600 non-null  float64
# dtypes: float64(5)
# memory usage: 17.8 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_24424/2283961063.py:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:   51.5s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.7s finished
# Training MSE 0.02826842554510124
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.1s finished
# Validation MSE 0.02571552323007786
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power0 Importance: 0.61
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.14
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# [None, None, None, None, None]

# %% [markdown]
# # Weigthing of averge of multiple library scores

# %% [markdown]
# ### Adding additional features
# The different weighting methods were calculated with the functions below, but are currently already stored in the file loaded in the first step of this notebook

# %%
from tqdm.notebook import tqdm

def add_different_weighting(dataframe, power_tanimioto):
    new_score = []
    for index, row in tqdm(dataframe.iterrows()):
        total_weight = 0
        total_ms2ds = 0 
        for i in range(10):
            average_ms2ds = row["average_ms2deepscore_" + str(i)]
            tanimoto_score = row["tanimoto_score_structure_" + str(i)]
            nr_of_spectra = row["nr_of_spectra_structure_" + str(i)]
            weight = nr_of_spectra * tanimoto_score**power_tanimioto
            total_weight += weight
            weighted_score = average_ms2ds * weight
            total_ms2ds += weighted_score
        average = total_ms2ds/total_weight
        new_score.append(average)
    dataframe["chemical_neighbourhood_tanimoto_"+str(power_tanimioto)] = new_score

# %%
from tqdm.notebook import tqdm

def no_nr_of_spectra_filtering(dataframe, power_tanimioto):
    new_score = []
    for index, row in tqdm(dataframe.iterrows()):
        total_weight = 0
        total_ms2ds = 0 
        for i in range(10):
            average_ms2ds = row["average_ms2deepscore_" + str(i)]
            tanimoto_score = row["tanimoto_score_structure_" + str(i)]
            weight = tanimoto_score**power_tanimioto
            total_weight += weight
            weighted_score = average_ms2ds * weight
            total_ms2ds += weighted_score
        average = total_ms2ds/total_weight
        new_score.append(average)
    dataframe["chemical_neighbourhood_no_spectrum_nr_tanimoto_power"+str(power_tanimioto)] = new_score

# %%
no_nr_of_spectra_filtering(training_scores, 1)
no_nr_of_spectra_filtering(validation_scores, 1)
no_nr_of_spectra_filtering(training_scores, 2)
no_nr_of_spectra_filtering(validation_scores, 2)
no_nr_of_spectra_filtering(training_scores, 3)
no_nr_of_spectra_filtering(validation_scores, 3)
no_nr_of_spectra_filtering(training_scores, 4)
no_nr_of_spectra_filtering(validation_scores, 4)
no_nr_of_spectra_filtering(training_scores, 5)
no_nr_of_spectra_filtering(validation_scores, 5)
no_nr_of_spectra_filtering(training_scores, 0)
no_nr_of_spectra_filtering(validation_scores, 0)
add_different_weighting(training_scores, 0)
add_different_weighting(validation_scores, 0)

# %% [markdown]
# ### Use all features in one model

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power0",
                           "chemical_neighbourhood_no_spectrum_nr_tanimoto_power1",
                           "chemical_neighbourhood_no_spectrum_nr_tanimoto_power2",
                           "chemical_neighbourhood_no_spectrum_nr_tanimoto_power3",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power4",
                              "chemical_neighbourhood_no_spectrum_nr_tanimoto_power5"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 10 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power0  467600 non-null  float64
#  5   chemical_neighbourhood_no_spectrum_nr_tanimoto_power1  467600 non-null  float64
#  6   chemical_neighbourhood_no_spectrum_nr_tanimoto_power2  467600 non-null  float64
#  7   chemical_neighbourhood_no_spectrum_nr_tanimoto_power3  467600 non-null  float64
#  8   chemical_neighbourhood_no_spectrum_nr_tanimoto_power4  467600 non-null  float64
#  9   chemical_neighbourhood_no_spectrum_nr_tanimoto_power5  467600 non-null  float64
# dtypes: float64(10)
# memory usage: 35.7 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_3400/843284625.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:   24.5s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  2.3min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.028228783148908698
# Validation MSE 0.025983753544486
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power1 Importance: 0.46
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.14
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power0 Importance: 0.12
# Variable: s2v_score            Importance: 0.05
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power2 Importance: 0.03
# Variable: ms2ds_score          Importance: 0.02
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power3 Importance: 0.0
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power4 Importance: 0.0
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power5 Importance: 0.0
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished

# %% [markdown]
# ### Use different weighting one by one

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power0"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 5 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power0  467600 non-null  float64
# dtypes: float64(5)
# memory usage: 17.8 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_3400/843284625.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.1min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.02826842554510124
# Validation MSE 0.02571552323007786
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power0 Importance: 0.61
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.14
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power1"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 5 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power1  467600 non-null  float64
# dtypes: float64(5)
# memory usage: 17.8 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_10312/2325191212.py:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.1min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.028375345962102953
# Validation MSE 0.026004592509868557
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power1 Importance: 0.61
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.14
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished
# [None, None, None, None, None]

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power2"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 5 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power2  467600 non-null  float64
# dtypes: float64(5)
# memory usage: 17.8 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_3400/843284625.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   56.4s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.3min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.0s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.02859209987438069
# Validation MSE 0.026239289479840083
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power2 Importance: 0.61
# Variable: precursor_mz_difference Importance: 0.17
# Variable: query_precursor_mz   Importance: 0.15
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished

# %%
subselection_of_features = ["query_precursor_mz",
                            "precursor_mz_difference",
                            "s2v_score",
                            "ms2ds_score",
                            "chemical_neighbourhood_no_spectrum_nr_tanimoto_power3"]
selection_of_training_scores = training_scores[subselection_of_features]
selection_of_validation_scores = validation_scores[subselection_of_features]
selection_of_training_scores.info()
train_random_forest(selection_of_training_scores, selection_of_validation_scores)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467600 entries, 0 to 467599
# Data columns (total 5 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   query_precursor_mz                                     467600 non-null  float64
#  1   precursor_mz_difference                                467600 non-null  float64
#  2   s2v_score                                              467600 non-null  float64
#  3   ms2ds_score                                            467600 non-null  float64
#  4   chemical_neighbourhood_no_spectrum_nr_tanimoto_power3  467600 non-null  float64
# dtypes: float64(5)
# memory usage: 17.8 MB
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_3400/843284625.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selection_of_training_scores, training_labels)
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:   55.6s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:  1.2min finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    1.4s finished
# [Parallel(n_jobs=7)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  36 tasks      | elapsed:    0.0s
# Training MSE 0.02900090331946365
# Validation MSE 0.02658879720884346
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power3 Importance: 0.61
# Variable: query_precursor_mz   Importance: 0.17
# Variable: precursor_mz_difference Importance: 0.17
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.0
# [Parallel(n_jobs=7)]: Done 186 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=7)]: Done 250 out of 250 | elapsed:    0.2s finished

# %% [markdown]
# # Additional runs not structured

# %% [markdown]
# ### Run on all scores

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# train rf using optimised parameters from below

rf = RandomForestRegressor(n_estimators = 250, 
                           random_state = 42, 
                           max_depth = 5, 
                           verbose=1,
                           min_samples_leaf=50,
                           n_jobs=-1)
rf.fit(training_scores, training_labels)

# predict on train
rf_train_predictions = rf.predict(training_scores)
mse_train_rf = mean_squared_error(training_labels, rf_train_predictions)
print('Training MSE', mse_train_rf)

# predict on test
rf_predictions = rf.predict(validation_scores)
mse_rf = mean_squared_error(validation_labels, rf_predictions)
print('Validation MSE', mse_rf)

# get feature importances
importances = list(rf.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(training_scores.columns, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
# Out:
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_35220/278076265.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(training_scores, training_labels)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  9.4min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# Training MSE 0.028084835705205147
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.4s finished
# Validation MSE 0.02558998386978749
# Variable: chemical_neighbourhood_no_spectrum_nr_tanimoto_power1 Importance: 0.6
# Variable: precursor_mz_difference Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.13
# Variable: s2v_score            Importance: 0.05
# Variable: ms2ds_score          Importance: 0.02
# Variable: tanimoto_score_structure_5 Importance: 0.01
# Variable: average_ms2deepscore_7 Importance: 0.01
# Variable: average_ms2ds_score_for_inchikey14 Importance: 0.0
# Variable: nr_of_spectra_with_same_inchikey14 Importance: 0.0
# Variable: chemical_neighbourhood_score Importance: 0.0
# Variable: average_tanimoto_score_for_chemical_neighbourhood_score Importance: 0.0
# Variable: nr_of_spectra_for_chemical_neighbourhood_score Importance: 0.0
# Variable: cosine_score         Importance: 0.0
# Variable: modified_cosine_score Importance: 0.0
# Variable: lib_instrument_orbitrap Importance: 0.0
# Variable: lib_instrument_ion_trap Importance: 0.0
# Variable: lib_instrument_tof   Importance: 0.0
# Variable: lib_instrument_quadrupole Importance: 0.0
# Variable: query_instrument_orbitrap Importance: 0.0
# Variable: query_instrument_ion_trap Importance: 0.0
# Variable: query_instrument_tof Importance: 0.0
# Variable: query_instrument_quadrupole Importance: 0.0
# Variable: average_ms2deepscore_0 Importance: 0.0
# Variable: tanimoto_score_structure_0 Importance: 0.0
# Variable: nr_of_spectra_structure_0 Importance: 0.0
# Variable: average_ms2deepscore_1 Importance: 0.0
# Variable: tanimoto_score_structure_1 Importance: 0.0
# Variable: nr_of_spectra_structure_1 Importance: 0.0
# Variable: average_ms2deepscore_2 Importance: 0.0
# Variable: tanimoto_score_structure_2 Importance: 0.0
# Variable: nr_of_spectra_structure_2 Importance: 0.0
# Variable: average_ms2deepscore_3 Importance: 0.0
# Variable: tanimoto_score_structure_3 Importance: 0.0
# Variable: nr_of_spectra_structure_3 Importance: 0.0
# Variable: average_ms2deepscore_4 Importance: 0.0
# Variable: tanimoto_score_structure_4 Importance: 0.0
# Variable: nr_of_spectra_structure_4 Importance: 0.0
# Variable: average_ms2deepscore_5 Importance: 0.0
# Variable: nr_of_spectra_structure_5 Importance: 0.0
# Variable: average_ms2deepscore_6 Importance: 0.0
# Variable: tanimoto_score_structure_6 Importance: 0.0
# Variable: nr_of_spectra_structure_6 Importance: 0.0
# Variable: tanimoto_score_structure_7 Importance: 0.0
# Variable: nr_of_spectra_structure_7 Importance: 0.0
# Variable: average_ms2deepscore_8 Importance: 0.0
# Variable: tanimoto_score_structure_8 Importance: 0.0
# Variable: nr_of_spectra_structure_8 Importance: 0.0
# Variable: average_ms2deepscore_9 Importance: 0.0
# Variable: tanimoto_score_structure_9 Importance: 0.0
# Variable: nr_of_spectra_structure_9 Importance: 0.0
# Variable: chemical_neighbourhood_tanimoto_3 Importance: 0.0
# Variable: chemical_neighbourhood_tanimoto_4 Importance: 0.0
# Variable: chemical_neighbourhood_tanimoto_5 Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
training_scores.corr()
# Out:
#                                                     query_precursor_mz  \
# query_precursor_mz                                            1.000000
# precursor_mz_difference                                       0.376204
# s2v_score                                                     0.060726
# ms2ds_score                                                   0.280129
# average_ms2ds_score_for_inchikey14                            0.252732
# nr_of_spectra_with_same_inchikey14                           -0.068031
# chemical_neighbourhood_score                                  0.367003
# average_tanimoto_score_for_chemical_neighbourho...            0.401451
# nr_of_spectra_for_chemical_neighbourhood_score               -0.006880
# cosine_score                                                 -0.174724
# modified_cosine_score                                        -0.133822
# lib_instrument_orbitrap                                       0.045918
# lib_instrument_ion_trap                                      -0.053258
# lib_instrument_tof                                           -0.048207
# lib_instrument_quadrupole                                          NaN
# query_instrument_orbitrap                                     0.075350
# query_instrument_ion_trap                                    -0.071810
# query_instrument_tof                                         -0.033114
# query_instrument_quadrupole                                        NaN
# average_ms2deepscore_0                                        0.246782
# tanimoto_score_structure_0                                         NaN
# nr_of_spectra_structure_0                                    -0.146295
# average_ms2deepscore_1                                        0.281132
# tanimoto_score_structure_1                                    0.325783
# nr_of_spectra_structure_1                                     0.002364
# average_ms2deepscore_2                                        0.298756
# tanimoto_score_structure_2                                    0.386708
# nr_of_spectra_structure_2                                     0.047387
# average_ms2deepscore_3                                        0.304898
# tanimoto_score_structure_3                                    0.420071
# nr_of_spectra_structure_3                                     0.020306
# average_ms2deepscore_4                                        0.318240
# tanimoto_score_structure_4                                    0.436006
# nr_of_spectra_structure_4                                     0.024502
# average_ms2deepscore_5                                        0.331954
# tanimoto_score_structure_5                                    0.448592
# nr_of_spectra_structure_5                                     0.037343
# average_ms2deepscore_6                                        0.335379
# tanimoto_score_structure_6                                    0.462857
# nr_of_spectra_structure_6                                    -0.003827
# average_ms2deepscore_7                                        0.326733
# tanimoto_score_structure_7                                    0.471585
# nr_of_spectra_structure_7                                     0.012879
# average_ms2deepscore_8                                        0.345448
# tanimoto_score_structure_8                                    0.477739
# nr_of_spectra_structure_8                                     0.051192
# average_ms2deepscore_9                                        0.347443
# tanimoto_score_structure_9                                    0.484518
# nr_of_spectra_structure_9                                     0.004490
# chemical_neighbourhood_tanimoto_3                             0.323522
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...            0.352519
# chemical_neighbourhood_tanimoto_4                             0.303038
# chemical_neighbourhood_tanimoto_5                             0.285893
#
#                                                     precursor_mz_difference  \
# query_precursor_mz                                                 0.376204
# precursor_mz_difference                                            1.000000
# s2v_score                                                         -0.159887
# ms2ds_score                                                       -0.049766
# average_ms2ds_score_for_inchikey14                                -0.060590
# nr_of_spectra_with_same_inchikey14                                 0.006943
# chemical_neighbourhood_score                                      -0.029210
# average_tanimoto_score_for_chemical_neighbourho...                 0.105554
# nr_of_spectra_for_chemical_neighbourhood_score                     0.013430
# cosine_score                                                      -0.130538
# modified_cosine_score                                             -0.193266
# lib_instrument_orbitrap                                            0.007960
# lib_instrument_ion_trap                                           -0.003739
# lib_instrument_tof                                                -0.004223
# lib_instrument_quadrupole                                               NaN
# query_instrument_orbitrap                                          0.019090
# query_instrument_ion_trap                                         -0.018426
# query_instrument_tof                                              -0.006029
# query_instrument_quadrupole                                             NaN
# average_ms2deepscore_0                                            -0.062616
# tanimoto_score_structure_0                                              NaN
# nr_of_spectra_structure_0                                         -0.017155
# average_ms2deepscore_1                                            -0.046268
# tanimoto_score_structure_1                                         0.070627
# nr_of_spectra_structure_1                                         -0.000980
# average_ms2deepscore_2                                            -0.037439
# tanimoto_score_structure_2                                         0.078731
# nr_of_spectra_structure_2                                          0.023725
# average_ms2deepscore_3                                            -0.034040
# tanimoto_score_structure_3                                         0.088688
# nr_of_spectra_structure_3                                          0.003277
# average_ms2deepscore_4                                            -0.022970
# tanimoto_score_structure_4                                         0.094047
# nr_of_spectra_structure_4                                          0.016141
# average_ms2deepscore_5                                            -0.019439
# tanimoto_score_structure_5                                         0.099180
# nr_of_spectra_structure_5                                          0.015107
# average_ms2deepscore_6                                            -0.016122
# tanimoto_score_structure_6                                         0.103495
# nr_of_spectra_structure_6                                          0.008157
# average_ms2deepscore_7                                            -0.021941
# tanimoto_score_structure_7                                         0.105339
# nr_of_spectra_structure_7                                          0.002599
# average_ms2deepscore_8                                            -0.010312
# tanimoto_score_structure_8                                         0.106936
# nr_of_spectra_structure_8                                          0.033204
# average_ms2deepscore_9                                            -0.013854
# tanimoto_score_structure_9                                         0.108111
# nr_of_spectra_structure_9                                         -0.006929
# chemical_neighbourhood_tanimoto_3                                 -0.044686
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                -0.039129
# chemical_neighbourhood_tanimoto_4                                 -0.051350
# chemical_neighbourhood_tanimoto_5                                 -0.056701
#
#                                                     s2v_score  ms2ds_score  \
# query_precursor_mz                                   0.060726     0.280129
# precursor_mz_difference                             -0.159887    -0.049766
# s2v_score                                            1.000000     0.292340
# ms2ds_score                                          0.292340     1.000000
# average_ms2ds_score_for_inchikey14                   0.277627     0.465841
# nr_of_spectra_with_same_inchikey14                  -0.095746     0.021132
# chemical_neighbourhood_score                         0.220795     0.493936
# average_tanimoto_score_for_chemical_neighbourho...   0.016752     0.258245
# nr_of_spectra_for_chemical_neighbourhood_score      -0.105255     0.094478
# cosine_score                                         0.256245     0.426974
# modified_cosine_score                                0.204098     0.433892
# lib_instrument_orbitrap                             -0.246684     0.108465
# lib_instrument_ion_trap                             -0.047917    -0.059898
# lib_instrument_tof                                   0.129230    -0.078491
# lib_instrument_quadrupole                                 NaN          NaN
# query_instrument_orbitrap                           -0.177598     0.156183
# query_instrument_ion_trap                           -0.072533    -0.076062
# query_instrument_tof                                 0.087644    -0.112018
# query_instrument_quadrupole                               NaN          NaN
# average_ms2deepscore_0                               0.274752     0.452683
# tanimoto_score_structure_0                                NaN          NaN
# nr_of_spectra_structure_0                           -0.103407    -0.009064
# average_ms2deepscore_1                               0.230714     0.376855
# tanimoto_score_structure_1                           0.036139     0.211977
# nr_of_spectra_structure_1                           -0.063221     0.056551
# average_ms2deepscore_2                               0.214154     0.390903
# tanimoto_score_structure_2                           0.043211     0.250603
# nr_of_spectra_structure_2                           -0.041518     0.050034
# average_ms2deepscore_3                               0.213026     0.391312
# tanimoto_score_structure_3                           0.045698     0.271380
# nr_of_spectra_structure_3                           -0.049900     0.060092
# average_ms2deepscore_4                               0.200174     0.387169
# tanimoto_score_structure_4                           0.043535     0.278613
# nr_of_spectra_structure_4                           -0.048313     0.045706
# average_ms2deepscore_5                               0.202673     0.396195
# tanimoto_score_structure_5                           0.045267     0.286018
# nr_of_spectra_structure_5                           -0.040576     0.048748
# average_ms2deepscore_6                               0.189105     0.391889
# tanimoto_score_structure_6                           0.047050     0.294587
# nr_of_spectra_structure_6                           -0.037036     0.054312
# average_ms2deepscore_7                               0.201542     0.396544
# tanimoto_score_structure_7                           0.049356     0.301003
# nr_of_spectra_structure_7                           -0.018972     0.063412
# average_ms2deepscore_8                               0.191030     0.390889
# tanimoto_score_structure_8                           0.046601     0.305707
# nr_of_spectra_structure_8                           -0.026938     0.067034
# average_ms2deepscore_9                               0.190920     0.395373
# tanimoto_score_structure_9                           0.047476     0.307129
# nr_of_spectra_structure_9                           -0.038428     0.057550
# chemical_neighbourhood_tanimoto_3                    0.230656     0.485797
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...   0.250778     0.461083
# chemical_neighbourhood_tanimoto_4                    0.234396     0.479370
# chemical_neighbourhood_tanimoto_5                    0.237673     0.473221
#
#                                                     average_ms2ds_score_for_inchikey14  \
# query_precursor_mz                                                            0.252732
# precursor_mz_difference                                                      -0.060590
# s2v_score                                                                     0.277627
# ms2ds_score                                                                   0.465841
# average_ms2ds_score_for_inchikey14                                            1.000000
# nr_of_spectra_with_same_inchikey14                                           -0.319088
# chemical_neighbourhood_score                                                  0.776430
# average_tanimoto_score_for_chemical_neighbourho...                            0.016046
# nr_of_spectra_for_chemical_neighbourhood_score                               -0.220868
# cosine_score                                                                  0.112303
# modified_cosine_score                                                         0.157215
# lib_instrument_orbitrap                                                      -0.158205
# lib_instrument_ion_trap                                                      -0.007485
# lib_instrument_tof                                                            0.155981
# lib_instrument_quadrupole                                                          NaN
# query_instrument_orbitrap                                                     0.006992
# query_instrument_ion_trap                                                    -0.046877
# query_instrument_tof                                                          0.004835
# query_instrument_quadrupole                                                        NaN
# average_ms2deepscore_0                                                        0.965638
# tanimoto_score_structure_0                                                         NaN
# nr_of_spectra_structure_0                                                    -0.323677
# average_ms2deepscore_1                                                        0.707114
# tanimoto_score_structure_1                                                    0.131615
# nr_of_spectra_structure_1                                                    -0.114579
# average_ms2deepscore_2                                                        0.671920
# tanimoto_score_structure_2                                                    0.148058
# nr_of_spectra_structure_2                                                    -0.097940
# average_ms2deepscore_3                                                        0.637096
# tanimoto_score_structure_3                                                    0.158102
# nr_of_spectra_structure_3                                                    -0.055995
# average_ms2deepscore_4                                                        0.622182
# tanimoto_score_structure_4                                                    0.158295
# nr_of_spectra_structure_4                                                    -0.076966
# average_ms2deepscore_5                                                        0.616828
# tanimoto_score_structure_5                                                    0.161578
# nr_of_spectra_structure_5                                                    -0.067807
# average_ms2deepscore_6                                                        0.604430
# tanimoto_score_structure_6                                                    0.165434
# nr_of_spectra_structure_6                                                    -0.044283
# average_ms2deepscore_7                                                        0.597921
# tanimoto_score_structure_7                                                    0.168867
# nr_of_spectra_structure_7                                                    -0.039404
# average_ms2deepscore_8                                                        0.596604
# tanimoto_score_structure_8                                                    0.168498
# nr_of_spectra_structure_8                                                    -0.037785
# average_ms2deepscore_9                                                        0.579684
# tanimoto_score_structure_9                                                    0.167204
# nr_of_spectra_structure_9                                                    -0.044200
# chemical_neighbourhood_tanimoto_3                                             0.823672
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                            0.789089
# chemical_neighbourhood_tanimoto_4                                             0.841307
# chemical_neighbourhood_tanimoto_5                                             0.855410
#
#                                                     nr_of_spectra_with_same_inchikey14  \
# query_precursor_mz                                                           -0.068031
# precursor_mz_difference                                                       0.006943
# s2v_score                                                                    -0.095746
# ms2ds_score                                                                   0.021132
# average_ms2ds_score_for_inchikey14                                           -0.319088
# nr_of_spectra_with_same_inchikey14                                            1.000000
# chemical_neighbourhood_score                                                 -0.105165
# average_tanimoto_score_for_chemical_neighbourho...                            0.331616
# nr_of_spectra_for_chemical_neighbourhood_score                                0.655639
# cosine_score                                                                  0.028875
# modified_cosine_score                                                         0.022458
# lib_instrument_orbitrap                                                       0.253469
# lib_instrument_ion_trap                                                      -0.071449
# lib_instrument_tof                                                           -0.156609
# lib_instrument_quadrupole                                                          NaN
# query_instrument_orbitrap                                                     0.071370
# query_instrument_ion_trap                                                     0.010192
# query_instrument_tof                                                         -0.038252
# query_instrument_quadrupole                                                        NaN
# average_ms2deepscore_0                                                       -0.292502
# tanimoto_score_structure_0                                                         NaN
# nr_of_spectra_structure_0                                                     0.821650
# average_ms2deepscore_1                                                       -0.151729
# tanimoto_score_structure_1                                                    0.151293
# nr_of_spectra_structure_1                                                     0.429426
# average_ms2deepscore_2                                                       -0.109313
# tanimoto_score_structure_2                                                    0.154903
# nr_of_spectra_structure_2                                                     0.385150
# average_ms2deepscore_3                                                       -0.092211
# tanimoto_score_structure_3                                                    0.157582
# nr_of_spectra_structure_3                                                     0.133584
# average_ms2deepscore_4                                                       -0.079269
# tanimoto_score_structure_4                                                    0.164223
# nr_of_spectra_structure_4                                                     0.117241
# average_ms2deepscore_5                                                       -0.095615
# tanimoto_score_structure_5                                                    0.157723
# nr_of_spectra_structure_5                                                     0.174537
# average_ms2deepscore_6                                                       -0.061398
# tanimoto_score_structure_6                                                    0.153924
# nr_of_spectra_structure_6                                                     0.186381
# average_ms2deepscore_7                                                       -0.071310
# tanimoto_score_structure_7                                                    0.148442
# nr_of_spectra_structure_7                                                     0.095215
# average_ms2deepscore_8                                                       -0.084394
# tanimoto_score_structure_8                                                    0.153997
# nr_of_spectra_structure_8                                                     0.219161
# average_ms2deepscore_9                                                       -0.049468
# tanimoto_score_structure_9                                                    0.155055
# nr_of_spectra_structure_9                                                     0.128287
# chemical_neighbourhood_tanimoto_3                                            -0.144255
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                           -0.138126
# chemical_neighbourhood_tanimoto_4                                            -0.162716
# chemical_neighbourhood_tanimoto_5                                            -0.178775
#
#                                                     chemical_neighbourhood_score  \
# query_precursor_mz                                                      0.367003
# precursor_mz_difference                                                -0.029210
# s2v_score                                                               0.220795
# ms2ds_score                                                             0.493936
# average_ms2ds_score_for_inchikey14                                      0.776430
# nr_of_spectra_with_same_inchikey14                                     -0.105165
# chemical_neighbourhood_score                                            1.000000
# average_tanimoto_score_for_chemical_neighbourho...                      0.341885
# nr_of_spectra_for_chemical_neighbourhood_score                         -0.121845
# cosine_score                                                            0.050612
# modified_cosine_score                                                   0.116796
# lib_instrument_orbitrap                                                -0.020070
# lib_instrument_ion_trap                                                -0.038031
# lib_instrument_tof                                                      0.043291
# lib_instrument_quadrupole                                                    NaN
# query_instrument_orbitrap                                               0.086098
# query_instrument_ion_trap                                              -0.057770
# query_instrument_tof                                                   -0.037244
# query_instrument_quadrupole                                                  NaN
# average_ms2deepscore_0                                                  0.772152
# tanimoto_score_structure_0                                                   NaN
# nr_of_spectra_structure_0                                              -0.137377
# average_ms2deepscore_1                                                  0.786329
# tanimoto_score_structure_1                                              0.305589
# nr_of_spectra_structure_1                                              -0.035684
# average_ms2deepscore_2                                                  0.797517
# tanimoto_score_structure_2                                              0.344381
# nr_of_spectra_structure_2                                              -0.043083
# average_ms2deepscore_3                                                  0.793358
# tanimoto_score_structure_3                                              0.361450
# nr_of_spectra_structure_3                                              -0.035587
# average_ms2deepscore_4                                                  0.794046
# tanimoto_score_structure_4                                              0.367885
# nr_of_spectra_structure_4                                              -0.063754
# average_ms2deepscore_5                                                  0.793863
# tanimoto_score_structure_5                                              0.372005
# nr_of_spectra_structure_5                                              -0.059155
# average_ms2deepscore_6                                                  0.783690
# tanimoto_score_structure_6                                              0.376532
# nr_of_spectra_structure_6                                              -0.046973
# average_ms2deepscore_7                                                  0.783490
# tanimoto_score_structure_7                                              0.378057
# nr_of_spectra_structure_7                                              -0.057399
# average_ms2deepscore_8                                                  0.778365
# tanimoto_score_structure_8                                              0.376794
# nr_of_spectra_structure_8                                              -0.024232
# average_ms2deepscore_9                                                  0.766231
# tanimoto_score_structure_9                                              0.373542
# nr_of_spectra_structure_9                                              -0.044909
# chemical_neighbourhood_tanimoto_3                                       0.979220
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                      0.916760
# chemical_neighbourhood_tanimoto_4                                       0.959757
# chemical_neighbourhood_tanimoto_5                                       0.940077
#
#                                                     average_tanimoto_score_for_chemical_neighbourhood_score  \
# query_precursor_mz                                                                           0.401451
# precursor_mz_difference                                                                      0.105554
# s2v_score                                                                                    0.016752
# ms2ds_score                                                                                  0.258245
# average_ms2ds_score_for_inchikey14                                                           0.016046
# nr_of_spectra_with_same_inchikey14                                                           0.331616
# chemical_neighbourhood_score                                                                 0.341885
# average_tanimoto_score_for_chemical_neighbourho...                                           1.000000
# nr_of_spectra_for_chemical_neighbourhood_score                                               0.295781
# cosine_score                                                                                -0.053413
# modified_cosine_score                                                                       -0.030463
# lib_instrument_orbitrap                                                                      0.215541
# lib_instrument_ion_trap                                                                     -0.119895
# lib_instrument_tof                                                                          -0.135833
# lib_instrument_quadrupole                                                                         NaN
# query_instrument_orbitrap                                                                    0.132620
# query_instrument_ion_trap                                                                   -0.063457
# query_instrument_tof                                                                        -0.053176
# query_instrument_quadrupole                                                                       NaN
# average_ms2deepscore_0                                                                       0.009279
# tanimoto_score_structure_0                                                                        NaN
# nr_of_spectra_structure_0                                                                    0.275876
# average_ms2deepscore_1                                                                       0.208280
# tanimoto_score_structure_1                                                                   0.734430
# nr_of_spectra_structure_1                                                                    0.226395
# average_ms2deepscore_2                                                                       0.272960
# tanimoto_score_structure_2                                                                   0.822642
# nr_of_spectra_structure_2                                                                    0.171586
# average_ms2deepscore_3                                                                       0.309654
# tanimoto_score_structure_3                                                                   0.852210
# nr_of_spectra_structure_3                                                                    0.125104
# average_ms2deepscore_4                                                                       0.333101
# tanimoto_score_structure_4                                                                   0.867440
# nr_of_spectra_structure_4                                                                    0.096047
# average_ms2deepscore_5                                                                       0.348347
# tanimoto_score_structure_5                                                                   0.870203
# nr_of_spectra_structure_5                                                                    0.106784
# average_ms2deepscore_6                                                                       0.352416
# tanimoto_score_structure_6                                                                   0.868147
# nr_of_spectra_structure_6                                                                    0.069057
# average_ms2deepscore_7                                                                       0.364781
# tanimoto_score_structure_7                                                                   0.864106
# nr_of_spectra_structure_7                                                                    0.071838
# average_ms2deepscore_8                                                                       0.370047
# tanimoto_score_structure_8                                                                   0.858453
# nr_of_spectra_structure_8                                                                    0.094969
# average_ms2deepscore_9                                                                       0.383896
# tanimoto_score_structure_9                                                                   0.851443
# nr_of_spectra_structure_9                                                                    0.042888
# chemical_neighbourhood_tanimoto_3                                                            0.210808
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                                           0.303177
# chemical_neighbourhood_tanimoto_4                                                            0.150899
# chemical_neighbourhood_tanimoto_5                                                            0.101793
#
#                                                     nr_of_spectra_for_chemical_neighbourhood_score  \
# query_precursor_mz                                                                       -0.006880
# precursor_mz_difference                                                                   0.013430
# s2v_score                                                                                -0.105255
# ms2ds_score                                                                               0.094478
# average_ms2ds_score_for_inchikey14                                                       -0.220868
# nr_of_spectra_with_same_inchikey14                                                        0.655639
# chemical_neighbourhood_score                                                             -0.121845
# average_tanimoto_score_for_chemical_neighbourho...                                        0.295781
# nr_of_spectra_for_chemical_neighbourhood_score                                            1.000000
# cosine_score                                                                              0.031652
# modified_cosine_score                                                                     0.020955
# lib_instrument_orbitrap                                                                   0.233379
# lib_instrument_ion_trap                                                                  -0.083244
# lib_instrument_tof                                                                       -0.146806
# lib_instrument_quadrupole                                                                      NaN
# query_instrument_orbitrap                                                                 0.091290
# query_instrument_ion_trap                                                                -0.010118
# query_instrument_tof                                                                     -0.061346
# query_instrument_quadrupole                                                                    NaN
# average_ms2deepscore_0                                                                   -0.209762
# tanimoto_score_structure_0                                                                     NaN
# nr_of_spectra_structure_0                                                                 0.592659
# average_ms2deepscore_1                                                                   -0.112050
# tanimoto_score_structure_1                                                                0.249389
# nr_of_spectra_structure_1                                                                 0.544623
# average_ms2deepscore_2                                                                   -0.066339
# tanimoto_score_structure_2                                                                0.282920
# nr_of_spectra_structure_2                                                                 0.500685
# average_ms2deepscore_3                                                                   -0.051109
# tanimoto_score_structure_3                                                                0.297273
# nr_of_spectra_structure_3                                                                 0.440381
# average_ms2deepscore_4                                                                   -0.026571
# tanimoto_score_structure_4                                                                0.307437
# nr_of_spectra_structure_4                                                                 0.425187
# average_ms2deepscore_5                                                                   -0.037363
# tanimoto_score_structure_5                                                                0.307749
# nr_of_spectra_structure_5                                                                 0.471190
# average_ms2deepscore_6                                                                   -0.008586
# tanimoto_score_structure_6                                                                0.307333
# nr_of_spectra_structure_6                                                                 0.447920
# average_ms2deepscore_7                                                                   -0.007779
# tanimoto_score_structure_7                                                                0.307411
# nr_of_spectra_structure_7                                                                 0.386720
# average_ms2deepscore_8                                                                   -0.013231
# tanimoto_score_structure_8                                                                0.314493
# nr_of_spectra_structure_8                                                                 0.481313
# average_ms2deepscore_9                                                                    0.007455
# tanimoto_score_structure_9                                                                0.314768
# nr_of_spectra_structure_9                                                                 0.425647
# chemical_neighbourhood_tanimoto_3                                                        -0.173167
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                                       -0.077132
# chemical_neighbourhood_tanimoto_4                                                        -0.193787
# chemical_neighbourhood_tanimoto_5                                                        -0.210055
#
#                                                     cosine_score  ...  \
# query_precursor_mz                                     -0.174724  ...
# precursor_mz_difference                                -0.130538  ...
# s2v_score                                               0.256245  ...
# ms2ds_score                                             0.426974  ...
# average_ms2ds_score_for_inchikey14                      0.112303  ...
# nr_of_spectra_with_same_inchikey14                      0.028875  ...
# chemical_neighbourhood_score                            0.050612  ...
# average_tanimoto_score_for_chemical_neighbourho...     -0.053413  ...
# nr_of_spectra_for_chemical_neighbourhood_score          0.031652  ...
# cosine_score                                            1.000000  ...
# modified_cosine_score                                   0.814299  ...
# lib_instrument_orbitrap                                 0.043754  ...
# lib_instrument_ion_trap                                -0.007020  ...
# lib_instrument_tof                                     -0.012982  ...
# lib_instrument_quadrupole                                    NaN  ...
# query_instrument_orbitrap                               0.060015  ...
# query_instrument_ion_trap                              -0.021308  ...
# query_instrument_tof                                   -0.031139  ...
# query_instrument_quadrupole                                  NaN  ...
# average_ms2deepscore_0                                  0.105242  ...
# tanimoto_score_structure_0                                   NaN  ...
# nr_of_spectra_structure_0                               0.034953  ...
# average_ms2deepscore_1                                  0.026516  ...
# tanimoto_score_structure_1                             -0.049480  ...
# nr_of_spectra_structure_1                              -0.009142  ...
# average_ms2deepscore_2                                  0.022004  ...
# tanimoto_score_structure_2                             -0.059838  ...
# nr_of_spectra_structure_2                               0.006048  ...
# average_ms2deepscore_3                                  0.021000  ...
# tanimoto_score_structure_3                             -0.061862  ...
# nr_of_spectra_structure_3                               0.014191  ...
# average_ms2deepscore_4                                  0.008537  ...
# tanimoto_score_structure_4                             -0.064948  ...
# nr_of_spectra_structure_4                               0.003030  ...
# average_ms2deepscore_5                                  0.002232  ...
# tanimoto_score_structure_5                             -0.064737  ...
# nr_of_spectra_structure_5                               0.009438  ...
# average_ms2deepscore_6                                 -0.002952  ...
# tanimoto_score_structure_6                             -0.065791  ...
# nr_of_spectra_structure_6                               0.023517  ...
# average_ms2deepscore_7                                  0.004848  ...
# tanimoto_score_structure_7                             -0.064984  ...
# nr_of_spectra_structure_7                               0.036126  ...
# average_ms2deepscore_8                                 -0.014836  ...
# tanimoto_score_structure_8                             -0.067477  ...
# nr_of_spectra_structure_8                               0.012557  ...
# average_ms2deepscore_9                                 -0.007853  ...
# tanimoto_score_structure_9                             -0.070049  ...
# nr_of_spectra_structure_9                               0.022090  ...
# chemical_neighbourhood_tanimoto_3                       0.072754  ...
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...      0.025297  ...
# chemical_neighbourhood_tanimoto_4                       0.081594  ...
# chemical_neighbourhood_tanimoto_5                       0.088477  ...
#
#                                                     average_ms2deepscore_8  \
# query_precursor_mz                                                0.345448
# precursor_mz_difference                                          -0.010312
# s2v_score                                                         0.191030
# ms2ds_score                                                       0.390889
# average_ms2ds_score_for_inchikey14                                0.596604
# nr_of_spectra_with_same_inchikey14                               -0.084394
# chemical_neighbourhood_score                                      0.778365
# average_tanimoto_score_for_chemical_neighbourho...                0.370047
# nr_of_spectra_for_chemical_neighbourhood_score                   -0.013231
# cosine_score                                                     -0.014836
# modified_cosine_score                                             0.050057
# lib_instrument_orbitrap                                          -0.059806
# lib_instrument_ion_trap                                          -0.057110
# lib_instrument_tof                                                0.074393
# lib_instrument_quadrupole                                              NaN
# query_instrument_orbitrap                                         0.040439
# query_instrument_ion_trap                                        -0.069292
# query_instrument_tof                                              0.003449
# query_instrument_quadrupole                                            NaN
# average_ms2deepscore_0                                            0.602997
# tanimoto_score_structure_0                                             NaN
# nr_of_spectra_structure_0                                        -0.115636
# average_ms2deepscore_1                                            0.676176
# tanimoto_score_structure_1                                        0.362369
# nr_of_spectra_structure_1                                         0.009808
# average_ms2deepscore_2                                            0.710404
# tanimoto_score_structure_2                                        0.416658
# nr_of_spectra_structure_2                                         0.023799
# average_ms2deepscore_3                                            0.726265
# tanimoto_score_structure_3                                        0.440670
# nr_of_spectra_structure_3                                         0.015922
# average_ms2deepscore_4                                            0.736156
# tanimoto_score_structure_4                                        0.451124
# nr_of_spectra_structure_4                                        -0.002940
# average_ms2deepscore_5                                            0.750279
# tanimoto_score_structure_5                                        0.458405
# nr_of_spectra_structure_5                                        -0.007739
# average_ms2deepscore_6                                            0.748487
# tanimoto_score_structure_6                                        0.465875
# nr_of_spectra_structure_6                                         0.028170
# average_ms2deepscore_7                                            0.763870
# tanimoto_score_structure_7                                        0.470788
# nr_of_spectra_structure_7                                         0.015990
# average_ms2deepscore_8                                            1.000000
# tanimoto_score_structure_8                                        0.473489
# nr_of_spectra_structure_8                                         0.000605
# average_ms2deepscore_9                                            0.757996
# tanimoto_score_structure_9                                        0.471365
# nr_of_spectra_structure_9                                         0.035420
# chemical_neighbourhood_tanimoto_3                                 0.723610
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                0.857397
# chemical_neighbourhood_tanimoto_4                                 0.697284
# chemical_neighbourhood_tanimoto_5                                 0.675204
#
#                                                     tanimoto_score_structure_8  \
# query_precursor_mz                                                    0.477739
# precursor_mz_difference                                               0.106936
# s2v_score                                                             0.046601
# ms2ds_score                                                           0.305707
# average_ms2ds_score_for_inchikey14                                    0.168498
# nr_of_spectra_with_same_inchikey14                                    0.153997
# chemical_neighbourhood_score                                          0.376794
# average_tanimoto_score_for_chemical_neighbourho...                    0.858453
# nr_of_spectra_for_chemical_neighbourhood_score                        0.314493
# cosine_score                                                         -0.067477
# modified_cosine_score                                                -0.032850
# lib_instrument_orbitrap                                               0.138685
# lib_instrument_ion_trap                                              -0.125887
# lib_instrument_tof                                                   -0.084202
# lib_instrument_quadrupole                                                  NaN
# query_instrument_orbitrap                                             0.105415
# query_instrument_ion_trap                                            -0.072787
# query_instrument_tof                                                 -0.042833
# ...
# nr_of_spectra_structure_9                                                   -0.061330
# chemical_neighbourhood_tanimoto_3                                            1.000000
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                           0.891806
# chemical_neighbourhood_tanimoto_4                                            0.996126
# chemical_neighbourhood_tanimoto_5                                            0.987164
#
#                                                     chemical_neighbourhood_no_spectrum_nr_tanimoto_power1  \
# query_precursor_mz                                                                           0.352519
# precursor_mz_difference                                                                     -0.039129
# s2v_score                                                                                    0.250778
# ms2ds_score                                                                                  0.461083
# average_ms2ds_score_for_inchikey14                                                           0.789089
# nr_of_spectra_with_same_inchikey14                                                          -0.138126
# chemical_neighbourhood_score                                                                 0.916760
# average_tanimoto_score_for_chemical_neighbourho...                                           0.303177
# nr_of_spectra_for_chemical_neighbourhood_score                                              -0.077132
# cosine_score                                                                                 0.025297
# modified_cosine_score                                                                        0.095119
# lib_instrument_orbitrap                                                                     -0.115692
# lib_instrument_ion_trap                                                                     -0.036955
# lib_instrument_tof                                                                           0.123261
# lib_instrument_quadrupole                                                                         NaN
# query_instrument_orbitrap                                                                    0.019600
# query_instrument_ion_trap                                                                   -0.065090
# query_instrument_tof                                                                         0.018935
# query_instrument_quadrupole                                                                       NaN
# average_ms2deepscore_0                                                                       0.795666
# tanimoto_score_structure_0                                                                        NaN
# nr_of_spectra_structure_0                                                                   -0.180745
# average_ms2deepscore_1                                                                       0.858053
# tanimoto_score_structure_1                                                                   0.350161
# nr_of_spectra_structure_1                                                                   -0.023237
# average_ms2deepscore_2                                                                       0.872269
# tanimoto_score_structure_2                                                                   0.394455
# nr_of_spectra_structure_2                                                                   -0.002549
# average_ms2deepscore_3                                                                       0.872952
# tanimoto_score_structure_3                                                                   0.408244
# nr_of_spectra_structure_3                                                                   -0.010840
# average_ms2deepscore_4                                                                       0.876051
# tanimoto_score_structure_4                                                                   0.413382
# nr_of_spectra_structure_4                                                                   -0.034402
# average_ms2deepscore_5                                                                       0.871927
# tanimoto_score_structure_5                                                                   0.416579
# nr_of_spectra_structure_5                                                                   -0.025244
# average_ms2deepscore_6                                                                       0.862925
# tanimoto_score_structure_6                                                                   0.420219
# nr_of_spectra_structure_6                                                                   -0.010000
# average_ms2deepscore_7                                                                       0.862568
# tanimoto_score_structure_7                                                                   0.421121
# nr_of_spectra_structure_7                                                                   -0.005697
# average_ms2deepscore_8                                                                       0.857397
# tanimoto_score_structure_8                                                                   0.419012
# nr_of_spectra_structure_8                                                                    0.012804
# average_ms2deepscore_9                                                                       0.845215
# tanimoto_score_structure_9                                                                   0.415931
# nr_of_spectra_structure_9                                                                   -0.004428
# chemical_neighbourhood_tanimoto_3                                                            0.891806
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                                           1.000000
# chemical_neighbourhood_tanimoto_4                                                            0.876126
# chemical_neighbourhood_tanimoto_5                                                            0.861702
#
#                                                     chemical_neighbourhood_tanimoto_4  \
# query_precursor_mz                                                           0.303038
# precursor_mz_difference                                                     -0.051350
# s2v_score                                                                    0.234396
# ms2ds_score                                                                  0.479370
# average_ms2ds_score_for_inchikey14                                           0.841307
# nr_of_spectra_with_same_inchikey14                                          -0.162716
# chemical_neighbourhood_score                                                 0.959757
# average_tanimoto_score_for_chemical_neighbourho...                           0.150899
# nr_of_spectra_for_chemical_neighbourhood_score                              -0.193787
# cosine_score                                                                 0.081594
# modified_cosine_score                                                        0.141340
# lib_instrument_orbitrap                                                     -0.057365
# lib_instrument_ion_trap                                                     -0.004782
# lib_instrument_tof                                                           0.070262
# lib_instrument_quadrupole                                                         NaN
# query_instrument_orbitrap                                                    0.063321
# query_instrument_ion_trap                                                   -0.041594
# query_instrument_tof                                                        -0.028078
# query_instrument_quadrupole                                                       NaN
# average_ms2deepscore_0                                                       0.836015
# tanimoto_score_structure_0                                                        NaN
# nr_of_spectra_structure_0                                                   -0.189609
# average_ms2deepscore_1                                                       0.776204
# tanimoto_score_structure_1                                                   0.161572
# nr_of_spectra_structure_1                                                   -0.081710
# average_ms2deepscore_2                                                       0.760925
# tanimoto_score_structure_2                                                   0.182670
# nr_of_spectra_structure_2                                                   -0.081124
# average_ms2deepscore_3                                                       0.735343
# tanimoto_score_structure_3                                                   0.195393
# nr_of_spectra_structure_3                                                   -0.069704
# average_ms2deepscore_4                                                       0.728083
# tanimoto_score_structure_4                                                   0.200013
# nr_of_spectra_structure_4                                                   -0.096408
# average_ms2deepscore_5                                                       0.722832
# tanimoto_score_structure_5                                                   0.204467
# nr_of_spectra_structure_5                                                   -0.087661
# average_ms2deepscore_6                                                       0.713821
# tanimoto_score_structure_6                                                   0.210057
# nr_of_spectra_structure_6                                                   -0.073450
# average_ms2deepscore_7                                                       0.706992
# tanimoto_score_structure_7                                                   0.213284
# nr_of_spectra_structure_7                                                   -0.082542
# average_ms2deepscore_8                                                       0.697284
# tanimoto_score_structure_8                                                   0.213476
# nr_of_spectra_structure_8                                                   -0.049060
# average_ms2deepscore_9                                                       0.683719
# tanimoto_score_structure_9                                                   0.212100
# nr_of_spectra_structure_9                                                   -0.066545
# chemical_neighbourhood_tanimoto_3                                            0.996126
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                           0.876126
# chemical_neighbourhood_tanimoto_4                                            1.000000
# chemical_neighbourhood_tanimoto_5                                            0.997231
#
#                                                     chemical_neighbourhood_tanimoto_5
# query_precursor_mz                                                           0.285893
# precursor_mz_difference                                                     -0.056701
# s2v_score                                                                    0.237673
# ms2ds_score                                                                  0.473221
# average_ms2ds_score_for_inchikey14                                           0.855410
# nr_of_spectra_with_same_inchikey14                                          -0.178775
# chemical_neighbourhood_score                                                 0.940077
# average_tanimoto_score_for_chemical_neighbourho...                           0.101793
# nr_of_spectra_for_chemical_neighbourhood_score                              -0.210055
# cosine_score                                                                 0.088477
# modified_cosine_score                                                        0.146477
# lib_instrument_orbitrap                                                     -0.067516
# lib_instrument_ion_trap                                                      0.000026
# lib_instrument_tof                                                           0.077480
# lib_instrument_quadrupole                                                         NaN
# query_instrument_orbitrap                                                    0.056916
# query_instrument_ion_trap                                                   -0.038863
# query_instrument_tof                                                        -0.025611
# query_instrument_quadrupole                                                       NaN
# average_ms2deepscore_0                                                       0.849799
# tanimoto_score_structure_0                                                        NaN
# nr_of_spectra_structure_0                                                   -0.204071
# average_ms2deepscore_1                                                       0.769796
# tanimoto_score_structure_1                                                   0.128015
# nr_of_spectra_structure_1                                                   -0.093373
# average_ms2deepscore_2                                                       0.748243
# tanimoto_score_structure_2                                                   0.145631
# nr_of_spectra_structure_2                                                   -0.089986
# average_ms2deepscore_3                                                       0.717970
# tanimoto_score_structure_3                                                   0.157503
# nr_of_spectra_structure_3                                                   -0.077063
# average_ms2deepscore_4                                                       0.708953
# tanimoto_score_structure_4                                                   0.161578
# nr_of_spectra_structure_4                                                   -0.102970
# average_ms2deepscore_5                                                       0.702664
# tanimoto_score_structure_5                                                   0.166046
# nr_of_spectra_structure_5                                                   -0.093435
# average_ms2deepscore_6                                                       0.693430
# tanimoto_score_structure_6                                                   0.171857
# nr_of_spectra_structure_6                                                   -0.078186
# average_ms2deepscore_7                                                       0.685460
# tanimoto_score_structure_7                                                   0.175456
# nr_of_spectra_structure_7                                                   -0.086982
# average_ms2deepscore_8                                                       0.675204
# tanimoto_score_structure_8                                                   0.175993
# nr_of_spectra_structure_8                                                   -0.053730
# average_ms2deepscore_9                                                       0.661667
# tanimoto_score_structure_9                                                   0.175051
# nr_of_spectra_structure_9                                                   -0.069819
# chemical_neighbourhood_tanimoto_3                                            0.987164
# chemical_neighbourhood_no_spectrum_nr_tanimoto_...                           0.861702
# chemical_neighbourhood_tanimoto_4                                            0.997231
# chemical_neighbourhood_tanimoto_5                                            1.000000
#
# [53 rows x 53 columns]

# %% [markdown]
# # Tune settings

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# train rf using optimised parameters from below

rf = RandomForestRegressor(n_estimators = 250, 
                           random_state = 42, 
                           max_depth = 5, 
                           verbose=1,
                           min_samples_leaf=50,
                           n_jobs=-1)
rf.fit(training_scores, training_labels)

# predict on train
rf_train_predictions = rf.predict(training_scores)
mse_train_rf = mean_squared_error(training_labels, rf_train_predictions)
print('Training MSE', mse_train_rf)

# predict on test
rf_predictions = rf.predict(validation_scores)
mse_rf = mean_squared_error(validation_labels, rf_predictions)
print('Validation MSE', mse_rf)

# get feature importances
importances = list(rf.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(training_scores.columns, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
# Out:
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_35220/278076265.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(training_scores, training_labels)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  6.7min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# Training MSE 0.029233031734963836
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# Validation MSE 0.028655398385403413
# Variable: chemical_neighbourhood_score Importance: 0.43
# Variable: precursor_mz_difference Importance: 0.16
# Variable: query_precursor_mz   Importance: 0.14
# Variable: s2v_score            Importance: 0.11
# Variable: average_ms2deepscore_9 Importance: 0.04
# Variable: tanimoto_score_structure_7 Importance: 0.02
# Variable: tanimoto_score_structure_9 Importance: 0.02
# Variable: ms2ds_score          Importance: 0.01
# Variable: average_ms2deepscore_1 Importance: 0.01
# Variable: average_ms2deepscore_3 Importance: 0.01
# Variable: average_ms2deepscore_5 Importance: 0.01
# Variable: average_ms2deepscore_6 Importance: 0.01
# Variable: average_ms2ds_score_for_inchikey14 Importance: 0.0
# Variable: nr_of_spectra_with_same_inchikey14 Importance: 0.0
# Variable: average_tanimoto_score_for_chemical_neighbourhood_score Importance: 0.0
# Variable: nr_of_spectra_for_chemical_neighbourhood_score Importance: 0.0
# Variable: cosine_score         Importance: 0.0
# Variable: modified_cosine_score Importance: 0.0
# Variable: lib_instrument_orbitrap Importance: 0.0
# Variable: lib_instrument_ion_trap Importance: 0.0
# Variable: lib_instrument_tof   Importance: 0.0
# Variable: lib_instrument_quadrupole Importance: 0.0
# Variable: query_instrument_orbitrap Importance: 0.0
# Variable: query_instrument_ion_trap Importance: 0.0
# Variable: query_instrument_tof Importance: 0.0
# Variable: query_instrument_quadrupole Importance: 0.0
# Variable: average_ms2deepscore_0 Importance: 0.0
# Variable: tanimoto_score_structure_0 Importance: 0.0
# Variable: nr_of_spectra_structure_0 Importance: 0.0
# Variable: tanimoto_score_structure_1 Importance: 0.0
# Variable: nr_of_spectra_structure_1 Importance: 0.0
# Variable: average_ms2deepscore_2 Importance: 0.0
# Variable: tanimoto_score_structure_2 Importance: 0.0
# Variable: nr_of_spectra_structure_2 Importance: 0.0
# Variable: tanimoto_score_structure_3 Importance: 0.0
# Variable: nr_of_spectra_structure_3 Importance: 0.0
# Variable: average_ms2deepscore_4 Importance: 0.0
# Variable: tanimoto_score_structure_4 Importance: 0.0
# Variable: nr_of_spectra_structure_4 Importance: 0.0
# Variable: tanimoto_score_structure_5 Importance: 0.0
# Variable: nr_of_spectra_structure_5 Importance: 0.0
# Variable: tanimoto_score_structure_6 Importance: 0.0
# Variable: nr_of_spectra_structure_6 Importance: 0.0
# Variable: average_ms2deepscore_7 Importance: 0.0
# Variable: nr_of_spectra_structure_7 Importance: 0.0
# Variable: average_ms2deepscore_8 Importance: 0.0
# Variable: tanimoto_score_structure_8 Importance: 0.0
# Variable: nr_of_spectra_structure_8 Importance: 0.0
# Variable: nr_of_spectra_structure_9 Importance: 0.0
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.2s finished
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Run with 30 features for similar structures, without chemical neighbourhood score

# %%
columns_to_drop = ["average_ms2ds_score_for_inchikey14",
                       "nr_of_spectra_with_same_inchikey14",
                       "chemical_neighbourhood_score",
                       "average_tanimoto_score_for_chemical_neighbourhood_score",
                       "nr_of_spectra_for_chemical_neighbourhood_score",
                   "lib_instrument_orbitrap",
                       "lib_instrument_ion_trap",
                       "lib_instrument_tof",
                       "lib_instrument_quadrupole",
                       "query_instrument_orbitrap",
                       "query_instrument_ion_trap",
                       "query_instrument_tof",
                       "query_instrument_quadrupole"]
selected_training_scores = training_scores.drop(columns_to_drop, axis=1)
selected_validation_scores = validation_scores.drop(columns_to_drop, axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# train rf using optimised parameters from below

rf = RandomForestRegressor(n_estimators = 250, 
                           random_state = 42, 
                           max_depth = 5, 
                           verbose=1,
                           min_samples_leaf=50,
                           n_jobs=-1)
rf.fit(selected_training_scores, training_labels)

# predict on train
rf_train_predictions = rf.predict(selected_training_scores)
mse_train_rf = mean_squared_error(training_labels, rf_train_predictions)
print('Training MSE', mse_train_rf)

# predict on test
rf_predictions = rf.predict(selected_validation_scores)
mse_rf = mean_squared_error(validation_labels, rf_predictions)
print('Validation MSE', mse_rf)

# get feature importances
importances = list(rf.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(selected_training_scores.columns, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
# Out:
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_35220/1839702755.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selected_training_scores, training_labels)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  5.2min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# Training MSE 0.029163197001385248
# Validation MSE 0.027283918454377432
# Variable: average_ms2deepscore_9 Importance: 0.37
# Variable: precursor_mz_difference Importance: 0.2
# Variable: query_precursor_mz   Importance: 0.16
# Variable: average_ms2deepscore_5 Importance: 0.06
# Variable: s2v_score            Importance: 0.05
# Variable: average_ms2deepscore_1 Importance: 0.05
# Variable: average_ms2deepscore_6 Importance: 0.04
# Variable: average_ms2deepscore_2 Importance: 0.03
# Variable: ms2ds_score          Importance: 0.01
# Variable: average_ms2deepscore_3 Importance: 0.01
# Variable: average_ms2deepscore_7 Importance: 0.01
# Variable: average_ms2deepscore_8 Importance: 0.01
# Variable: cosine_score         Importance: 0.0
# Variable: modified_cosine_score Importance: 0.0
# Variable: average_ms2deepscore_0 Importance: 0.0
# Variable: tanimoto_score_structure_0 Importance: 0.0
# Variable: nr_of_spectra_structure_0 Importance: 0.0
# Variable: tanimoto_score_structure_1 Importance: 0.0
# Variable: nr_of_spectra_structure_1 Importance: 0.0
# Variable: tanimoto_score_structure_2 Importance: 0.0
# Variable: nr_of_spectra_structure_2 Importance: 0.0
# Variable: tanimoto_score_structure_3 Importance: 0.0
# Variable: nr_of_spectra_structure_3 Importance: 0.0
# Variable: average_ms2deepscore_4 Importance: 0.0
# Variable: tanimoto_score_structure_4 Importance: 0.0
# Variable: nr_of_spectra_structure_4 Importance: 0.0
# Variable: tanimoto_score_structure_5 Importance: 0.0
# Variable: nr_of_spectra_structure_5 Importance: 0.0
# Variable: tanimoto_score_structure_6 Importance: 0.0
# Variable: nr_of_spectra_structure_6 Importance: 0.0
# Variable: tanimoto_score_structure_7 Importance: 0.0
# Variable: nr_of_spectra_structure_7 Importance: 0.0
# Variable: tanimoto_score_structure_8 Importance: 0.0
# Variable: nr_of_spectra_structure_8 Importance: 0.0
# Variable: tanimoto_score_structure_9 Importance: 0.0
# Variable: nr_of_spectra_structure_9 Importance: 0.0
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.2s finished
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ### Duplicate score to check how random forest behaves

# %%
selected_training_scores["average_ms2deepscore_9_duplicated"] = selected_training_scores["average_ms2deepscore_9"]
selected_training_scores.head()
# Out:
#    query_precursor_mz  precursor_mz_difference  s2v_score  ms2ds_score  \
# 0             357.206                   17.027   0.342509     0.958357
# 1             495.381                  121.148   0.120013     0.871954
# 2             373.165                    1.068   0.234691     0.867854
# 3             455.290                   81.057   0.082091     0.865033
# 4             373.165                    1.068   0.280886     0.861416
#
#    cosine_score  modified_cosine_score  average_ms2deepscore_0  \
# 0      0.843849               0.844019                0.738493
# 1      0.040108               0.040108                0.582930
# 2      0.183264               0.190980                0.793660
# 3      0.064454               0.065283                0.671383
# 4      0.131869               0.148776                0.793660
#
#    tanimoto_score_structure_0  nr_of_spectra_structure_0  \
# 0                         1.0                          2
# 1                         1.0                         23
# 2                         1.0                          4
# 3                         1.0                          1
# 4                         1.0                          4
#
#    average_ms2deepscore_1  ...  average_ms2deepscore_7  \
# 0                0.544468  ...                0.654104
# 1                0.576751  ...                0.575334
# 2                0.740528  ...                0.360988
# 3                0.653571  ...                0.393941
# 4                0.740528  ...                0.360988
#
#    tanimoto_score_structure_7  nr_of_spectra_structure_7  \
# 0                    0.714286                          1
# 1                    0.833770                         13
# 2                    0.673967                          1
# 3                    0.510050                          1
# 4                    0.673967                          1
#
#    average_ms2deepscore_8  tanimoto_score_structure_8  \
# 0                0.779384                    0.685567
# 1                0.599541                    0.825916
# 2                0.594069                    0.672654
# 3                0.511891                    0.506122
# 4                0.594069                    0.672654
#
#    nr_of_spectra_structure_8  average_ms2deepscore_9  \
# 0                          2                0.664638
# 1                          1                0.577323
# 2                          2                0.321590
# 3                          1                0.451606
# 4                          2                0.321590
#
#    tanimoto_score_structure_9  nr_of_spectra_structure_9  \
# 0                    0.668224                          2
# 1                    0.806069                         25
# 2                    0.672294                          1
# 3                    0.505410                          2
# 4                    0.672294                          1
#
#    average_ms2deepscore_9_duplicated
# 0                           0.664638
# 1                           0.577323
# 2                           0.321590
# 3                           0.451606
# 4                           0.321590
#
# [5 rows x 37 columns]

# %%
selected_validation_scores["average_ms2deepscore_9_duplicated"] = selected_training_scores["average_ms2deepscore_9"]
selected_validation_scores.head()
# Out:
#    query_precursor_mz  precursor_mz_difference  s2v_score  ms2ds_score  \
# 0             353.070                    0.000   0.275057     0.994153
# 1             353.070                    0.000   0.795537     0.990910
# 2             353.064                    0.006   0.309851     0.988226
# 3             353.064                    0.006   0.188902     0.986870
# 4             353.060                    0.010   0.589266     0.986744
#
#    cosine_score  modified_cosine_score  average_ms2deepscore_0  \
# 0      0.999314               0.999314                0.696601
# 1      0.999493               0.999493                0.696601
# 2      0.998043               0.998043                0.650752
# 3      0.998182               0.998182                0.650752
# 4      0.999215               0.999215                0.766091
#
#    tanimoto_score_structure_0  nr_of_spectra_structure_0  \
# 0                         1.0                         12
# 1                         1.0                         12
# 2                         1.0                        119
# 3                         1.0                        119
# 4                         1.0                         81
#
#    average_ms2deepscore_1  ...  average_ms2deepscore_7  \
# 0                0.536532  ...                0.512984
# 1                0.536532  ...                0.512984
# 2                0.655310  ...                0.571004
# 3                0.655310  ...                0.571004
# 4                0.710621  ...                0.559293
#
#    tanimoto_score_structure_7  nr_of_spectra_structure_7  \
# 0                    0.666199                          2
# 1                    0.666199                          2
# 2                    0.931792                         72
# 3                    0.931792                         72
# 4                    0.621039                          1
#
#    average_ms2deepscore_8  tanimoto_score_structure_8  \
# 0                0.506112                    0.658080
# 1                0.506112                    0.658080
# 2                0.550560                    0.928654
# 3                0.550560                    0.928654
# 4                0.525179                    0.620448
#
#    nr_of_spectra_structure_8  average_ms2deepscore_9  \
# 0                          3                0.560865
# 1                          3                0.560865
# 2                         62                0.664738
# 3                         62                0.664738
# 4                         11                0.576588
#
#    tanimoto_score_structure_9  nr_of_spectra_structure_9  \
# 0                    0.648837                         93
# 1                    0.648837                         93
# 2                    0.928112                         60
# 3                    0.928112                         60
# 4                    0.620321                         74
#
#    average_ms2deepscore_9_duplicated
# 0                           0.664638
# 1                           0.577323
# 2                           0.321590
# 3                           0.451606
# 4                           0.321590
#
# [5 rows x 37 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# train rf using optimised parameters from below

rf = RandomForestRegressor(n_estimators = 250, 
                           random_state = 42, 
                           max_depth = 5, 
                           verbose=1,
                           min_samples_leaf=50,
                           n_jobs=-1)
rf.fit(selected_training_scores, training_labels)

# predict on train
rf_train_predictions = rf.predict(selected_training_scores)
mse_train_rf = mean_squared_error(training_labels, rf_train_predictions)
print('Training MSE', mse_train_rf)

# predict on test
rf_predictions = rf.predict(selected_validation_scores)
mse_rf = mean_squared_error(validation_labels, rf_predictions)
print('Validation MSE', mse_rf)

# get feature importances
importances = list(rf.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(selected_training_scores.columns, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
# Out:
# C:\Users\jonge094\AppData\Local\Temp/ipykernel_35220/1839702755.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(selected_training_scores, training_labels)
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  5.5min finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# Training MSE 0.029163198449911065
# Validation MSE 0.029619576135149716
# Variable: precursor_mz_difference Importance: 0.2
# Variable: average_ms2deepscore_9 Importance: 0.19
# Variable: average_ms2deepscore_9_duplicated Importance: 0.18
# Variable: query_precursor_mz   Importance: 0.16
# Variable: average_ms2deepscore_5 Importance: 0.06
# Variable: s2v_score            Importance: 0.05
# Variable: average_ms2deepscore_1 Importance: 0.05
# Variable: average_ms2deepscore_6 Importance: 0.04
# Variable: average_ms2deepscore_2 Importance: 0.03
# Variable: ms2ds_score          Importance: 0.01
# Variable: average_ms2deepscore_3 Importance: 0.01
# Variable: average_ms2deepscore_7 Importance: 0.01
# Variable: average_ms2deepscore_8 Importance: 0.01
# Variable: cosine_score         Importance: 0.0
# Variable: modified_cosine_score Importance: 0.0
# Variable: average_ms2deepscore_0 Importance: 0.0
# Variable: tanimoto_score_structure_0 Importance: 0.0
# Variable: nr_of_spectra_structure_0 Importance: 0.0
# Variable: tanimoto_score_structure_1 Importance: 0.0
# Variable: nr_of_spectra_structure_1 Importance: 0.0
# Variable: tanimoto_score_structure_2 Importance: 0.0
# Variable: nr_of_spectra_structure_2 Importance: 0.0
# Variable: tanimoto_score_structure_3 Importance: 0.0
# Variable: nr_of_spectra_structure_3 Importance: 0.0
# Variable: average_ms2deepscore_4 Importance: 0.0
# Variable: tanimoto_score_structure_4 Importance: 0.0
# Variable: nr_of_spectra_structure_4 Importance: 0.0
# Variable: tanimoto_score_structure_5 Importance: 0.0
# Variable: nr_of_spectra_structure_5 Importance: 0.0
# Variable: tanimoto_score_structure_6 Importance: 0.0
# Variable: nr_of_spectra_structure_6 Importance: 0.0
# Variable: tanimoto_score_structure_7 Importance: 0.0
# Variable: nr_of_spectra_structure_7 Importance: 0.0
# Variable: tanimoto_score_structure_8 Importance: 0.0
# Variable: nr_of_spectra_structure_8 Importance: 0.0
# Variable: tanimoto_score_structure_9 Importance: 0.0
# Variable: nr_of_spectra_structure_9 Importance: 0.0
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.2s finished
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
